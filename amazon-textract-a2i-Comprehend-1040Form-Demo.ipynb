# %% [markdown]
# ## Step 0 - Install and Import Libraries
#
# We will be using the [Amazon Textract Parser Library](https://github.com/aws-samples/amazon-textract-response-parser/tree/master/src-python) for parsing through the Textract response, data science library [Pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) for content analysis, the [Amazon SageMaker Python SDK](https://sagemaker.readthedocs.io/en/stable/), and [AWS boto3 python sdk](https://boto3.amazonaws.com/v1/documentation/api/latest/index.html) to work with Amazon Textract and Amazon A2I. Let's now install and import them.

# %%
# install trp
# !pip install amazon-textract-response-parser
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: amazon-textract-response-parser in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from amazon-textract-response-parser) (1.26.157)
# Requirement already satisfied: marshmallow<4,>=3.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from amazon-textract-response-parser) (3.20.1)
# Requirement already satisfied: packaging>=17.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from marshmallow<4,>=3.14->amazon-textract-response-parser) (21.3)
# Requirement already satisfied: botocore<1.30.0,>=1.29.157 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3->amazon-textract-response-parser) (1.29.157)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3->amazon-textract-response-parser) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3->amazon-textract-response-parser) (0.6.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.157->boto3->amazon-textract-response-parser) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.157->boto3->amazon-textract-response-parser) (1.26.14)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4,>=3.14->amazon-textract-response-parser) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.157->boto3->amazon-textract-response-parser) (1.16.0)

# %%
import pandas as pd
import webbrowser, os
import json
import boto3
import re
import sagemaker
from sagemaker import get_execution_role
from sagemaker.s3 import S3Uploader, S3Downloader
import uuid
import time
import io
from io import BytesIO
import sys
import csv
from pprint import pprint
from IPython.display import Image, display
from PIL import Image as PImage, ImageDraw

from IPython.display import Image, display, IFrame
from PIL import Image as PImage, ImageDraw
from textractprettyprinter.t_pretty_print_expense import get_string, Textract_Expense_Pretty_Print, Pretty_Print_Table_Format, get_expensesummary_string, get_expenselineitemgroups_string
# from textractcaller.t_call import call_textract, Textract_Features
from textractprettyprinter.t_pretty_print import Textract_Pretty_Print, get_string

# %% [markdown]
# ### Setup a private review workforce
#
# This step requires you to use the AWS Console. However, we highly recommend that you follow it, especially when creating your own task with a custom template we will use for this notebook. We will create a private workteam and add only one user (you) to it.
#
# To create a private team:
#
#    1. Go to AWS Console > Amazon SageMaker > Labeling workforces
#    1. Click "Private" and then "Create private team".
#    1. Enter the desired name for your private workteam.
#    1. Enter your own email address in the "Email addresses" section.
#    1. Enter the name of your organization and a contact email to administer the private workteam.
#    1. Click "Create Private Team".
#    1. The AWS Console should now return to AWS Console > Amazon SageMaker > Labeling workforces. Your newly created team should be visible under "Private teams". Next to it you will see an ARN which is a long string that looks like arn:aws:sagemaker:region-name-123456:workteam/private-crowd/team-name. Please copy this ARN to paste in the cell below.
#    1. You should get an email from no-reply@verificationemail.com that contains your workforce username and password.
#    1. In AWS Console > Amazon SageMaker > Labeling workforces, click on the URL in Labeling portal sign-in URL. Use the email/password combination from Step 8 to log in (you will be asked to create a new, non-default password).
#    1. This is your private worker's interface. When we create a verification task in Verify your task using a private team below, your task should appear in this window. You can invite your colleagues to participate in the labeling job by clicking the "Invite new workers" button.
#
# Please refer to the Amazon SageMaker documentation if you need more details.

# %%
# Enter the Workteam ARN from step 7 above
WORKTEAM_ARN= 'arn:aws:sagemaker:us-east-1:485636232393:workteam/private-crowd/demo'
 
# Define IAM role
role = get_execution_role()
print("RoleArn: {}".format(role))
sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = 'textract-a2i-handwritten'
# Out:
# RoleArn: arn:aws:iam::485636232393:role/TextractA2I-SageMakerIamRole-T6LRZRF62Q68

# %%
# !pip install poppler-utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting poppler-utils
#   Downloading poppler_utils-0.1.0-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: Click>=7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from poppler-utils) (8.1.3)
# Installing collected packages: poppler-utils
# Successfully installed poppler-utils-0.1.0

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# devtmpfs        1.9G     0  1.9G   0% /dev
# tmpfs           2.0G     0  2.0G   0% /dev/shm
# tmpfs           2.0G  588K  2.0G   1% /run
# tmpfs           2.0G     0  2.0G   0% /sys/fs/cgroup
# /dev/xvda1      180G  135G   46G  75% /
# /dev/xvdf       9.7G   44M  9.2G   1% /home/ec2-user/SageMaker
# tmpfs           391M     0  391M   0% /run/user/1002
# tmpfs           391M     0  391M   0% /run/user/1001
# tmpfs           391M     0  391M   0% /run/user/1000

# %% [markdown]
# ## Step 1 - Use Amazon Textract to retrieve document content and inspect response
#
# In this step, we will download our test invoice from a S3 bucket to our notebook instance, and then use Amazon Textract to read the hand-written content present in the invoice line items table, and load this into a pandas dataframe for analysis.

# %% [markdown]
# #### Review the sample document which has both printed and handwritten content in the tables

# %%
import fitz  # PyMuPDF
from IPython.display import display_pdf
from pdf2image import convert_from_path

documentName = "f1040 Page 1 Sample - Handwritten - Soumya.pdf"


def pdf_to_images(pdf_file, output_folder):
    # Open the PDF file
    pdf_document = fitz.open(pdf_file)

    # Iterate through pages and convert each page to an image
    for page_number in range(len(pdf_document)):
        page = pdf_document[page_number]
        image = page.get_pixmap()

        # Save the image as a PNG file
        image.save(f"{output_folder}/{pdf_file}.png")

output_folder = '.'  # Replace with your desired output folder

pdf_to_images(documentName, output_folder)
image_paths = [f"{'.'}/{documentName}.png"]

# %%
s3_img_url = S3Uploader.upload(f"{documentName}.png", 's3://{}/{}'.format(bucket, prefix))

# %%
client = boto3.client(
         service_name='textract',
         region_name= 'us-east-1',
         endpoint_url='https://textract.us-east-1.amazonaws.com',
)

# %%
with open(documentName, 'rb') as file:
        img_test = file.read()
        bytes_test = bytearray(img_test)
        print('Image loaded', documentName)
# Out:
# Image loaded f1040 Page 1 Sample - Handwritten - Soumya.pdf

# %%
# process using image bytes
response = client.analyze_document(Document={'Bytes': bytes_test}, FeatureTypes=['TABLES','FORMS'])

# %%
response
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 2.555005664817145e-07},
#      {'X': 1.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 9.367063853460422e-07, 'Y': 1.0}]},
#    'Id': '1c20c8c8-3823-4188-beaa-ad8dbe42a600',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8f7b1058-3309-46d4-8ac3-77e390f1176c',
#       '7a5c8cfa-a7ec-4d0f-88d2-a797c829f3d9',
#       'a79f6fab-e290-4190-bd07-856cef6c28ee',
#       'e4119cb5-4403-4deb-b016-bd6c11c0ea69',
#       'ad185e1a-cf8c-4b6c-ad82-e0be6dc95fe8',
#       'dbd26741-74ee-49f0-95be-ddcebff675e0',
#       '428e1c4a-42de-46b1-92f3-34ae3840a4ba',
#       '9de74134-b335-4651-a26a-a15c61590ef2',
#       'cdeb30c8-0037-4534-b956-c343b4b3bcf0',
#       '456a762f-40f7-40dd-a9c7-a6e06fdf9b9d',
#       '4ad03df3-7225-42a5-a1e6-ba17fe2ab990',
#       'bfb0a1b8-d870-4095-b5aa-cc0b729feec8',
#       'ce5871ef-65ed-4d2e-b4bc-8d437aae506a',
#       '9838d59f-a2d8-4582-9998-c09d71c6e096',
#       'ea7bed9f-a4d3-4abe-bef9-82621b58de9e',
#       '98e6d6d0-137f-420b-88eb-061c6456c574',
#       'd75eb107-4176-45b0-bb40-e4b1b8e74c57',
#       '454b48aa-bfd9-41d4-b6cb-684ecfa0ed66',
#       'e4e75d8f-da20-4f35-b501-3974498e0738',
#       'c587e190-4d83-4906-a4f5-87e130ac50ff',
#       'b1d79d9e-9f11-4a52-a532-5e0c86d5b7ab',
#       'e76753d5-4b8b-4fdb-86c2-64a7f487bf06',
#       '5907fb6c-3367-4df1-8f9b-ee0f977822e5',
#       '1a211f31-faa9-4811-b14a-6a96e4ba0357',
#       'c73403ff-63e3-40af-ae92-33b7e8fad8b5',
#       'f3edb7f4-7d57-4cce-9d70-80a305c16d87',
#       '6bd6aea9-2d24-4dd9-9f27-9fe0403334d1',
#       '0abc0192-9c9a-4cfd-8ee7-c710d2a7e115',
#       '00f624a8-5900-42bf-9d03-a621e08d88ec',
#       '415accd5-6e35-461e-9bee-9b79d25d9690',
#       '96ba06f7-c717-4853-9a57-4fe6e62fea42',
#       'df6628c5-316b-4df0-b4df-be9b2ec1527a',
#       '920735ad-ba03-4085-9412-39beb7aaa260',
#       '9bca8be4-fa50-4469-9443-c996c3065626',
#       '189e1166-f201-4f3c-8e30-46aa79569405',
#       'f5a0687a-00c0-471a-88e0-7998c1d46412',
#       '5e8625db-70f9-40c2-b2e3-4ae789c6eab7',
#       '7cd71716-0c98-4376-a4f4-21ec74e1f975',
#       '25ab5d42-55ad-47c8-88f9-edb61f59a5b7',
#       'fe69db2f-f26a-409e-9cef-5d0e41ed4db6',
#       '7e434f98-a4d3-48b9-9067-e0ff409f2bf5',
#       '051860a3-8947-4710-afcc-51796ee6d121',
#       '147cb893-78cc-4a2d-bc15-a0b5c87268e5',
#       'c6633030-3c45-40ab-b1fe-296758674a22']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.80696105957031,
#    'Text': 'Filing Status',
#    'Geometry': {'BoundingBox': {'Width': 0.09008651971817017,
#      'Height': 0.01241262350231409,
#      'Left': 0.04208345338702202,
#      'Top': 0.08388248085975647},
#     'Polygon': [{'X': 0.04208345338702202, 'Y': 0.08393289148807526},
#      {'X': 0.1321585476398468, 'Y': 0.08388248085975647},
#      {'X': 0.13216997683048248, 'Y': 0.09624382108449936},
#      {'X': 0.04209214821457863, 'Y': 0.09629510343074799}]},
#    'Id': '428e1c4a-42de-46b1-92f3-34ae3840a4ba',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['916e12e0-b0aa-40bb-adb0-e30dd8a862e3',
#       'f07a1374-17fe-4c6c-94bc-033ba3047f1a']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.84115600585938,
#    'Text': 'Single',
#    'Geometry': {'BoundingBox': {'Width': 0.03729948773980141,
#      'Height': 0.010623972862958908,
#      'Left': 0.1622249037027359,
#      'Top': 0.0853925496339798},
#     'Polygon': [{'X': 0.1622249037027359, 'Y': 0.08541347086429596},
#      {'X': 0.19951283931732178, 'Y': 0.0853925496339798},
#      {'X': 0.1995244026184082, 'Y': 0.09599529951810837},
#      {'X': 0.16223549842834473, 'Y': 0.096016526222229}]},
#    'Id': '9de74134-b335-4651-a26a-a15c61590ef2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b2139918-5c87-4031-bbbb-e5b064be1d58']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.80797576904297,
#    'Text': 'Married filing jointly',
#    'Geometry': {'BoundingBox': {'Width': 0.11610810458660126,
#      'Height': 0.010980888269841671,
#      'Left': 0.2349015772342682,
#      'Top': 0.08502659201622009},
#     'Polygon': [{'X': 0.2349015772342682, 'Y': 0.08509168773889542},
#      {'X': 0.35099372267723083, 'Y': 0.08502659201622009},
#      {'X': 0.35100969672203064, 'Y': 0.09594140201807022},
#      {'X': 0.23491442203521729, 'Y': 0.09600748121738434}]},
#    'Id': 'cdeb30c8-0037-4534-b956-c343b4b3bcf0',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['79ebbadc-042a-4d47-8dc3-5ce9503d8299',
#       '8159fee0-d0ae-4bae-b77d-39d9a9c25d9f',
#       '87f8812e-2340-4aca-b585-3ee46db0870e']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.8315200805664,
#    'Text': 'Married filing separately (MFS)',
#    'Geometry': {'BoundingBox': {'Width': 0.17856217920780182,
#      'Height': 0.01098912674933672,
#      'Left': 0.39177677035331726,
#      'Top': 0.08500152826309204},
#     'Polygon': [{'X': 0.39177677035331726, 'Y': 0.0851016491651535},
#      {'X': 0.5703172087669373, 'Y': 0.08500152826309204},
#      {'X': 0.5703389644622803, 'Y': 0.09588902443647385},
#      {'X': 0.39179378747940063, 'Y': 0.09599065035581589}]},
#    'Id': '456a762f-40f7-40dd-a9c7-a6e06fdf9b9d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['150245de-7574-47f8-8ebd-651cff0c38d2',
#       '5681ae6e-ee97-4d52-94bb-b9d769b67294',
#       '627c6d80-3a05-41d3-8c89-702d605ff0b4',
#       'aa9697a9-1017-402f-8c7c-943154d3e9ae']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.94461822509766,
#    'Text': 'Head of household (HOH)',
#    'Geometry': {'BoundingBox': {'Width': 0.14445336163043976,
#      'Height': 0.010921234264969826,
#      'Left': 0.6066108345985413,
#      'Top': 0.08509467542171478},
#     'Polygon': [{'X': 0.6066108345985413, 'Y': 0.08517568558454514},
#      {'X': 0.7510377168655396, 'Y': 0.08509467542171478},
#      {'X': 0.7510641813278198, 'Y': 0.09593368321657181},
#      {'X': 0.6066334247589111, 'Y': 0.09601590782403946}]},
#    'Id': '4ad03df3-7225-42a5-a1e6-ba17fe2ab990',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5eec1728-d4ea-4eae-936f-f18f481c9bd0',
#       'ae1bfea9-1d25-4629-afc8-283621806ea2',
#       'dd8a8de0-2c3c-4586-a7fa-767ff505ad5a',
#       'bc8d71ee-599e-4cbb-9f19-9f2c21b8b2a4']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.6077880859375,
#    'Text': 'Qualifying surviving',
#    'Geometry': {'BoundingBox': {'Width': 0.11630610376596451,
#      'Height': 0.010899138636887074,
#      'Left': 0.7865773439407349,
#      'Top': 0.08533723652362823},
#     'Polygon': [{'X': 0.7865773439407349, 'Y': 0.0854024812579155},
#      {'X': 0.9028529524803162, 'Y': 0.08533723652362823},
#      {'X': 0.9028834104537964, 'Y': 0.09617014229297638},
#      {'X': 0.7866047024726868, 'Y': 0.09623637050390244}]},
#    'Id': 'bfb0a1b8-d870-4095-b5aa-cc0b729feec8',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['1471403e-ca5b-4f37-99ef-d9e63d21ac45',
#       '96be0382-1a4d-437c-af9b-f4c1d6c6cdee']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.9493179321289,
#    'Text': 'Check only',
#    'Geometry': {'BoundingBox': {'Width': 0.06719794124364853,
#      'Height': 0.01068917103111744,
#      'Left': 0.04302973672747612,
#      'Top': 0.09947837144136429},
#     'Polygon': [{'X': 0.04302973672747612, 'Y': 0.09951678663492203},
#      {'X': 0.11021841317415237, 'Y': 0.09947837144136429},
#      {'X': 0.11022768169641495, 'Y': 0.11012856662273407},
#      {'X': 0.043037254363298416, 'Y': 0.11016754060983658}]},
#    'Id': 'ce5871ef-65ed-4d2e-b4bc-8d437aae506a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['bfb562f6-3f0a-4b06-9f16-06bfcc89aecf',
#       'e46248f5-6e22-4c7e-a53f-17ee213a0536']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.84162139892578,
#    'Text': 'spouse (QSS)',
#    'Geometry': {'BoundingBox': {'Width': 0.08212818950414658,
#      'Height': 0.010767273604869843,
#      'Left': 0.7864469885826111,
#      'Top': 0.0963255912065506},
#     'Polygon': [{'X': 0.7864469885826111, 'Y': 0.09637236595153809},
#      {'X': 0.8685458898544312, 'Y': 0.0963255912065506},
#      {'X': 0.8685751557350159, 'Y': 0.10704541206359863},
#      {'X': 0.7864741086959839, 'Y': 0.10709286481142044}]},
#    'Id': '9838d59f-a2d8-4582-9998-c09d71c6e096',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a2abe102-aebc-4e1d-b4d5-068eb03c82c1',
#       '27686132-44f3-4ec0-8950-a11c566b28e0']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.56189727783203,
#    'Text': 'one box.',
#    'Geometry': {'BoundingBox': {'Width': 0.0518978126347065,
#      'Height': 0.008352191187441349,
#      'Left': 0.04318634793162346,
#      'Top': 0.11096794903278351},
#     'Polygon': [{'X': 0.04318634793162346, 'Y': 0.11099808663129807},
#      {'X': 0.09507722407579422, 'Y': 0.11096794903278351},
#      {'X': 0.09508416056632996, 'Y': 0.11928967386484146},
#      {'X': 0.04319222271442413, 'Y': 0.11932014673948288}]},
#    'Id': 'ea7bed9f-a4d3-4abe-bef9-82621b58de9e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5907f7c9-c27e-4ea8-9898-1e5a8415a008',
#       'b0779fdf-8c98-474a-bf70-4f9483c1707c']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.77618408203125,
#    'Text': "If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child's name if the qualifying",
#    'Geometry': {'BoundingBox': {'Width': 0.7986370325088501,
#      'Height': 0.01118827797472477,
#      'Left': 0.14302663505077362,
#      'Top': 0.109505295753479},
#     'Polygon': [{'X': 0.14302663505077362, 'Y': 0.10996843874454498},
#      {'X': 0.9416324496269226, 'Y': 0.109505295753479},
#      {'X': 0.9416636824607849, 'Y': 0.12022377550601959},
#      {'X': 0.1430368274450302, 'Y': 0.12069357186555862}]},
#    'Id': '98e6d6d0-137f-420b-88eb-061c6456c574',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e9a127f6-01a1-4ecc-8067-96268de13fd5',
#       'b3885f0a-f843-4134-ae4e-6925c879bbb7',
#       'c41bdddf-e68d-4539-aa4c-c2fa8db2e44d',
#       'fb14e8af-7fc6-4180-88c5-533e017433f8',
#       '80a58976-cf0d-4cee-844d-5eba57c4a9fb',
#       '4748f42e-d859-4883-9dfb-a5bdc8c4623a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['563f900d-e80c-4911-97b6-caf9b7a52de5',
#       '21dc9af8-d28d-428e-b5e8-53d1329eead3',
#       '2eeae385-915b-4291-8143-ba376da38d33',
#       '5ab58407-9f77-4c1c-bfe1-64d3517e6833',
#       'e5701f8e-c74b-40aa-aa92-55c99bca5dc9',
#       '3d9dee70-be2a-4e9f-ad65-16c324952caa']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.9211654663086,
#    'Text': 'Last name',
#    'Geometry': {'BoundingBox': {'Width': 0.05466853827238083,
#      'Height': 0.007429610006511211,
#      'Left': 0.38652607798576355,
#      'Top': 0.14040035009384155},
#     'Polygon': [{'X': 0.38652607798576355, 'Y': 0.14043334126472473},
#      {'X': 0.4411821663379669, 'Y': 0.14040035009384155},
#      {'X': 0.441194623708725, 'Y': 0.1477966457605362},
#      {'X': 0.3865375220775604, 'Y': 0.14782994985580444}]},
#    'Id': 'e4e75d8f-da20-4f35-b501-3974498e0738',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['46e6341d-0e04-4b9e-86da-af76c3a50e26',
#       'c3fb4098-c5ce-4bef-aee4-a13201175415']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.57872009277344,
#    'Text': 'Your social security number',
#    'Geometry': {'BoundingBox': {'Width': 0.1574879139661789,
#      'Height': 0.009653276763856411,
#      'Left': 0.7690325975418091,
#      'Top': 0.1398763209581375},
#     'Polygon': [{'X': 0.7690325975418091, 'Y': 0.13997136056423187},
#      {'X': 0.9264930486679077, 'Y': 0.1398763209581375},
#      {'X': 0.9265204668045044, 'Y': 0.14943340420722961},
#      {'X': 0.7690563201904297, 'Y': 0.1495296061038971}]},
#    'Id': 'c587e190-4d83-4906-a4f5-87e130ac50ff',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['aa014730-e308-4298-98e6-9a6d3972dc4d',
#       'cc562d86-c1d8-40c8-933e-2cde7cbe71a1',
#       'a064f920-2773-42ff-aa74-8ecfb7f21a03',
#       'd4f95372-8cde-4973-87a2-5e4baacc2200']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 98.53521728515625,
#    'Text': 'JOHN J',
#    'Geometry': {'BoundingBox': {'Width': 0.10962802171707153,
#      'Height': 0.018257424235343933,
#      'Left': 0.04694512113928795,
#      'Top': 0.15074476599693298},
#     'Polygon': [{'X': 0.04694512113928795, 'Y': 0.1508118063211441},
#      {'X': 0.15655525028705597, 'Y': 0.15074476599693298},
#      {'X': 0.15657314658164978, 'Y': 0.16893361508846283},
#      {'X': 0.04695812985301018, 'Y': 0.16900219023227692}]},
#    'Id': 'b1d79d9e-9f11-4a52-a532-5e0c86d5b7ab',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['9e71ccce-3350-4642-96ca-845488604f07',
#       '5cbb1370-e11e-4b02-b1ae-7c5888143da8']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.81177520751953,
#    'Text': 'SMITH',
#    'Geometry': {'BoundingBox': {'Width': 0.0795825868844986,
#      'Height': 0.019300665706396103,
#      'Left': 0.3893839716911316,
#      'Top': 0.14738471806049347},
#     'Polygon': [{'X': 0.3893839716911316, 'Y': 0.14743316173553467},
#      {'X': 0.4689328670501709, 'Y': 0.14738471806049347},
#      {'X': 0.4689665734767914, 'Y': 0.16663573682308197},
#      {'X': 0.3894139230251312, 'Y': 0.16668537259101868}]},
#    'Id': 'e76753d5-4b8b-4fdb-86c2-64a7f487bf06',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['29cc8c45-40d4-4177-97ad-0a26c9eb33da']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 79.23318481445312,
#    'Text': '123 45 6789',
#    'Geometry': {'BoundingBox': {'Width': 0.17038479447364807,
#      'Height': 0.015758659690618515,
#      'Left': 0.7663208246231079,
#      'Top': 0.15123175084590912},
#     'Polygon': [{'X': 0.7663208246231079, 'Y': 0.15133605897426605},
#      {'X': 0.9366602897644043, 'Y': 0.15123175084590912},
#      {'X': 0.9367056488990784, 'Y': 0.16688404977321625},
#      {'X': 0.7663596868515015, 'Y': 0.16699041426181793}]},
#    'Id': '5907fb6c-3367-4df1-8f9b-ee0f977822e5',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a91fce0c-18c7-4866-8d03-e5dbc5e82f00']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.89195251464844,
#    'Text': "If joint return, spouse's first name and middle initial",
#    'Geometry': {'BoundingBox': {'Width': 0.264850378036499,
#      'Height': 0.010159782133996487,
#      'Left': 0.05195990204811096,
#      'Top': 0.17073719203472137},
#     'Polygon': [{'X': 0.05195990204811096, 'Y': 0.170903280377388},
#      {'X': 0.31679654121398926, 'Y': 0.17073719203472137},
#      {'X': 0.31681028008461, 'Y': 0.18072883784770966},
#      {'X': 0.05196717008948326, 'Y': 0.18089698255062103}]},
#    'Id': '1a211f31-faa9-4811-b14a-6a96e4ba0357',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['6c43e212-4abe-446d-88bf-fe66478b9208',
#       '2921d33f-5ada-45bd-97d6-9d7317b33af5',
#       'b2872e78-3657-44c1-921d-47aad809c7c0',
#       '35fb8720-ba1c-4b1a-aeb5-7d4256966623',
#       '786828c9-4e5b-48c5-892f-1355711c6276',
#       '40d22856-1aa6-40e9-844c-11d931976a0d',
#       '9a40fc9d-c894-4265-aff3-a61e0f192b8f',
#       '931bea65-f035-4e74-8110-1c9df36fa882',
#       '800ff6d4-2702-4014-97cd-7ff75ea3c89f']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.881103515625,
#    'Text': 'Last name',
#    'Geometry': {'BoundingBox': {'Width': 0.054542165249586105,
#      'Height': 0.007642571348696947,
#      'Left': 0.38694965839385986,
#      'Top': 0.1708773970603943},
#     'Polygon': [{'X': 0.38694965839385986, 'Y': 0.17091159522533417},
#      {'X': 0.44147902727127075, 'Y': 0.1708773970603943},
#      {'X': 0.4414918124675751, 'Y': 0.1784854382276535},
#      {'X': 0.386961430311203, 'Y': 0.17851996421813965}]},
#    'Id': 'c73403ff-63e3-40af-ae92-33b7e8fad8b5',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['50d036bd-60f8-4583-924c-f87c76e55c9b',
#       'd3d3234f-d05c-427d-861e-46f71185a7e6']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.63674926757812,
#    'Text': "Spouse's social security number",
#    'Geometry': {'BoundingBox': {'Width': 0.17542234063148499,
#      'Height': 0.009329767897725105,
#      'Left': 0.7691923975944519,
#      'Top': 0.1703946441411972},
#     'Polygon': [{'X': 0.7691923975944519, 'Y': 0.1705046445131302},
#      {'X': 0.9445878863334656, 'Y': 0.1703946441411972},
#      {'X': 0.9446147680282593, 'Y': 0.1796131581068039},
#      {'X': 0.7692153453826904, 'Y': 0.17972441017627716}]},
#    'Id': 'f3edb7f4-7d57-4cce-9d70-80a305c16d87',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b5c272c3-50b2-4fe5-8583-1852f91c3637',
#       'c4b21d55-f263-4da3-a67d-10f0223aec2d',
#       '97f10311-c4b0-40ea-b209-0d6de5344daf',
#       '9a6129c9-4faa-4e07-a414-34137931ce53']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 96.60441589355469,
#    'Text': 'JANE K',
#    'Geometry': {'BoundingBox': {'Width': 0.12449505925178528,
#      'Height': 0.016301529482007027,
#      'Left': 0.04852844029664993,
#      'Top': 0.18237324059009552},
#     'Polygon': [{'X': 0.04852844029664993, 'Y': 0.18245241045951843},
#      {'X': 0.17300689220428467, 'Y': 0.18237324059009552},
#      {'X': 0.1730235069990158, 'Y': 0.19859401881694794},
#      {'X': 0.04854010045528412, 'Y': 0.1986747682094574}]},
#    'Id': '6bd6aea9-2d24-4dd9-9f27-9fe0403334d1',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a5092a63-4572-4b07-a1eb-80b6f938d342',
#       '80706796-15cb-4694-b163-6df8c5d61ed1']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.76094055175781,
#    'Text': 'SMITH',
#    'Geometry': {'BoundingBox': {'Width': 0.08136595040559769,
#      'Height': 0.015427960082888603,
#      'Left': 0.39492398500442505,
#      'Top': 0.18261054158210754},
#     'Polygon': [{'X': 0.39492398500442505, 'Y': 0.18266230821609497},
#      {'X': 0.47626274824142456, 'Y': 0.18261054158210754},
#      {'X': 0.47628992795944214, 'Y': 0.19798576831817627},
#      {'X': 0.3949480950832367, 'Y': 0.1980385035276413}]},
#    'Id': '0abc0192-9c9a-4cfd-8ee7-c710d2a7e115',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['61de73c2-65be-4342-86ec-53c77e89e3e8']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 64.75991821289062,
#    'Text': '9871654321',
#    'Geometry': {'BoundingBox': {'Width': 0.15721412003040314,
#      'Height': 0.01691785641014576,
#      'Left': 0.7646774649620056,
#      'Top': 0.18002483248710632},
#     'Polygon': [{'X': 0.7646774649620056, 'Y': 0.18012456595897675},
#      {'X': 0.9218434691429138, 'Y': 0.18002483248710632},
#      {'X': 0.9218915700912476, 'Y': 0.19684089720249176},
#      {'X': 0.7647191286087036, 'Y': 0.19694268703460693}]},
#    'Id': '00f624a8-5900-42bf-9d03-a621e08d88ec',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['132251fe-acba-44ab-a07c-01cea365d3c7']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.10761260986328,
#    'Text': 'Home address (number and street). If you have a P.O. box, see instructions.',
#    'Geometry': {'BoundingBox': {'Width': 0.3935737609863281,
#      'Height': 0.009869080036878586,
#      'Left': 0.052683025598526,
#      'Top': 0.20102189481258392},
#     'Polygon': [{'X': 0.052683025598526, 'Y': 0.201277956366539},
#      {'X': 0.44624048471450806, 'Y': 0.20102189481258392},
#      {'X': 0.4462567865848541, 'Y': 0.21063195168972015},
#      {'X': 0.05269003286957741, 'Y': 0.2108909636735916}]},
#    'Id': '415accd5-6e35-461e-9bee-9b79d25d9690',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['6adfab0b-4fc3-4a90-8d7c-4935d912716b',
#       'a88bd0a4-9800-4476-b2de-a9b82cbafff9',
#       '44ad2721-e578-499f-9c6b-e9f6603929c8',
#       '93fa090b-ee65-45ff-a4e1-3a6ec7bf0370',
#       'cb6438e0-b218-4028-956d-5e09ec0511de',
#       '84b3fd8d-d8c7-43ac-bef4-24a72dc32bd5',
#       '3ef5a7f0-8832-4358-9614-2b8535d1b8dd',
#       'e04476fb-5c7a-408f-8908-f94878bdeefd',
#       'c931e5b4-a48a-4a11-89ad-f0c783565734',
#       '16c78990-0cb5-4152-b313-a20a64af2075',
#       '87af81b4-1e79-4d4a-b856-d7a9ef8dbaa3',
#       '0fd93d23-7bd1-491e-b95c-71b42de5bfaf',
#       'f121cf1e-14e9-4458-8ed6-cc94d86dd34a']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.71284484863281,
#    'Text': 'Apt. no.',
#    'Geometry': {'BoundingBox': {'Width': 0.041825514286756516,
#      'Height': 0.009155821986496449,
#      'Left': 0.6851625442504883,
#      'Top': 0.20069795846939087},
#     'Polygon': [{'X': 0.6851625442504883, 'Y': 0.20072515308856964},
#      {'X': 0.7269663214683533, 'Y': 0.20069795846939087},
#      {'X': 0.7269880771636963, 'Y': 0.2098262757062912},
#      {'X': 0.6851834058761597, 'Y': 0.20985376834869385}]},
#    'Id': '96ba06f7-c717-4853-9a57-4fe6e62fea42',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f0c8edd2-dc8d-4965-a58e-b7860a6fc816',
#       '0a607666-30f4-43ab-9a5d-94429a690330']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.78077697753906,
#    'Text': 'Presidential Election Campaign',
#    'Geometry': {'BoundingBox': {'Width': 0.17427466809749603,
#      'Height': 0.00998244620859623,
#      'Left': 0.7698148488998413,
#      'Top': 0.20132166147232056},
#     'Polygon': [{'X': 0.7698148488998413, 'Y': 0.2014351189136505},
#      {'X': 0.944060742855072, 'Y': 0.20132166147232056},
#      {'X': 0.9440894722938538, 'Y': 0.21118931472301483},
#      {'X': 0.7698394060134888, 'Y': 0.21130411326885223}]},
#    'Id': 'df6628c5-316b-4df0-b4df-be9b2ec1527a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f6ed667c-fb54-4806-a045-a8ade7f4fa1e',
#       '7548c27b-1d0b-42a5-b2ee-2d8db261211f',
#       'cb0ebde5-79c8-43b9-b158-9f233ec45a5a']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.21765899658203,
#    'Text': '1040 N PHOENIX RD',
#    'Geometry': {'BoundingBox': {'Width': 0.29642269015312195,
#      'Height': 0.02013975754380226,
#      'Left': 0.05414443090558052,
#      'Top': 0.2095598429441452},
#     'Polygon': [{'X': 0.05414443090558052, 'Y': 0.20975463092327118},
#      {'X': 0.3505380153656006, 'Y': 0.2095598429441452},
#      {'X': 0.350567102432251, 'Y': 0.2295002043247223},
#      {'X': 0.05415904521942139, 'Y': 0.22969959676265717}]},
#    'Id': '920735ad-ba03-4085-9412-39beb7aaa260',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e41c1bd5-a91a-49d9-8491-e295e0708ee3',
#       '50e69ecc-c360-4b12-94e2-052ec901fcf5',
#       'fb0b20a8-0d28-4f75-8a9c-31789701dbbb',
#       '4ef9079e-4e60-44f2-97c8-fe6b129af220']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.81645965576172,
#    'Text': 'Check here if you, or your',
#    'Geometry': {'BoundingBox': {'Width': 0.14533831179141998,
#      'Height': 0.009918563067913055,
#      'Left': 0.769861102104187,
#      'Top': 0.2138797491788864},
#     'Polygon': [{'X': 0.769861102104187, 'Y': 0.21397577226161957},
#      {'X': 0.9151714444160461, 'Y': 0.2138797491788864},
#      {'X': 0.9151993989944458, 'Y': 0.22370116412639618},
#      {'X': 0.7698855400085449, 'Y': 0.22379830479621887}]},
#    'Id': '9bca8be4-fa50-4469-9443-c996c3065626',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8e2fcde2-d8cb-4a8b-be29-cd8ef04b7674',
#       'b8a9f043-aefc-4957-ae33-6367194b898e',
#       'e84d2d3c-094f-4a15-9cf3-e43084dc35c2',
#       'a2f88a12-677f-4510-b771-2411afd5d54b',
#       '16f0e1c2-f4e0-4f64-b170-04cbcf8422d4',
#       'b64fb94a-305b-4d34-96f6-90226eaa1e3e']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.8166732788086,
#    'Text': 'City, town, or post office. If you have a foreign address, also complete spaces below.',
#    'Geometry': {'BoundingBox': {'Width': 0.4424145519733429,
#      'Height': 0.010010907426476479,
#      'Left': 0.05223272740840912,
#      'Top': 0.23126471042633057},
#     'Polygon': [{'X': 0.05223272740840912, 'Y': 0.23156295716762543},
#      {'X': 0.4946296811103821, 'Y': 0.23126471042633057},
#      {'X': 0.4946472644805908, 'Y': 0.2409740537405014},
#      {'X': 0.0522397980093956, 'Y': 0.2412756234407425}]},
#    'Id': '189e1166-f201-4f3c-8e30-46aa79569405',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f171de6d-664c-4ac9-b910-c51f170575c8',
#       'e7feec34-2428-4d6f-835a-5f0b60aaecde',
#       'f260f671-d75a-46e7-a71a-68d9a70411cc',
#       '9830ffa7-a9eb-49d4-9170-db875d19fbb5',
#       'a7c3bc09-5641-4cd3-ac4f-4a7796532874',
#       'c74665be-7822-4cd6-a565-924a04c888b4',
#       '463ba0db-67d5-4224-82f6-0bb0194189cc',
#       '3ffb1e6e-2713-48f6-8856-82c1dd3fb7e0',
#       '563c36b4-5a48-443f-95b1-3810b47b8a0c',
#       '9bfcdec1-5371-4287-9b52-6cbebb5966b0',
#       'd449768f-58e9-4d5a-96f5-7f54453f18ba',
#       '049121d4-49ad-4eb4-852e-6fb45b91a5dc',
#       '86f16b1e-5e96-44c1-925e-f69695df3b3d',
#       'a336b9b6-4067-4085-a554-79f012078f89',
#       '71a9559e-8004-4bf2-bfc9-d718dd884052']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.95453643798828,
#    'Text': 'State',
#    'Geometry': {'BoundingBox': {'Width': 0.0282313022762537,
#      'Height': 0.007693926803767681,
#      'Left': 0.5540422201156616,
#      'Top': 0.23141439259052277},
#     'Polygon': [{'X': 0.5540422201156616, 'Y': 0.23143340647220612},
#      {'X': 0.5822579860687256, 'Y': 0.23141439259052277},
#      {'X': 0.582273542881012, 'Y': 0.23908911645412445},
#      {'X': 0.554057240486145, 'Y': 0.23910830914974213}]},
#    'Id': 'a6b722f3-3586-4b6a-b6fe-f2434d4336ec',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['6fa75bb9-39aa-4043-8874-821373dae27e']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.91280364990234,
#    'Text': 'ZIP code',
#    'Geometry': {'BoundingBox': {'Width': 0.047762226313352585,
#      'Height': 0.007864100858569145,
#      'Left': 0.6615864038467407,
#      'Top': 0.23083139955997467},
#     'Polygon': [{'X': 0.6615864038467407, 'Y': 0.2308635711669922},
#      {'X': 0.7093302607536316, 'Y': 0.23083139955997467},
#      {'X': 0.7093486189842224, 'Y': 0.23866303265094757},
#      {'X': 0.6616038084030151, 'Y': 0.23869550228118896}]},
#    'Id': 'd15b17f4-9abc-4874-b4f6-c2e15ab31b66',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['28ca4d2d-316f-4461-bb0e-07cb719e1c21',
#       '3cfcf103-8653-4bd0-9098-9756d8a8522c']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.7634506225586,
#    'Text': 'spouse if filing jointly, want $3',
#    'Geometry': {'BoundingBox': {'Width': 0.16893573105335236,
#      'Height': 0.010752672329545021,
#      'Left': 0.7700309753417969,
#      'Top': 0.2246003895998001},
#     'Polygon': [{'X': 0.7700309753417969, 'Y': 0.22471341490745544},
#      {'X': 0.9389358162879944, 'Y': 0.2246003895998001},
#      {'X': 0.938966691493988, 'Y': 0.23523862659931183},
#      {'X': 0.7700574398040771, 'Y': 0.23535306751728058}]},
#    'Id': 'be8ffab6-32aa-4834-872e-4558ab3c5a61',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['190f35cc-12ca-40eb-b08c-ea1438bac17e',
#       'fdc4de08-0fa0-46a6-8c3d-fab6f3c6b77f',
#       '4d886c9c-ae15-4edf-a2da-3db6e385c189',
#       '76e525cb-f711-4f52-b42a-75adf4114fe9',
#       'cdab670b-cb5f-446d-9455-542ae5e2f584',
#       '796e8231-44f3-47c0-92de-4d9476aee69b']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.21516418457031,
#    'Text': 'GLENDALE',
#    'Geometry': {'BoundingBox': {'Width': 0.15614624321460724,
#      'Height': 0.0177655927836895,
#      'Left': 0.05166378617286682,
#      'Top': 0.2417314499616623},
#     'Polygon': [{'X': 0.05166378617286682, 'Y': 0.24183794856071472},
#      {'X': 0.20779043436050415, 'Y': 0.2417314499616623},
#      {'X': 0.20781002938747406, 'Y': 0.25938841700553894},
#      {'X': 0.051676616072654724, 'Y': 0.2594970464706421}]},
#    'Id': 'a8b0fde2-800b-461d-aa3c-e6f350a16fce',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8a75181f-6f55-41f2-8ece-fd0e41aeab42']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 90.44326782226562,
#    'Text': 'A2',
#    'Geometry': {'BoundingBox': {'Width': 0.03916167840361595,
# ...
#     'Polygon': [{'X': 0.26509442925453186, 'Y': 0.38649386167526245},
#      {'X': 0.4305102527141571, 'Y': 0.3863624632358551},
#      {'X': 0.4305356442928314, 'Y': 0.4017072916030884},
#      {'X': 0.26511359214782715, 'Y': 0.4018406569957733}]},
#    'Id': '3a585e9b-9510-43c7-9feb-0460e72f87f8',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b5d015e7-4bb8-40fe-9e22-4c607bf28680',
#       '471fd9fe-2668-4ec5-a998-f2f419a28f75']}],
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 94.873046875,
#    'RowIndex': 2,
#    'ColumnIndex': 3,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.04380648955702782,
#      'Height': 0.01537959836423397,
#      'Left': 0.4305102527141571,
#      'Top': 0.38632768392562866},
#     'Polygon': [{'X': 0.4305102527141571, 'Y': 0.3863624632358551},
#      {'X': 0.4742897152900696, 'Y': 0.38632768392562866},
#      {'X': 0.4743167459964752, 'Y': 0.40167200565338135},
#      {'X': 0.4305356442928314, 'Y': 0.4017072916030884}]},
#    'Id': '824c0b65-65b6-4301-ba0a-d6e5c1dd151c',
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 94.873046875,
#    'RowIndex': 2,
#    'ColumnIndex': 4,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.0305393785238266,
#      'Height': 0.015368537046015263,
#      'Left': 0.4742897152900696,
#      'Top': 0.38630345463752747},
#     'Polygon': [{'X': 0.4742897152900696, 'Y': 0.38632768392562866},
#      {'X': 0.5048009157180786, 'Y': 0.38630345463752747},
#      {'X': 0.5048291087150574, 'Y': 0.4016473889350891},
#      {'X': 0.4743167459964752, 'Y': 0.40167200565338135}]},
#    'Id': 'e6e258d1-ea69-4fd1-a108-5d4c71812a40',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['2d5df2a8-4be3-43ce-b8dc-cea4a5fc3421']}],
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 94.873046875,
#    'RowIndex': 2,
#    'ColumnIndex': 5,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.06768082827329636,
#      'Height': 0.015397673472762108,
#      'Left': 0.5048009157180786,
#      'Top': 0.38624972105026245},
#     'Polygon': [{'X': 0.5048009157180786, 'Y': 0.38630345463752747},
#      {'X': 0.5724509954452515, 'Y': 0.38624972105026245},
#      {'X': 0.5724817514419556, 'Y': 0.40159285068511963},
#      {'X': 0.5048291087150574, 'Y': 0.4016473889350891}]},
#    'Id': '58cecdf7-a384-41bd-a38b-a168d833d63a',
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 96.19140625,
#    'RowIndex': 2,
#    'ColumnIndex': 6,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.10746445506811142,
#      'Height': 0.01542846579104662,
#      'Left': 0.5724509954452515,
#      'Top': 0.3861643970012665},
#     'Polygon': [{'X': 0.5724509954452515, 'Y': 0.38624972105026245},
#      {'X': 0.679880678653717, 'Y': 0.3861643970012665},
#      {'X': 0.6799154281616211, 'Y': 0.401506245136261},
#      {'X': 0.5724817514419556, 'Y': 0.40159285068511963}]},
#    'Id': 'a903ed93-ecb8-46f1-ba15-2a3fbdd2849b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a8561035-fffe-4c47-acad-248905009069',
#       '6a8b09f2-b064-4b3e-b207-f8cc473621d1']}],
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 70.751953125,
#    'RowIndex': 2,
#    'ColumnIndex': 7,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13264431059360504,
#      'Height': 0.015447182580828667,
#      'Left': 0.679880678653717,
#      'Top': 0.386059045791626},
#     'Polygon': [{'X': 0.679880678653717, 'Y': 0.3861643970012665},
#      {'X': 0.8124852180480957, 'Y': 0.386059045791626},
#      {'X': 0.8125249743461609, 'Y': 0.40139931440353394},
#      {'X': 0.6799154281616211, 'Y': 0.401506245136261}]},
#    'Id': '7d4f3878-bb5b-4a5a-90f9-2f068226c9ab',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['80523cf6-a377-4b18-934c-d504ccd3a6e0',
#       'd8f4dd06-b869-4c91-bd6a-0b623501d33f',
#       '745d79e9-4e51-40b0-8d51-8c3e4046f47a']}],
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 68.994140625,
#    'RowIndex': 2,
#    'ColumnIndex': 8,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13661450147628784,
#      'Height': 0.015448749996721745,
#      'Left': 0.8124852180480957,
#      'Top': 0.38595056533813477},
#     'Polygon': [{'X': 0.8124852180480957, 'Y': 0.386059045791626},
#      {'X': 0.9490548372268677, 'Y': 0.38595056533813477},
#      {'X': 0.9490997195243835, 'Y': 0.4012891948223114},
#      {'X': 0.8125249743461609, 'Y': 0.40139931440353394}]},
#    'Id': '8e28599e-a582-4c93-95a2-e45075fbf616',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e4094993-e410-4378-9c8e-76f4d287f3f4',
#       'a6104bbe-0b74-4f1d-a7c7-ee0ac649adfb',
#       '677c9755-8f99-45f8-ba75-46d8e3d1e44d',
#       '861fb666-1a0b-4f80-9c6b-988f1a442b26']}],
#    'EntityTypes': ['COLUMN_HEADER']},
#   {'BlockType': 'CELL',
#    'Confidence': 87.59765625,
#    'RowIndex': 3,
#    'ColumnIndex': 1,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.1235465556383133,
#      'Height': 0.01511532161384821,
#      'Left': 0.1415857970714569,
#      'Top': 0.4018406569957733},
#     'Polygon': [{'X': 0.1415857970714569, 'Y': 0.401940256357193},
#      {'X': 0.26511359214782715, 'Y': 0.4018406569957733},
#      {'X': 0.265132337808609, 'Y': 0.41685494780540466},
#      {'X': 0.14160001277923584, 'Y': 0.41695597767829895}]},
#    'Id': '485ed0f0-31c8-480f-9f81-ab7c6c104272',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['00e1b4f5-8612-4994-aea1-f252d217b0fb']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 88.134765625,
#    'RowIndex': 3,
#    'ColumnIndex': 2,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.1654469072818756,
#      'Height': 0.015147657133638859,
#      'Left': 0.26511359214782715,
#      'Top': 0.4017072916030884},
#     'Polygon': [{'X': 0.26511359214782715, 'Y': 0.4018406569957733},
#      {'X': 0.4305356442928314, 'Y': 0.4017072916030884},
#      {'X': 0.43056049942970276, 'Y': 0.4167196452617645},
#      {'X': 0.265132337808609, 'Y': 0.41685494780540466}]},
#    'Id': 'bb176c5b-35fc-41af-9419-0e35731b21ca',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['9eec02cb-70a8-42a9-b9bd-98be0da3b909']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 77.783203125,
#    'RowIndex': 3,
#    'ColumnIndex': 3,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.04380754753947258,
#      'Height': 0.015047654509544373,
#      'Left': 0.4305356442928314,
#      'Top': 0.40167200565338135},
#     'Polygon': [{'X': 0.4305356442928314, 'Y': 0.4017072916030884},
#      {'X': 0.4743167459964752, 'Y': 0.40167200565338135},
#      {'X': 0.4743432104587555, 'Y': 0.4166838526725769},
#      {'X': 0.43056049942970276, 'Y': 0.4167196452617645}]},
#    'Id': '8cb8234d-7a8c-4c99-90ac-3bba7a9a8b01'},
#   {'BlockType': 'CELL',
#    'Confidence': 78.3203125,
#    'RowIndex': 3,
#    'ColumnIndex': 4,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.030539914965629578,
#      'Height': 0.015036446042358875,
#      'Left': 0.4743167459964752,
#      'Top': 0.4016473889350891},
#     'Polygon': [{'X': 0.4743167459964752, 'Y': 0.40167200565338135},
#      {'X': 0.5048291087150574, 'Y': 0.4016473889350891},
#      {'X': 0.5048566460609436, 'Y': 0.416658878326416},
#      {'X': 0.4743432104587555, 'Y': 0.4166838526725769}]},
#    'Id': 'fef9ec03-b76a-495b-a6e2-93692fbc1a11',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['59e28478-43df-4d55-aff7-136dc5818e58']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 85.9375,
#    'RowIndex': 3,
#    'ColumnIndex': 5,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.06768270581960678,
#      'Height': 0.015066034160554409,
#      'Left': 0.5048291087150574,
#      'Top': 0.40159285068511963},
#     'Polygon': [{'X': 0.5048291087150574, 'Y': 0.4016473889350891},
#      {'X': 0.5724817514419556, 'Y': 0.40159285068511963},
#      {'X': 0.5725117921829224, 'Y': 0.41660353541374207},
#      {'X': 0.5048566460609436, 'Y': 0.416658878326416}]},
#    'Id': '8d61f050-6a0c-41ed-9a4f-f149d60477c5'},
#   {'BlockType': 'CELL',
#    'Confidence': 89.94140625,
#    'RowIndex': 3,
#    'ColumnIndex': 6,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.10746774077415466,
#      'Height': 0.015097318217158318,
#      'Left': 0.5724817514419556,
#      'Top': 0.401506245136261},
#     'Polygon': [{'X': 0.5724817514419556, 'Y': 0.40159285068511963},
#      {'X': 0.6799154281616211, 'Y': 0.401506245136261},
#      {'X': 0.6799494624137878, 'Y': 0.41651567816734314},
#      {'X': 0.5725117921829224, 'Y': 0.41660353541374207}]},
#    'Id': 'c535787a-316c-40fd-bf47-50bc4b57eee0',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['32a05199-0554-40ae-9a22-feb86481bf1e']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 87.98828125,
#    'RowIndex': 3,
#    'ColumnIndex': 7,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13264843821525574,
#      'Height': 0.015116361901164055,
#      'Left': 0.6799154281616211,
#      'Top': 0.40139931440353394},
#     'Polygon': [{'X': 0.6799154281616211, 'Y': 0.401506245136261},
#      {'X': 0.8125249743461609, 'Y': 0.40139931440353394},
#      {'X': 0.8125638961791992, 'Y': 0.4164072275161743},
#      {'X': 0.6799494624137878, 'Y': 0.41651567816734314}]},
#    'Id': 'e6ab6de4-21c2-468a-bd15-740aea19e79e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['dc49ec5b-6cf2-44fd-ad9c-9c437f782248']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 85.791015625,
#    'RowIndex': 3,
#    'ColumnIndex': 8,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13661865890026093,
#      'Height': 0.015118011273443699,
#      'Left': 0.8125249743461609,
#      'Top': 0.4012891948223114},
#     'Polygon': [{'X': 0.8125249743461609, 'Y': 0.40139931440353394},
#      {'X': 0.9490997195243835, 'Y': 0.4012891948223114},
#      {'X': 0.949143648147583, 'Y': 0.41629549860954285},
#      {'X': 0.8125638961791992, 'Y': 0.4164072275161743}]},
#    'Id': '1ba230e9-97dd-4ba3-91b2-bfc9df6238ac',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5eea800e-3bf0-49cf-ab1b-5e42a1b94483']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 88.4765625,
#    'RowIndex': 4,
#    'ColumnIndex': 1,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.12355110049247742,
#      'Height': 0.015117868781089783,
#      'Left': 0.14160001277923584,
#      'Top': 0.41685494780540466},
#     'Polygon': [{'X': 0.14160001277923584, 'Y': 0.41695597767829895},
#      {'X': 0.265132337808609, 'Y': 0.41685494780540466},
#      {'X': 0.26515111327171326, 'Y': 0.43187034130096436},
#      {'X': 0.14161422848701477, 'Y': 0.43197283148765564}]},
#    'Id': '60d817a0-86f0-4049-a4e3-24e3f2b39528',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d4d77a34-bb42-477e-80f9-7c474a548f21']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 89.013671875,
#    'RowIndex': 4,
#    'ColumnIndex': 2,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.1654530018568039,
#      'Height': 0.01515069231390953,
#      'Left': 0.265132337808609,
#      'Top': 0.4167196452617645},
#     'Polygon': [{'X': 0.265132337808609, 'Y': 0.41685494780540466},
#      {'X': 0.43056049942970276, 'Y': 0.4167196452617645},
#      {'X': 0.4305853545665741, 'Y': 0.431733101606369},
#      {'X': 0.26515111327171326, 'Y': 0.43187034130096436}]},
#    'Id': 'a047ac7c-53e9-4a0e-b50e-d9eeb6017483',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['3a788056-4b94-45aa-be42-919c68387abd']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 78.564453125,
#    'RowIndex': 4,
#    'ColumnIndex': 3,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.043809160590171814,
#      'Height': 0.01504927035421133,
#      'Left': 0.43056049942970276,
#      'Top': 0.4166838526725769},
#     'Polygon': [{'X': 0.43056049942970276, 'Y': 0.4167196452617645},
#      {'X': 0.4743432104587555, 'Y': 0.4166838526725769},
#      {'X': 0.47436967492103577, 'Y': 0.4316968023777008},
#      {'X': 0.4305853545665741, 'Y': 0.431733101606369}]},
#    'Id': '23db512c-cc06-466d-8aad-4bf531e8b62a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ae011065-fa07-499e-b4f8-87240a25a89f']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 79.1015625,
#    'RowIndex': 4,
#    'ColumnIndex': 4,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.030541040003299713,
#      'Height': 0.015037906356155872,
#      'Left': 0.4743432104587555,
#      'Top': 0.416658878326416},
#     'Polygon': [{'X': 0.4743432104587555, 'Y': 0.4166838526725769},
#      {'X': 0.5048566460609436, 'Y': 0.416658878326416},
#      {'X': 0.5048842430114746, 'Y': 0.43167147040367126},
#      {'X': 0.47436967492103577, 'Y': 0.4316968023777008}]},
#    'Id': '77010be3-e83e-4ce2-8853-3c1d9d992dfc',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['111efc57-68bb-4afc-b74e-a578ece18a6f']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 86.81640625,
#    'RowIndex': 4,
#    'ColumnIndex': 5,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.06768519431352615,
#      'Height': 0.015067928470671177,
#      'Left': 0.5048566460609436,
#      'Top': 0.41660353541374207},
#     'Polygon': [{'X': 0.5048566460609436, 'Y': 0.416658878326416},
#      {'X': 0.5725117921829224, 'Y': 0.41660353541374207},
#      {'X': 0.5725418329238892, 'Y': 0.43161535263061523},
#      {'X': 0.5048842430114746, 'Y': 0.43167147040367126}]},
#    'Id': 'fe8be95f-7756-4e8c-b187-0abbe72de8b1',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d71351e8-fa39-434a-bb8d-223753f7bb4f']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 90.869140625,
#    'RowIndex': 4,
#    'ColumnIndex': 6,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.10747169703245163,
#      'Height': 0.015099676325917244,
#      'Left': 0.5725117921829224,
#      'Top': 0.41651567816734314},
#     'Polygon': [{'X': 0.5725117921829224, 'Y': 0.41660353541374207},
#      {'X': 0.6799494624137878, 'Y': 0.41651567816734314},
#      {'X': 0.6799834966659546, 'Y': 0.43152621388435364},
#      {'X': 0.5725418329238892, 'Y': 0.43161535263061523}]},
#    'Id': 'e865f096-62f2-44b8-bc44-692e0cb61c56',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e9b15cfd-e89d-4ea9-bd05-a23676d92e9d']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 88.8671875,
#    'RowIndex': 4,
#    'ColumnIndex': 7,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13265331089496613,
#      'Height': 0.01511901430785656,
#      'Left': 0.6799494624137878,
#      'Top': 0.4164072275161743},
#     'Polygon': [{'X': 0.6799494624137878, 'Y': 0.41651567816734314},
#      {'X': 0.8125638961791992, 'Y': 0.4164072275161743},
#      {'X': 0.8126027584075928, 'Y': 0.43141621351242065},
#      {'X': 0.6799834966659546, 'Y': 0.43152621388435364}]},
#    'Id': '8d850495-6b47-44dd-b1a4-5ff58011018e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['c826b4ce-e868-45f2-a6c2-a11f936609fc']}]},
#   {'BlockType': 'CELL',
#    'Confidence': 86.669921875,
#    'RowIndex': 4,
#    'ColumnIndex': 8,
#    'RowSpan': 1,
#    'ColumnSpan': 1,
#    'Geometry': {'BoundingBox': {'Width': 0.13662368059158325,
#      'Height': 0.01512070931494236,
#      'Left': 0.8125638961791992,
#      'Top': 0.41629549860954285},
#     'Polygon': [{'X': 0.8125638961791992, 'Y': 0.4164072275161743},
#      {'X': 0.949143648147583, 'Y': 0.41629549860954285},
#      {'X': 0.9491875767707825, 'Y': 0.43130290508270264},
#      {'X': 0.8126027584075928, 'Y': 0.43141621351242065}]},
#    'Id': '38cf181a-e27e-41a5-8917-27e2583a0f6e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['2a106f76-489d-4fee-bbfa-d0aa718f2083']}]},
#   ...],
#  'AnalyzeDocumentModelVersion': '1.0',
#  'ResponseMetadata': {'RequestId': 'd5fd0dc9-032c-4bc1-a797-8d593c219b7d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd5fd0dc9-032c-4bc1-a797-8d593c219b7d',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '815509',
#    'date': 'Mon, 18 Sep 2023 18:40:31 GMT'},
#   'RetryAttempts': 0}}

# %%
from trp import Document

# Parse JSON response from Textract
doc = Document(response)

# Iterate over elements in the document
for page in doc.pages:
    # Print lines and words
    for line in page.lines:
        print("Line: {}".format(line.text))
        for word in line.words:
            print("Word: {}".format(word.text))

    # Print tables
    for table in page.tables:
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}".format(r, c, cell.text))

    # Print fields
    for field in page.form.fields:
        key_text = field.key.text if field.key else "N/A"
        value_text = field.value.text if field.value else "N/A"
        print("Field: Key: {}, Value: {}".format(key_text, value_text))
# Out:
# Line: 1040
# Word: 1040
# Line: Department of the Treasury - Internal Revenue Service
# Word: Department
# Word: of
# Word: the
# Word: Treasury
# Word: -
# Word: Internal
# Word: Revenue
# Word: Service
# Line: U.S. Individual Income Tax Return
# Word: U.S.
# Word: Individual
# Word: Income
# Word: Tax
# Word: Return
# Line: 2022
# Word: 2022
# Line: OMB No. 1545-0074
# Word: OMB
# Word: No.
# Word: 1545-0074
# Line: IRS Use Only-Do not write or staple in this space.
# Word: IRS
# Word: Use
# Word: Only-Do
# Word: not
# Word: write
# Word: or
# Word: staple
# Word: in
# Word: this
# Word: space.
# Line: Filing Status
# Word: Filing
# Word: Status
# Line: Single
# Word: Single
# Line: Married filing jointly
# Word: Married
# Word: filing
# Word: jointly
# Line: Married filing separately (MFS)
# Word: Married
# Word: filing
# Word: separately
# Word: (MFS)
# Line: Head of household (HOH)
# Word: Head
# Word: of
# Word: household
# Word: (HOH)
# Line: Qualifying surviving
# Word: Qualifying
# Word: surviving
# Line: Check only
# Word: Check
# Word: only
# Line: spouse (QSS)
# Word: spouse
# Word: (QSS)
# Line: one box.
# Word: one
# Word: box.
# Line: If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child's name if the qualifying
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: MFS
# Word: box,
# Word: enter
# Word: the
# Word: name
# Word: of
# Word: your
# Word: spouse.
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: HOH
# Word: or
# Word: QSS
# Word: box,
# Word: enter
# Word: the
# Word: child's
# Word: name
# Word: if
# Word: the
# Word: qualifying
# Line: person is a child but not your dependent:
# Word: person
# Word: is
# Word: a
# Word: child
# Word: but
# Word: not
# Word: your
# Word: dependent:
# Line: Your first name and middle initial
# Word: Your
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Your social security number
# Word: Your
# Word: social
# Word: security
# Word: number
# Line: JOHN J
# Word: JOHN
# Word: J
# Line: SMITH
# Word: SMITH
# Line: 123 45 6789
# Word: 123 45 6789
# Line: If joint return, spouse's first name and middle initial
# Word: If
# Word: joint
# Word: return,
# Word: spouse's
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Spouse's social security number
# Word: Spouse's
# Word: social
# Word: security
# Word: number
# Line: JANE K
# Word: JANE
# Word: K
# Line: SMITH
# Word: SMITH
# Line: 9871654321
# Word: 9871654321
# Line: Home address (number and street). If you have a P.O. box, see instructions.
# Word: Home
# Word: address
# Word: (number
# Word: and
# Word: street).
# Word: If
# Word: you
# Word: have
# Word: a
# Word: P.O.
# Word: box,
# Word: see
# Word: instructions.
# Line: Apt. no.
# Word: Apt.
# Word: no.
# Line: Presidential Election Campaign
# Word: Presidential
# Word: Election
# Word: Campaign
# Line: 1040 N PHOENIX RD
# Word: 1040
# Word: N
# Word: PHOENIX
# Word: RD
# Line: Check here if you, or your
# Word: Check
# Word: here
# Word: if
# Word: you,
# Word: or
# Word: your
# Line: City, town, or post office. If you have a foreign address, also complete spaces below.
# Word: City,
# Word: town,
# Word: or
# Word: post
# Word: office.
# Word: If
# Word: you
# Word: have
# Word: a
# Word: foreign
# Word: address,
# Word: also
# Word: complete
# Word: spaces
# Word: below.
# Line: State
# Word: State
# Line: ZIP code
# Word: ZIP
# Word: code
# Line: spouse if filing jointly, want $3
# Word: spouse
# Word: if
# Word: filing
# Word: jointly,
# Word: want
# Word: $3
# Line: GLENDALE
# Word: GLENDALE
# Line: A2
# Word: A2
# Line: 85308
# Word: 85308
# Line: to go to this fund. Checking a
# Word: to
# Word: go
# Word: to
# Word: this
# Word: fund.
# Word: Checking
# Word: a
# Line: box below will not change
# Word: box
# Word: below
# Word: will
# Word: not
# Word: change
# Line: Foreign country name
# Word: Foreign
# Word: country
# Word: name
# Line: Foreign province/state/county
# Word: Foreign
# Word: province/state/county
# Line: Foreign postal code
# Word: Foreign
# Word: postal
# Word: code
# Line: your tax or refund.
# Word: your
# Word: tax
# Word: or
# Word: refund.
# Line: You
# Word: You
# Line: Spouse
# Word: Spouse
# Line: Digital
# Word: Digital
# Line: At any time during 2022, did you: (a) receive (as a reward, award, or payment for property or services); or (b) sell,
# Word: At
# Word: any
# Word: time
# Word: during
# Word: 2022,
# Word: did
# Word: you:
# Word: (a)
# Word: receive
# Word: (as
# Word: a
# Word: reward,
# Word: award,
# Word: or
# Word: payment
# Word: for
# Word: property
# Word: or
# Word: services);
# Word: or
# Word: (b)
# Word: sell,
# Line: Assets
# Word: Assets
# Line: exchange, gift, or otherwise dispose of a digital asset (or a financial interest in a digital asset)? (See instructions.)
# Word: exchange,
# Word: gift,
# Word: or
# Word: otherwise
# Word: dispose
# Word: of
# Word: a
# Word: digital
# Word: asset
# Word: (or
# Word: a
# Word: financial
# Word: interest
# Word: in
# Word: a
# Word: digital
# Word: asset)?
# Word: (See
# Word: instructions.)
# Line: Yes
# Word: Yes
# Line: No
# Word: No
# Line: Standard
# Word: Standard
# Line: Someone can claim:
# Word: Someone
# Word: can
# Word: claim:
# Line: You as a dependent
# Word: You
# Word: as
# Word: a
# Word: dependent
# Line: Your spouse as a dependent
# Word: Your
# Word: spouse
# Word: as
# Word: a
# Word: dependent
# Line: Deduction
# Word: Deduction
# Line: Spouse itemizes on a separate return or you were a dual-status alien
# Word: Spouse
# Word: itemizes
# Word: on
# Word: a
# Word: separate
# Word: return
# Word: or
# Word: you
# Word: were
# Word: a
# Word: dual-status
# Word: alien
# Line: Age/Blindness You:
# Word: Age/Blindness
# Word: You:
# Line: Were born before January 2, 1958
# Word: Were
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Are blind
# Word: Are
# Word: blind
# Line: Spouse:
# Word: Spouse:
# Line: Was born before January 2, 1958
# Word: Was
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Is blind
# Word: Is
# Word: blind
# Line: Dependents (see instructions):
# Word: Dependents
# Word: (see
# Word: instructions):
# Line: (2) Social security
# Word: (2)
# Word: Social
# Word: security
# Line: (3) Relationship
# Word: (3)
# Word: Relationship
# Line: (4) Check the box if qualifies for (see instructions):
# Word: (4)
# Word: Check
# Word: the
# Word: box
# Word: if
# Word: qualifies
# Word: for
# Word: (see
# Word: instructions):
# Line: If more
# Word: If
# Word: more
# Line: (1) First name
# Word: (1)
# Word: First
# Word: name
# Line: Last name
# Word: Last
# Word: name
# Line: number
# Word: number
# Line: to you
# Word: to
# Word: you
# Line: Child tax credit
# Word: Child
# Word: tax
# Word: credit
# Line: Credit for other dependents
# Word: Credit
# Word: for
# Word: other
# Word: dependents
# Line: than four
# Word: than
# Word: four
# Line: JAY
# Word: JAY
# Line: SMITH
# Word: SMITH
# Line: 135792468
# Word: 135792468
# Line: SON
# Word: SON
# Line: dependents,
# Word: dependents,
# Line: see instructions
# Word: see
# Word: instructions
# Line: VICTORIA
# Word: VICTORIA
# Line: SMITH
# Word: SMITH
# Line: 246
# Word: 246
# Line: 81
# Word: 81
# Line: 3579
# Word: 3579
# Line: DAUGHTER
# Word: DAUGHTER
# Line: and check
# Word: and
# Word: check
# Line: here
# Word: here
# Line: Income
# Word: Income
# Line: 1a Total amount from Form(s) W-2, box 1 (see instructions)
# Word: 1a
# Word: Total
# Word: amount
# Word: from
# Word: Form(s)
# Word: W-2,
# Word: box
# Word: 1
# Word: (see
# Word: instructions)
# Line: 1a
# Word: 1a
# Line: 100,000
# Word: 100,000
# Line: b Household employee wages not reported on Form(s) W-2
# Word: b
# Word: Household
# Word: employee
# Word: wages
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Line: 1b
# Word: 1b
# Line: Attach Form(s)
# Word: Attach
# Word: Form(s)
# Line: c Tip income not reported on line 1a (see instructions)
# Word: c
# Word: Tip
# Word: income
# Word: not
# Word: reported
# Word: on
# Word: line
# Word: 1a
# Word: (see
# Word: instructions)
# Line: 1c
# Word: 1c
# Line: W-2 here. Also
# Word: W-2
# Word: here.
# Word: Also
# Line: attach Forms
# Word: attach
# Word: Forms
# Line: d Medicaid waiver payments not reported on Form(s) W-2 (see instructions)
# Word: d
# Word: Medicaid
# Word: waiver
# Word: payments
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Word: (see
# Word: instructions)
# Line: 1d
# Word: 1d
# Line: W-2G and
# Word: W-2G
# Word: and
# Line: e Taxable dependent care benefits from Form 2441, line 26
# Word: e
# Word: Taxable
# Word: dependent
# Word: care
# Word: benefits
# Word: from
# Word: Form
# Word: 2441,
# Word: line
# Word: 26
# Line: 1e
# Word: 1e
# Line: 1099-R if tax
# Word: 1099-R
# Word: if
# Word: tax
# Line: 5,000
# Word: 5,000
# Line: was withheld.
# Word: was
# Word: withheld.
# Line: f Employer-provided adoption benefits from Form 8839, line 29
# Word: f
# Word: Employer-provided
# Word: adoption
# Word: benefits
# Word: from
# Word: Form
# Word: 8839,
# Word: line
# Word: 29
# Line: 1f
# Word: 1f
# Line: If you did not
# Word: If
# Word: you
# Word: did
# Word: not
# Line: g Wages from Form 8919, line 6
# Word: g
# Word: Wages
# Word: from
# Word: Form
# Word: 8919,
# Word: line
# Word: 6
# Line: 1g
# Word: 1g
# Line: apia
# Word: apia
# Line: get a Form
# Word: get
# Word: a
# Word: Form
# Line: h Other earned income (see instructions)
# Word: h
# Word: Other
# Word: earned
# Word: income
# Word: (see
# Word: instructions)
# Line: 1h
# Word: 1h
# Line: W-2, see
# Word: W-2,
# Word: see
# Line: i
# Word: i
# Line: instructions.
# Word: instructions.
# Line: Nontaxable combat pay election (see instructions)
# Word: Nontaxable
# Word: combat
# Word: pay
# Word: election
# Word: (see
# Word: instructions)
# Line: 1i
# Word: 1i
# Line: z Add lines 1a through 1h
# Word: z
# Word: Add
# Word: lines
# Word: 1a
# Word: through
# Word: 1h
# Line: 1z
# Word: 1z
# Line: 105,000
# Word: 105,000
# Line: Attach Sch. B
# Word: Attach
# Word: Sch.
# Word: B
# Line: 2a
# Word: 2a
# Line: Tax-exempt interest
# Word: Tax-exempt
# Word: interest
# Line: 2a
# Word: 2a
# Line: b Taxable interest
# Word: b
# Word: Taxable
# Word: interest
# Line: 2b
# Word: 2b
# Line: 6,000
# Word: 6,000
# Line: if required.
# Word: if
# Word: required.
# Line: 3a
# Word: 3a
# Line: Qualified dividends
# Word: Qualified
# Word: dividends
# Line: 3a
# Word: 3a
# Line: b Ordinary dividends
# Word: b
# Word: Ordinary
# Word: dividends
# Line: 3b
# Word: 3b
# Line: 4a IRA distributions
# Word: 4a
# Word: IRA
# Word: distributions
# Line: 4a
# Word: 4a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 4b
# Word: 4b
# Line: Standard
# Word: Standard
# Line: 5a Pensions and annuities
# Word: 5a
# Word: Pensions
# Word: and
# Word: annuities
# Line: 5a
# Word: 5a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 5b
# Word: 5b
# Line: Deduction for-
# Word: Deduction
# Word: for-
# Line: 6a
# Word: 6a
# Line: Social security benefits
# Word: Social
# Word: security
# Word: benefits
# Line: 6a
# Word: 6a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 6b
# Word: 6b
# Line: Single or
# Word: Single
# Word: or
# Line: Married filing
# Word: Married
# Word: filing
# Line: c
# Word: c
# Line: If you elect to use the lump-sum election method, check here (see instructions)
# Word: If
# Word: you
# Word: elect
# Word: to
# Word: use
# Word: the
# Word: lump-sum
# Word: election
# Word: method,
# Word: check
# Word: here
# Word: (see
# Word: instructions)
# Line: separately,
# Word: separately,
# Line: $12,950
# Word: $12,950
# Line: 7
# Word: 7
# Line: Capital gaín or (loss). Attach Schedule D if required. If not required, check here
# Word: Capital
# Word: gaín
# Word: or
# Word: (loss).
# Word: Attach
# Word: Schedule
# Word: D
# Word: if
# Word: required.
# Word: If
# Word: not
# Word: required,
# Word: check
# Word: here
# Line: 7
# Word: 7
# Line: Married filing
# Word: Married
# Word: filing
# Line: 8
# Word: 8
# Line: Other income from Schedule 1, line 10
# Word: Other
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 10
# Line: 8
# Word: 8
# Line: 111,000
# Word: 111,000
# Line: jointly or
# Word: jointly
# Word: or
# Line: Qualifying
# Word: Qualifying
# Line: 9
# Word: 9
# Line: Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income
# Word: Add
# Word: lines
# Word: 1z,
# Word: 2b,
# Word: 3b,
# Word: 4b,
# Word: 5b,
# Word: 6b,
# Word: 7,
# Word: and
# Word: 8.
# Word: This
# Word: is
# Word: your
# Word: total
# Word: income
# Line: 9
# Word: 9
# Line: 7,000
# Word: 7,000
# Line: surviving spouse,
# Word: surviving
# Word: spouse,
# Line: 10
# Word: 10
# Line: $25,900
# Word: $25,900
# Line: Adjustments to income from Schedule 1, line 26
# Word: Adjustments
# Word: to
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 26
# Line: 10
# Word: 10
# Line: 104,000
# Word: 104,000
# Line: Head of
# Word: Head
# Word: of
# Line: 11
# Word: 11
# Line: Subtract line 10 from line 9. This is your adjusted gross income
# Word: Subtract
# Word: line
# Word: 10
# Word: from
# Word: line
# Word: 9.
# Word: This
# Word: is
# Word: your
# Word: adjusted
# Word: gross
# Word: income
# Line: 11
# Word: 11
# Line: household,
# Word: household,
# Line: $19,400
# Word: $19,400
# Line: 12
# Word: 12
# Line: Standard deduction or Itemized deductions (from Schedule A)
# Word: Standard
# Word: deduction
# Word: or
# Word: Itemized
# Word: deductions
# Word: (from
# Word: Schedule
# Word: A)
# Line: 12
# Word: 12
# Line: If you checked
# Word: If
# Word: you
# Word: checked
# Line: 13
# Word: 13
# Line: Qualified business income deduction from Form 8995 or Form 8995-A
# Word: Qualified
# Word: business
# Word: income
# Word: deduction
# Word: from
# Word: Form
# Word: 8995
# Word: or
# Word: Form
# Word: 8995-A
# Line: 13
# Word: 13
# Line: any box under
# Word: any
# Word: box
# Word: under
# Line: Standard
# Word: Standard
# Line: 14
# Word: 14
# Line: Add lines 12 and 13
# Word: Add
# Word: lines
# Word: 12
# Word: and
# Word: 13
# Line: 14
# Word: 14
# Line: 12,000
# Word: 12,000
# Line: Deduction,
# Word: Deduction,
# Line: 15
# Word: 15
# Line: see instructions.
# Word: see
# Word: instructions.
# Line: Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income
# Word: Subtract
# Word: line
# Word: 14
# Word: from
# Word: line
# Word: 11.
# Word: If
# Word: zero
# Word: or
# Word: less,
# Word: enter
# Word: -0-.
# Word: This
# Word: is
# Word: your
# Word: taxable
# Word: income
# Line: 15
# Word: 15
# Line: 92,000
# Word: 92,000
# Line: For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.
# Word: For
# Word: Disclosure,
# Word: Privacy
# Word: Act,
# Word: and
# Word: Paperwork
# Word: Reduction
# Word: Act
# Word: Notice,
# Word: see
# Word: separate
# Word: instructions.
# Line: Cat. No. 11320B
# Word: Cat.
# Word: No.
# Word: 11320B
# Line: Form
# Word: Form
# Line: 1040
# Word: 1040
# Line: (2022)
# Word: (2022)
# Table[0][0] = Your first name and middle initial
# Table[0][1] = Last name
# Table[1][0] = JOHN J
# Table[1][1] = SMITH
# Table[2][0] = If joint return, spouse's first name and middle initial
# Table[2][1] = Last name
# Table[3][0] = JANE K
# Table[3][1] = SMITH
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions.
# Table[0][1] = Apt. no.
# Table[1][0] = 1040 N PHOENIX RD
# Table[1][1] =
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below.
# Table[0][1] = State
# Table[0][2] = ZIP code
# Table[1][0] = GLENDALE
# Table[1][1] = A2
# Table[1][2] = 85308
# Table[0][0] = Foreign country name
# Table[0][1] = Foreign province/state/county
# Table[0][2] = Foreign postal code
# Table[1][0] =
# Table[1][1] =
# Table[1][2] =
# Table[0][0] = (see instructions):
# Table[0][1] =
# Table[0][2] = (2)
# Table[0][3] = Social
# Table[0][4] = security
# Table[0][5] = (3) Relationship
# Table[0][6] = (4) Check the box if qualifies
# Table[0][7] = for (see instructions):
# Table[1][0] = (1) First name
# Table[1][1] = Last name
# Table[1][2] =
# Table[1][3] = number
# Table[1][4] =
# Table[1][5] = to you
# Table[1][6] = Child tax credit
# Table[1][7] = Credit for other dependents
# Table[2][0] = JAY
# Table[2][1] = SMITH
# Table[2][2] =
# Table[2][3] = 135792468
# Table[2][4] =
# Table[2][5] = SON
# Table[2][6] = SELECTED,
# Table[2][7] = NOT_SELECTED,
# Table[3][0] = VICTORIA
# Table[3][1] = SMITH
# Table[3][2] = 246
# Table[3][3] = 81
# Table[3][4] = 3579
# Table[3][5] = DAUGHTER
# Table[3][6] = SELECTED,
# Table[3][7] = NOT_SELECTED,
# Table[4][0] =
# Table[4][1] =
# Table[4][2] =
# Table[4][3] =
# Table[4][4] =
# Table[4][5] =
# Table[4][6] = NOT_SELECTED,
# Table[4][7] = NOT_SELECTED,
# Table[5][0] =
# Table[5][1] =
# Table[5][2] =
# Table[5][3] =
# Table[5][4] =
# Table[5][5] =
# Table[5][6] = NOT_SELECTED,
# Table[5][7] = NOT_SELECTED,
# Table[0][0] = Income
# Table[0][1] = 1a
# Table[0][2] = Total amount from Form(s) W-2,
# Table[0][3] = box 1
# Table[0][4] = (see instructions)
# Table[0][5] =
# Table[0][6] =
# Table[0][7] =
# Table[0][8] = 1a
# Table[0][9] = 100,000
# Table[1][0] =
# Table[1][1] = b
# Table[1][2] = Household employee wages not
# Table[1][3] = reported
# Table[1][4] = on Form(s) W-2
# Table[1][5] =
# Table[1][6] =
# Table[1][7] =
# Table[1][8] = 1b
# Table[1][9] =
# Table[2][0] = Attach Form(s)
# Table[2][1] = c
# Table[2][2] = Tip income not reported on line
# Table[2][3] = 1a (see
# Table[2][4] = instructions)
# Table[2][5] =
# Table[2][6] =
# Table[2][7] =
# Table[2][8] = 1c
# Table[2][9] =
# Table[3][0] = W-2 here. Also attach Forms
# Table[3][1] = d
# Table[3][2] = Medicaid waiver payments not
# Table[3][3] = reported
# Table[3][4] = on Form(s) W-2 (see
# Table[3][5] = instructions)
# Table[3][6] =
# Table[3][7] =
# Table[3][8] = 1d
# Table[3][9] =
# Table[4][0] = W-2G and
# Table[4][1] = e
# Table[4][2] = Taxable dependent care benefits
# Table[4][3] = from
# Table[4][4] = Form 2441, line 26
# Table[4][5] =
# Table[4][6] =
# Table[4][7] =
# Table[4][8] = 1e
# Table[4][9] = 5,000
# Table[5][0] = 1099-R if tax was withheld.
# Table[5][1] = f
# Table[5][2] = Employer-provided adoption
# Table[5][3] = benefits
# Table[5][4] = from Form 8839, line
# Table[5][5] = 29
# Table[5][6] =
# Table[5][7] =
# Table[5][8] = 1f
# Table[5][9] =
# Table[6][0] = If you did not
# Table[6][1] = g
# Table[6][2] = Wages from Form 8919, line 6
# Table[6][3] =
# Table[6][4] =
# Table[6][5] =
# Table[6][6] =
# Table[6][7] =
# Table[6][8] = 1g
# Table[6][9] = apia
# Table[7][0] = get a Form
# Table[7][1] = h
# Table[7][2] = Other earned income (see
# Table[7][3] = instructions)
# Table[7][4] =
# Table[7][5] =
# Table[7][6] =
# Table[7][7] =
# Table[7][8] = 1h
# Table[7][9] =
# Table[8][0] = W-2, see instructions.
# Table[8][1] = i
# Table[8][2] = Nontaxable combat pay election
# Table[8][3] = (see
# Table[8][4] = instructions)
# Table[8][5] =
# Table[8][6] = 1i
# Table[8][7] =
# Table[8][8] =
# Table[8][9] =
# Table[9][0] =
# Table[9][1] = z
# Table[9][2] = Add lines 1a through 1h
# Table[9][3] =
# Table[9][4] =
# Table[9][5] =
# Table[9][6] =
# Table[9][7] =
# Table[9][8] = 1z
# Table[9][9] = 105,000
# Table[10][0] = Attach Sch. B
# Table[10][1] = 2a
# Table[10][2] = Tax-exempt interest
# Table[10][3] = 2a
# Table[10][4] =
# Table[10][5] = b Taxable
# Table[10][6] = interest
# Table[10][7] =
# Table[10][8] = 2b
# Table[10][9] = 6,000
# Table[11][0] = if required.
# Table[11][1] = 3a
# Table[11][2] = Qualified dividends
# Table[11][3] = 3a
# Table[11][4] =
# Table[11][5] = b Ordinary
# Table[11][6] = dividends
# Table[11][7] =
# Table[11][8] = 3b
# Table[11][9] =
# Table[12][0] =
# Table[12][1] = 4a
# Table[12][2] = IRA distributions
# Table[12][3] = 4a
# Table[12][4] =
# Table[12][5] = b Taxable
# Table[12][6] = amount
# Table[12][7] =
# Table[12][8] = 4b
# Table[12][9] =
# Table[13][0] = Standard
# Table[13][1] = 5a
# Table[13][2] = Pensions and annuities
# Table[13][3] = 5a
# Table[13][4] =
# Table[13][5] = b Taxable
# Table[13][6] = amount
# Table[13][7] =
# Table[13][8] = 5b
# Table[13][9] =
# Table[14][0] = Deduction for- Single or
# Table[14][1] = 6a
# Table[14][2] = Social security benefits
# Table[14][3] = 6a
# Table[14][4] =
# Table[14][5] = b Taxable
# Table[14][6] = amount
# Table[14][7] =
# Table[14][8] = 6b
# Table[14][9] =
# Table[15][0] = Married filing
# Table[15][1] = c
# Table[15][2] = If you elect to use the lump-sum
# Table[15][3] = election
# Table[15][4] = method, check
# Table[15][5] = here (see instructions)
# Table[15][6] =
# Table[15][7] = NOT_SELECTED,
# Table[15][8] =
# Table[15][9] =
# Table[16][0] = separately, $12,950
# Table[16][1] = 7
# Table[16][2] = Capital gaín or (loss). Attach
# Table[16][3] = Schedule
# Table[16][4] = D if required. If not
# Table[16][5] = required, check
# Table[16][6] = here
# Table[16][7] = NOT_SELECTED,
# Table[16][8] = 7
# Table[16][9] =
# Table[17][0] = Married filing
# Table[17][1] = 8
# Table[17][2] = Other income from Schedule 1,
# Table[17][3] = line 10
# Table[17][4] =
# Table[17][5] =
# Table[17][6] =
# Table[17][7] =
# Table[17][8] = 8
# Table[17][9] = 111,000
# Table[18][0] = jointly or Qualifying
# Table[18][1] = 9
# Table[18][2] = Add lines 1z, 2b, 3b, 4b, 5b, 6b,
# Table[18][3] = 7, and
# Table[18][4] = 8. This is your total
# Table[18][5] = income
# Table[18][6] =
# Table[18][7] =
# Table[18][8] = 9
# Table[18][9] = 7,000
# Table[19][0] = surviving spouse, $25,900
# Table[19][1] = 10
# Table[19][2] = Adjustments to income from
# Table[19][3] = Schedule
# Table[19][4] = 1, line 26
# Table[19][5] =
# Table[19][6] =
# Table[19][7] =
# Table[19][8] = 10
# Table[19][9] = 104,000
# Table[20][0] = Head of
# Table[20][1] = 11
# Table[20][2] = Subtract line 10 from line 9. This
# Table[20][3] = is your
# Table[20][4] = adjusted gross
# Table[20][5] = income
# Table[20][6] =
# Table[20][7] =
# Table[20][8] = 11
# Table[20][9] =
# Table[21][0] = household, $19,400
# Table[21][1] = 12
# Table[21][2] = Standard deduction or Itemized
# Table[21][3] =
# Table[21][4] = deductions (from Schedule
# Table[21][5] = A)
# Table[21][6] =
# Table[21][7] =
# Table[21][8] = 12
# Table[21][9] =
# Table[22][0] = If you checked box under
# Table[22][1] = 13
# Table[22][2] = Qualified business income deduction
# Table[22][3] =
# Table[22][4] = from Form 8995 or
# Table[22][5] = Form 8995-A
# Table[22][6] =
# Table[22][7] =
# Table[22][8] = 13
# Table[22][9] =
# Table[23][0] = any Standard
# Table[23][1] = 14
# Table[23][2] = Add lines 12 and 13
# Table[23][3] =
# Table[23][4] =
# Table[23][5] =
# Table[23][6] =
# Table[23][7] =
# Table[23][8] = 14
# Table[23][9] = 12,000
# Table[24][0] = Deduction, see instructions.
# Table[24][1] = 15
# Table[24][2] = Subtract line 14 from line 11. If
# Table[24][3] = zero or
# Table[24][4] = less, enter -0-. This
# Table[24][5] = is your taxable
# Table[24][6] = income
# Table[24][7] =
# Table[24][8] = 15
# Table[24][9] = 92,000
# Table[25][0] =
# Table[25][1] =
# Table[25][2] =
# Table[25][3] =
# Table[25][4] =
# Table[25][5] =
# Table[25][6] =
# Table[25][7] =
# Table[25][8] =
# Table[25][9] =
# Field: Key: Married filing jointly, Value: SELECTED
# Field: Key: Were born before January 2, 1958, Value: NOT_SELECTED
# Field: Key: Married filing separately (MFS), Value: NOT_SELECTED
# Field: Key: Head of household (HOH), Value: NOT_SELECTED
# Field: Key: 15 Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income 15, Value: 92,000
# Field: Key: b Taxable interest 2b, Value: 6,000
# Field: Key: Home address (number and street). If you have a P.O. box, see instructions., Value: 1040 N PHOENIX RD
# Field: Key: 1a Total amount from Form(s) W-2, box 1 (see instructions) 1a, Value: 100,000
# Field: Key: You, Value: NOT_SELECTED
# Field: Key: b Ordinary dividends 3b, Value: N/A
# Field: Key: Spouse, Value: NOT_SELECTED
# Field: Key: Last name, Value: SMITH
# Field: Key: Single, Value: NOT_SELECTED
# Field: Key: Was born before January 2, 1958, Value: NOT_SELECTED
# Field: Key: If joint return, spouse's first name and middle initial, Value: JANE K
# Field: Key: Your social security number, Value: 123 45 6789
# Field: Key: z Add lines 1a through 1h 1z, Value: 105,000
# Field: Key: Yes, Value: NOT_SELECTED
# Field: Key: b Household employee wages not reported on Form(s) W-2 1b, Value: N/A
# Field: Key: City, town, or post office. If you have a foreign address, also complete spaces below., Value: GLENDALE
# Field: Key: Last name, Value: SMITH
# Field: Key: Your first name and middle initial, Value: JOHN J
# Field: Key: Is blind, Value: NOT_SELECTED
# Field: Key: 14 Add lines 12 and 13 14, Value: 12,000
# Field: Key: Your spouse as a dependent, Value: NOT_SELECTED
# Field: Key: Foreign province/state/county, Value: N/A
# Field: Key: ZIP code, Value: 85308
# Field: Key: State, Value: A2
# Field: Key: Spouse itemizes on a separate return or you were a dual-status alien, Value: NOT_SELECTED
# Field: Key: 5a Pensions and annuities 5a, Value: N/A
# Field: Key: 4a IRA distributions 4a, Value: N/A
# Field: Key: No, Value: SELECTED
# Field: Key: 3a Qualified dividends 3a, Value: N/A
# Field: Key: b Taxable amount 4b, Value: N/A
# Field: Key: 10 Adjustments to income from Schedule 1, line 26 10, Value: 104,000
# Field: Key: Are blind, Value: NOT_SELECTED
# Field: Key: Spouse's social security number, Value: 9871654321
# Field: Key: 13 Qualified business income deduction from Form 8995 or Form 8995-A 13, Value: N/A
# Field: Key: You as a dependent, Value: NOT_SELECTED
# Field: Key: c If you elect to use the lump-sum election method, check here (see instructions), Value: NOT_SELECTED
# Field: Key: 6a Social security benefits 6a, Value: N/A
# Field: Key: Qualifying surviving spouse (QSS), Value: NOT_SELECTED
# Field: Key: h Other earned income (see instructions) 1h, Value: N/A
# Field: Key: 9 Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income 9, Value: 7,000
# Field: Key: 8 Other income from Schedule 1, line 10 8, Value: 111,000
# Field: Key: 2a Tax-exempt interest 2a, Value: N/A
# Field: Key: Foreign country name, Value: N/A
# Field: Key: f Employer-provided adoption benefits from Form 8839, line 29 1f, Value: N/A
# Field: Key: c Tip income not reported on line 1a (see instructions) 1c, Value: N/A
# Field: Key: b Taxable amount 5b, Value: N/A
# Field: Key: d Medicaid waiver payments not reported on Form(s) W-2 (see instructions) 1d, Value: N/A
# Field: Key: Apt. no., Value: N/A
# Field: Key: i Nontaxable combat pay election (see instructions) 1i, Value: N/A
# Field: Key: Foreign postal code, Value: N/A
# Field: Key: g Wages from Form 8919, line 6 1g, Value: apia
# Field: Key: 12 Standard deduction or Itemized deductions (from Schedule A) 12, Value: N/A
# Field: Key: e Taxable dependent care benefits from Form 2441, line 26 1e, Value: 5,000
# Field: Key: 7 Capital gaín or (loss). Attach Schedule D if required. If not required, check here, Value: NOT_SELECTED
# Field: Key: If more than four dependents, see instructions and check, Value: NOT_SELECTED
# Field: Key: 11 Subtract line 10 from line 9. This is your adjusted gross income 11, Value: N/A
# Field: Key: Cat. No., Value: 11320B

# %%
from trp import Document

# Parse JSON response from Textract
doc = Document(response)

# Iterate over elements in the document
for page in doc.pages:
    # Print lines and words
    for line in page.lines:
        print("Line: {}".format(line.text))
        for word in line.words:
            print("Word: {}, Confidence: {}".format(word.text, word.confidence))  # Add confidence

    # Print tables
    for table in page.tables:
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}, Confidence: {}".format(r, c, cell.text, cell.confidence))  # Add confidence

    # Print fields
    for field in page.form.fields:
        key_text = field.key.text if field.key else "N/A"
        key_confidence = field.key.confidence if field.key else "N/A"
        value_text = field.value.text if field.value else "N/A"
        value_confidence = field.value.confidence if field.value else "N/A"
        print("Field: Key: {}, Confidence: {}, Value: {}, Confidence: {}".format(key_text, key_confidence, value_text, value_confidence))  # Add confidence
# Out:
# Line: 1040
# Word: 1040, Confidence: 99.93353271484375
# Line: Department of the Treasury - Internal Revenue Service
# Word: Department, Confidence: 99.87731170654297
# Word: of, Confidence: 99.91316223144531
# Word: the, Confidence: 99.95600891113281
# Word: Treasury, Confidence: 90.90239715576172
# Word: -, Confidence: 78.8201904296875
# Word: Internal, Confidence: 89.28166961669922
# Word: Revenue, Confidence: 99.81559753417969
# Word: Service, Confidence: 99.86648559570312
# Line: U.S. Individual Income Tax Return
# Word: U.S., Confidence: 98.98809814453125
# Word: Individual, Confidence: 98.58805847167969
# Word: Income, Confidence: 98.80280303955078
# Word: Tax, Confidence: 99.95079040527344
# Word: Return, Confidence: 99.95491790771484
# Line: 2022
# Word: 2022, Confidence: 99.92893981933594
# Line: OMB No. 1545-0074
# Word: OMB, Confidence: 99.82048034667969
# Word: No., Confidence: 99.04751586914062
# Word: 1545-0074, Confidence: 99.56050872802734
# Line: IRS Use Only-Do not write or staple in this space.
# Word: IRS, Confidence: 99.94751739501953
# Word: Use, Confidence: 99.76444244384766
# Word: Only-Do, Confidence: 98.41730499267578
# Word: not, Confidence: 98.95364379882812
# Word: write, Confidence: 99.9099349975586
# Word: or, Confidence: 99.85980224609375
# Word: staple, Confidence: 99.4532470703125
# Word: in, Confidence: 99.94941711425781
# Word: this, Confidence: 99.901611328125
# Word: space., Confidence: 68.08936309814453
# Line: Filing Status
# Word: Filing, Confidence: 99.76435852050781
# Word: Status, Confidence: 99.84957122802734
# Line: Single
# Word: Single, Confidence: 99.84115600585938
# Line: Married filing jointly
# Word: Married, Confidence: 99.9462890625
# Word: filing, Confidence: 99.53595733642578
# Word: jointly, Confidence: 99.94168853759766
# Line: Married filing separately (MFS)
# Field: Key: 8 Other income from Schedule 1, line 10 8, Confidence: 87.18959045410156, Value: 111,000, Confidence: 87.18959045410156
# Field: Key: 2a Tax-exempt interest 2a, Confidence: 86.95977020263672, Value: N/A, Confidence: N/A
# Field: Key: Foreign country name, Confidence: 86.89826965332031, Value: N/A, Confidence: N/A
# Field: Key: f Employer-provided adoption benefits from Form 8839, line 29 1f, Confidence: 86.85977172851562, Value: N/A, Confidence: N/A
# Field: Key: c Tip income not reported on line 1a (see instructions) 1c, Confidence: 86.62361145019531, Value: N/A, Confidence: N/A
# Field: Key: b Taxable amount 5b, Confidence: 86.0455322265625, Value: N/A, Confidence: N/A
# Field: Key: d Medicaid waiver payments not reported on Form(s) W-2 (see instructions) 1d, Confidence: 86.044921875, Value: N/A, Confidence: N/A
# Field: Key: Apt. no., Confidence: 85.97003173828125, Value: N/A, Confidence: N/A
# Field: Key: i Nontaxable combat pay election (see instructions) 1i, Confidence: 85.03733825683594, Value: N/A, Confidence: N/A
# Field: Key: Foreign postal code, Confidence: 84.67644500732422, Value: N/A, Confidence: N/A
# Field: Key: g Wages from Form 8919, line 6 1g, Confidence: 83.85383605957031, Value: apia, Confidence: 83.85383605957031
# Field: Key: 12 Standard deduction or Itemized deductions (from Schedule A) 12, Confidence: 83.67191314697266, Value: N/A, Confidence: N/A
# Field: Key: e Taxable dependent care benefits from Form 2441, line 26 1e, Confidence: 80.87066650390625, Value: 5,000, Confidence: 80.87066650390625
# Field: Key: 7 Capital gaín or (loss). Attach Schedule D if required. If not required, check here, Confidence: 76.24028015136719, Value: NOT_SELECTED, Confidence: 76.24028015136719
# Field: Key: If more than four dependents, see instructions and check, Confidence: 76.09812927246094, Value: NOT_SELECTED, Confidence: 76.09812927246094
# Field: Key: 11 Subtract line 10 from line 9. This is your adjusted gross income 11, Confidence: 41.692100524902344, Value: N/A, Confidence: N/A
# Field: Key: Cat. No., Confidence: 21.56641960144043, Value: 11320B, Confidence: 21.56641960144043

# %%
from trp import Document
import json

# Create a dictionary to store fields and values
fields_dict = {}

# Parse JSON response from Textract
doc = Document(response)

# Function to calculate the average confidence score for a list of elements
def calculate_average_confidence(elements):
    total_confidence = sum(element.confidence for element in elements)
    return total_confidence / len(elements) if len(elements) > 0 else 0.0

# Iterate over elements in the document
for page in doc.pages:
    # Create a dictionary to store word confidence scores
    word_confidence_scores = {}
    
    # Print lines and words
    for line in page.lines:
        print("Line: {}, Confidence: {}".format(line.text, line.confidence))
        for word in line.words:
            word_text = word.text
            word_confidence = word.confidence
            word_confidence_scores[word_text] = word_confidence  # Store word confidence score in the dictionary
            print("Word: {}, Confidence: {}".format(word_text, word_confidence))

    # Print tables
    for table in page.tables:
        print("Table Confidence Score: {}".format(table.confidence))  # Print the confidence score of the table
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                cell_text = cell.text.strip()  # Get the text of the cell
                
                # Assign the confidence score of the word to the table cell if there is a matching word
                cell_confidence = word_confidence_scores.get(cell_text, 0.0)
                
# Line: For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions., Confidence: 99.84441375732422
# Word: For, Confidence: 99.94564056396484
# Word: Disclosure,, Confidence: 99.44959259033203
# Word: Privacy, Confidence: 99.93146514892578
# Word: Act,, Confidence: 99.80686950683594
# Word: and, Confidence: 99.95471954345703
# Word: Paperwork, Confidence: 99.84642791748047
# Word: Reduction, Confidence: 99.93560028076172
# Word: Act, Confidence: 99.95421600341797
# Word: Notice,, Confidence: 99.92428588867188
# Word: see, Confidence: 99.92802429199219
# Word: separate, Confidence: 99.69007110595703
# Word: instructions., Confidence: 99.76605224609375
# Line: Cat. No. 11320B, Confidence: 98.2468032836914
# Word: Cat., Confidence: 99.65556335449219
# Word: No., Confidence: 99.16486358642578
# Word: 11320B, Confidence: 95.91998291015625
# Line: Form, Confidence: 99.90760040283203
# Word: Form, Confidence: 99.90760040283203
# Line: 1040, Confidence: 99.91657257080078
# Word: 1040, Confidence: 99.91657257080078
# Line: (2022), Confidence: 99.44366455078125
# Word: (2022), Confidence: 99.44366455078125
# Table Confidence Score: 100.0
# Table[0][0] = Your first name and middle initial, Confidence: 0.0
# Table[0][1] = Last name, Confidence: 0.0
# Table[1][0] = JOHN J, Confidence: 0.0
# Table[1][1] = SMITH, Confidence: 99.43091583251953
# Table[2][0] = If joint return, spouse's first name and middle initial, Confidence: 0.0
# Table[2][1] = Last name, Confidence: 0.0
# Table[3][0] = JANE K, Confidence: 0.0
# Table[3][1] = SMITH, Confidence: 99.43091583251953
# Table Confidence Score: 99.951171875
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions., Confidence: 0.0
# Table[0][1] = Apt. no., Confidence: 0.0
# Table[1][0] = 1040 N PHOENIX RD, Confidence: 0.0
# Table[1][1] = , Confidence: 0.0
# Table Confidence Score: 100.0
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below., Confidence: 0.0
# Table[0][1] = State, Confidence: 99.95453643798828
# Table[0][2] = ZIP code, Confidence: 0.0
# Table[1][0] = GLENDALE, Confidence: 99.21516418457031
# Table[1][1] = A2, Confidence: 90.44326782226562
# Table[1][2] = 85308, Confidence: 98.56356048583984
# Table Confidence Score: 99.8046875
# Table[0][0] = Foreign country name, Confidence: 0.0
# Table[0][1] = Foreign province/state/county, Confidence: 0.0
# Table[0][2] = Foreign postal code, Confidence: 0.0
# Table[1][0] = , Confidence: 0.0
# Table[1][1] = , Confidence: 0.0
# Table[1][2] = , Confidence: 0.0
# Table Confidence Score: 100.0
# Table[0][0] = (see instructions):, Confidence: 0.0
# Table[0][1] = , Confidence: 0.0
# Table[0][2] = (2), Confidence: 99.39552307128906
# Table[0][3] = Social, Confidence: 99.84825134277344
# Table[0][4] = security, Confidence: 99.97445678710938
# Table[0][5] = (3) Relationship, Confidence: 0.0
# Table[0][6] = (4) Check the box if qualifies, Confidence: 0.0
# Table[0][7] = for (see instructions):, Confidence: 0.0
# Table[1][0] = (1) First name, Confidence: 0.0
# Table[1][1] = Last name, Confidence: 0.0
# Table[1][2] = , Confidence: 0.0
# Table[21][1] = 12, Confidence: 99.84488677978516
# Table[21][2] = Standard deduction or Itemized, Confidence: 0.0
# Table[21][3] = , Confidence: 0.0
# Table[21][4] = deductions (from Schedule, Confidence: 0.0
# Table[21][5] = A), Confidence: 99.50634002685547
# Table[21][6] = , Confidence: 0.0
# Table[21][7] = , Confidence: 0.0
# Table[21][8] = 12, Confidence: 99.84488677978516
# Table[21][9] = , Confidence: 0.0
# Table[22][0] = If you checked box under, Confidence: 0.0
# Table[22][1] = 13, Confidence: 99.85796356201172
# Table[22][2] = Qualified business income deduction, Confidence: 0.0
# Table[22][3] = , Confidence: 0.0
# Table[22][4] = from Form 8995 or, Confidence: 0.0
# Table[22][5] = Form 8995-A, Confidence: 0.0
# Table[22][6] = , Confidence: 0.0
# Table[22][7] = , Confidence: 0.0
# Table[22][8] = 13, Confidence: 99.85796356201172
# Table[22][9] = , Confidence: 0.0
# Table[23][0] = any Standard, Confidence: 0.0
# Table[23][1] = 14, Confidence: 99.91327667236328
# Table[23][2] = Add lines 12 and 13, Confidence: 0.0
# Table[23][3] = , Confidence: 0.0
# Table[23][4] = , Confidence: 0.0
# Table[23][5] = , Confidence: 0.0
# Table[23][6] = , Confidence: 0.0
# Table[23][7] = , Confidence: 0.0
# Table[23][8] = 14, Confidence: 99.91327667236328
# Table[23][9] = 12,000, Confidence: 95.19815063476562
# Table[24][0] = Deduction, see instructions., Confidence: 0.0
# Table[24][1] = 15, Confidence: 99.90511322021484
# Table[24][2] = Subtract line 14 from line 11. If, Confidence: 0.0
# Table[24][3] = zero or, Confidence: 0.0
# Table[24][4] = less, enter -0-. This, Confidence: 0.0
# Table[24][5] = is your taxable, Confidence: 0.0
# Table[24][6] = income, Confidence: 99.88873291015625
# Table[24][7] = , Confidence: 0.0
# Table[24][8] = 15, Confidence: 99.90511322021484
# Table[24][9] = 92,000, Confidence: 99.03303527832031
# Table[25][0] = , Confidence: 0.0
# Table[25][1] = , Confidence: 0.0
# Table[25][2] = , Confidence: 0.0
# Table[25][3] = , Confidence: 0.0
# Table[25][4] = , Confidence: 0.0
# Table[25][5] = , Confidence: 0.0
# Table[25][6] = , Confidence: 0.0
# Table[25][7] = , Confidence: 0.0
# Table[25][8] = , Confidence: 0.0
# Table[25][9] = , Confidence: 0.0

# %%
import pandas as pd

# Create an empty list to store tables
tables_list = []

# Iterate through the tables and append each table to the list
for table in page.tables:
    tables_list.append(table)

# Create an empty list to store table data with confidence scores
table_data_with_confidence = []

# Loop through the tables and print their content separately
for i, table in enumerate(tables_list):
    table_data = []
    print(f"Table {i + 1}:")
    
    for r, row in enumerate(table.rows):
        row_data = []
        for c, cell in enumerate(row.cells):
            cell_text = cell.text.strip()
            cell_confidence = cell.confidence if hasattr(cell, 'confidence') else None
            row_data.append((cell_text, cell_confidence))
            print(f"Table[{r}][{c}] = {cell_text}, Confidence: {cell_confidence}")
        
        table_data.append(row_data)
    
    table_data_with_confidence.append(table_data)
    print("\n")  # Separate tables with a newline

# Now you have each table's data with confidence scores stored in `table_data_with_confidence`

# If you want to convert a specific table (e.g., Table 5) to a Pandas DataFrame
# with additional columns for confidence scores for each value in each column:

desired_table_index = 4

if desired_table_index < len(table_data_with_confidence):
    table_5_data = table_data_with_confidence[desired_table_index]
    
    # Create a list of column names as numbers
    column_names = [str(c) for c in range(len(table_5_data[0]))]
    
    # Create a list to hold the data for the DataFrame
    df_data = []
    
    for row_data in table_5_data:
        row_values = []
        for (_, cell_confidence) in row_data:
            row_values.append(cell_confidence)
        df_data.append(row_values)
    
    # Create a Pandas DataFrame with columns named as numbers
    df = pd.DataFrame(df_data, columns=column_names)
    
    print("DataFrame for Table 5 with Confidence Scores for Each Value in Each Column:")
    print(df)
else:
    print(f"Table {desired_table_index + 1} not found in the document.")
# Out:
# Table 1:
# Table[0][0] = Your first name and middle initial, Confidence: 91.40625
# Table[0][1] = Last name, Confidence: 91.2109375
# Table[1][0] = JOHN J, Confidence: 90.185546875
# Table[1][1] = SMITH, Confidence: 90.0390625
# Table[2][0] = If joint return, spouse's first name and middle initial, Confidence: 89.2578125
# Table[2][1] = Last name, Confidence: 89.0625
# Table[3][0] = JANE K, Confidence: 92.3828125
# Table[3][1] = SMITH, Confidence: 92.1875
#
#
# Table 2:
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions., Confidence: 88.57421875
# Table[0][1] = Apt. no., Confidence: 84.814453125
# Table[1][0] = 1040 N PHOENIX RD, Confidence: 89.111328125
# Table[1][1] = , Confidence: 85.302734375
#
#
# Table 3:
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below., Confidence: 92.7734375
# Table[0][1] = State, Confidence: 87.79296875
# Table[0][2] = ZIP code, Confidence: 89.84375
# Table[1][0] = GLENDALE, Confidence: 91.9921875
# Table[1][1] = A2, Confidence: 87.060546875
# Table[1][2] = 85308, Confidence: 89.111328125
#
#
# Table 4:
# Table[0][0] = Foreign country name, Confidence: 66.162109375
# Table[0][1] = Foreign province/state/county, Confidence: 66.40625
# Table[0][2] = Foreign postal code, Confidence: 64.0625
# Table[1][0] = , Confidence: 86.376953125
# Table[1][1] = , Confidence: 86.71875
# Table[1][2] = , Confidence: 83.642578125
#
#
# Table 5:
# Table[0][0] = (see instructions):, Confidence: 46.58203125
# Table[0][1] = , Confidence: 53.125
# Table[0][2] = (2), Confidence: 94.873046875
# Table[0][3] = Social, Confidence: 94.873046875
# Table[0][4] = security, Confidence: 94.873046875
# Table[0][5] = (3) Relationship, Confidence: 96.19140625
# Table[0][6] = (4) Check the box if qualifies, Confidence: 80.17578125
# Table[0][7] = for (see instructions):, Confidence: 80.17578125
# Table[1][0] = (1) First name, Confidence: 46.58203125
# Table[1][1] = Last name, Confidence: 53.125
# Table[1][2] = , Confidence: 94.873046875
# Table[1][3] = number, Confidence: 94.873046875
# Table[1][4] = , Confidence: 94.873046875
# Table[1][5] = to you, Confidence: 96.19140625
# Table[1][6] = Child tax credit, Confidence: 70.751953125
# Table[1][7] = Credit for other dependents, Confidence: 68.994140625
# 5  91.503906  89.208984

# %%
df
# Out:
#            0          1          2          3          4          5
# 0  46.582031  53.125000  94.873047  94.873047  94.873047  96.191406  \
# 1  46.582031  53.125000  94.873047  94.873047  94.873047  96.191406
# 2  87.597656  88.134766  77.783203  78.320312  85.937500  89.941406
# 3  88.476562  89.013672  78.564453  79.101562  86.816406  90.869141
# 4  86.132812  86.669922  76.464844  77.001953  84.472656  88.427734
# 5  91.113281  91.699219  80.908203  81.445312  89.355469  93.554688
#
#            6          7
# 0  80.175781  80.175781
# 1  70.751953  68.994141
# 2  87.988281  85.791016
# 3  88.867188  86.669922
# 4  86.474609  84.375000
# 5  91.503906  89.208984

# %%
# Convert numerical columns to numeric (assuming they contain numerical values)
df["2"] = pd.to_numeric(df["2"], errors="coerce")
df["3"] = pd.to_numeric(df["3"], errors="coerce")
df["4"] = pd.to_numeric(df["4"], errors="coerce")

# Add the values in columns 2, 3, and 4 and store the result in column 3
df["3"] = df["2"] + df["3"] + df["4"]

# Now, you can drop the original columns
df.drop(["2", "4"], axis=1, inplace=True)

# Print the modified DataFrame
df
# Out:
#            0          1           3          5          6          7
# 0  46.582031  53.125000  284.619141  96.191406  80.175781  80.175781
# 1  46.582031  53.125000  284.619141  96.191406  70.751953  68.994141
# 2  87.597656  88.134766  242.041016  89.941406  87.988281  85.791016
# 3  88.476562  89.013672  244.482422  90.869141  88.867188  86.669922
# 4  86.132812  86.669922  237.939453  88.427734  86.474609  84.375000
# 5  91.113281  91.699219  251.708984  93.554688  91.503906  89.208984

# %%
df["3"] = df["3"]/3

# %%
df
# Out:
#            0          1          3          5          6          7
# 0  46.582031  53.125000  94.873047  96.191406  80.175781  80.175781
# 1  46.582031  53.125000  94.873047  96.191406  70.751953  68.994141
# 2  87.597656  88.134766  80.680339  89.941406  87.988281  85.791016
# 3  88.476562  89.013672  81.494141  90.869141  88.867188  86.669922
# 4  86.132812  86.669922  79.313151  88.427734  86.474609  84.375000
# 5  91.113281  91.699219  83.902995  93.554688  91.503906  89.208984

# %%
# Create an empty list to store tables
tables_list = []

# Iterate through the tables and append each table to the list
for table in page.tables:
    tables_list.append(table)

# Loop through the tables and print their content separately
for i, table in enumerate(tables_list):
    print(f"Table {i + 1}:")
    for r, row in enumerate(table.rows):
        for c, cell in enumerate(row.cells):
            print(f"Table[{r}][{c}] = {cell.text}")
    print("\n")  # Separate tables with a newline

# Now you have each table stored in the `tables_list` for further processing
# Out:
# Table 1:
# Table[0][0] = Your first name and middle initial
# Table[0][1] = Last name
# Table[1][0] = JOHN J
# Table[1][1] = SMITH
# Table[2][0] = If joint return, spouse's first name and middle initial
# Table[2][1] = Last name
# Table[3][0] = JANE K
# Table[3][1] = SMITH
#
#
# Table 2:
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions.
# Table[0][1] = Apt. no.
# Table[1][0] = 1040 N PHOENIX RD
# Table[1][1] =
#
#
# Table 3:
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below.
# Table[0][1] = State
# Table[0][2] = ZIP code
# Table[1][0] = GLENDALE
# Table[1][1] = A2
# Table[1][2] = 85308
#
#
# Table 4:
# Table[0][0] = Foreign country name
# Table[0][1] = Foreign province/state/county
# Table[0][2] = Foreign postal code
# Table[1][0] =
# Table[1][1] =
# Table[1][2] =
#
#
# Table 5:
# Table[0][0] = (see instructions):
# Table[0][1] =
# Table[0][2] = (2)
# Table[0][3] = Social
# Table[0][4] = security
# Table[0][5] = (3) Relationship
# Table[0][6] = (4) Check the box if qualifies
# Table[0][7] = for (see instructions):
# Table[1][0] = (1) First name
# Table[1][1] = Last name
# Table[1][2] =
# Table[1][3] = number
# Table[1][4] =
# Table[1][5] = to you
# Table[1][6] = Child tax credit
# Table[1][7] = Credit for other dependents
# Table[2][0] = JAY
# Table[2][1] = SMITH
# Table[2][2] =
# Table[2][3] = 135792468
# Table[2][4] =
# Table[2][5] = SON
# Table[2][6] = SELECTED,
# Table[2][7] = NOT_SELECTED,
# Table[3][0] = VICTORIA
# Table[3][1] = SMITH
# Table[3][2] = 246
# Table[3][3] = 81
# Table[3][4] = 3579
# Table[3][5] = DAUGHTER
# Table[3][6] = SELECTED,
# Table[3][7] = NOT_SELECTED,
# Table[4][0] =
# Table[4][1] =
# Table[4][2] =
# Table[4][3] =
# Table[4][4] =
# Table[4][5] =
# Table[4][6] = NOT_SELECTED,
# Table[4][7] = NOT_SELECTED,
# Table[5][0] =
# Table[5][1] =
# Table[5][2] =
# Table[5][3] =
# Table[5][4] =
# Table[5][5] =
# Table[5][6] = NOT_SELECTED,
# Table[5][7] = NOT_SELECTED,
#
#
# Table 6:
# Table[0][0] = Income
# Table[0][1] = 1a
# Table[0][2] = Total amount from Form(s) W-2,
# Table[0][3] = box 1
# Table[0][4] = (see instructions)
# Table[0][5] =
# Table[0][6] =
# Table[0][7] =
# Table[0][8] = 1a
# Table[0][9] = 100,000
# Table[1][0] =
# Table[1][1] = b
# Table[1][2] = Household employee wages not
# Table[1][3] = reported
# Table[1][4] = on Form(s) W-2
# Table[1][5] =
# Table[1][6] =
# Table[1][7] =
# Table[1][8] = 1b
# Table[1][9] =
# Table[2][0] = Attach Form(s)
# Table[2][1] = c
# Table[2][2] = Tip income not reported on line
# Table[2][3] = 1a (see
# Table[2][4] = instructions)
# Table[2][5] =
# Table[2][6] =
# Table[2][7] =
# Table[2][8] = 1c
# Table[2][9] =
# Table[3][0] = W-2 here. Also attach Forms
# Table[3][1] = d
# Table[3][2] = Medicaid waiver payments not
# Table[3][3] = reported
# Table[3][4] = on Form(s) W-2 (see
# Table[3][5] = instructions)
# Table[3][6] =
# Table[3][7] =
# Table[3][8] = 1d
# Table[3][9] =
# Table[4][0] = W-2G and
# Table[4][1] = e
# Table[4][2] = Taxable dependent care benefits
# Table[4][3] = from
# Table[4][4] = Form 2441, line 26
# Table[4][5] =
# Table[4][6] =
# Table[4][7] =
# Table[4][8] = 1e
# Table[4][9] = 5,000
# Table[5][0] = 1099-R if tax was withheld.
# Table[5][1] = f
# Table[5][2] = Employer-provided adoption
# Table[5][3] = benefits
# Table[5][4] = from Form 8839, line
# Table[5][5] = 29
# Table[5][6] =
# Table[5][7] =
# Table[5][8] = 1f
# Table[5][9] =
# Table[6][0] = If you did not
# Table[6][1] = g
# Table[6][2] = Wages from Form 8919, line 6
# Table[6][3] =
# Table[6][4] =
# Table[6][5] =
# Table[6][6] =
# Table[6][7] =
# Table[6][8] = 1g
# Table[6][9] = apia
# Table[7][0] = get a Form
# Table[7][1] = h
# Table[7][2] = Other earned income (see
# Table[7][3] = instructions)
# Table[7][4] =
# Table[7][5] =
# Table[7][6] =
# Table[7][7] =
# Table[7][8] = 1h
# Table[7][9] =
# Table[8][0] = W-2, see instructions.
# Table[8][1] = i
# Table[8][2] = Nontaxable combat pay election
# Table[8][3] = (see
# Table[8][4] = instructions)
# Table[8][5] =
# Table[8][6] = 1i
# Table[8][7] =
# Table[8][8] =
# Table[8][9] =
# Table[9][0] =
# Table[9][1] = z
# Table[9][2] = Add lines 1a through 1h
# Table[9][3] =
# Table[9][4] =
# Table[9][5] =
# Table[9][6] =
# Table[9][7] =
# Table[9][8] = 1z
# Table[9][9] = 105,000
# Table[10][0] = Attach Sch. B
# Table[10][1] = 2a
# Table[10][2] = Tax-exempt interest
# Table[10][3] = 2a
# Table[10][4] =
# Table[10][5] = b Taxable
# Table[10][6] = interest
# Table[10][7] =
# Table[10][8] = 2b
# Table[10][9] = 6,000
# Table[11][0] = if required.
# Table[11][1] = 3a
# Table[11][2] = Qualified dividends
# Table[11][3] = 3a
# Table[11][4] =
# Table[11][5] = b Ordinary
# Table[11][6] = dividends
# Table[11][7] =
# Table[11][8] = 3b
# Table[11][9] =
# Table[12][0] =
# Table[12][1] = 4a
# Table[12][2] = IRA distributions
# Table[12][3] = 4a
# Table[12][4] =
# Table[12][5] = b Taxable
# Table[12][6] = amount
# Table[12][7] =
# Table[12][8] = 4b
# Table[12][9] =
# Table[13][0] = Standard
# Table[13][1] = 5a
# Table[13][2] = Pensions and annuities
# Table[13][3] = 5a
# Table[13][4] =
# Table[13][5] = b Taxable
# Table[13][6] = amount
# Table[13][7] =
# Table[13][8] = 5b
# Table[13][9] =
# Table[14][0] = Deduction for- Single or
# Table[14][1] = 6a
# Table[14][2] = Social security benefits
# Table[14][3] = 6a
# Table[14][4] =
# Table[14][5] = b Taxable
# Table[14][6] = amount
# Table[14][7] =
# Table[14][8] = 6b
# Table[14][9] =
# Table[15][0] = Married filing
# Table[15][1] = c
# Table[15][2] = If you elect to use the lump-sum
# Table[15][3] = election
# Table[15][4] = method, check
# Table[15][5] = here (see instructions)
# Table[15][6] =
# Table[15][7] = NOT_SELECTED,
# Table[15][8] =
# Table[15][9] =
# Table[16][0] = separately, $12,950
# Table[16][1] = 7
# Table[16][2] = Capital gaín or (loss). Attach
# Table[16][3] = Schedule
# Table[16][4] = D if required. If not
# Table[16][5] = required, check
# Table[16][6] = here
# Table[16][7] = NOT_SELECTED,
# Table[16][8] = 7
# Table[16][9] =
# Table[17][0] = Married filing
# Table[17][1] = 8
# Table[17][2] = Other income from Schedule 1,
# Table[17][3] = line 10
# Table[17][4] =
# Table[17][5] =
# Table[17][6] =
# Table[17][7] =
# Table[17][8] = 8
# Table[17][9] = 111,000
# Table[18][0] = jointly or Qualifying
# Table[18][1] = 9
# Table[18][2] = Add lines 1z, 2b, 3b, 4b, 5b, 6b,
# Table[18][3] = 7, and
# Table[18][4] = 8. This is your total
# Table[18][5] = income
# Table[18][6] =
# Table[18][7] =
# Table[18][8] = 9
# Table[18][9] = 7,000
# Table[19][0] = surviving spouse, $25,900
# Table[19][1] = 10
# Table[19][2] = Adjustments to income from
# Table[19][3] = Schedule
# Table[19][4] = 1, line 26
# Table[19][5] =
# Table[19][6] =
# Table[19][7] =
# Table[19][8] = 10
# Table[19][9] = 104,000
# Table[20][0] = Head of
# Table[20][1] = 11
# Table[20][2] = Subtract line 10 from line 9. This
# Table[20][3] = is your
# Table[20][4] = adjusted gross
# Table[20][5] = income
# Table[20][6] =
# Table[20][7] =
# Table[20][8] = 11
# Table[20][9] =
# Table[21][0] = household, $19,400
# Table[21][1] = 12
# Table[21][2] = Standard deduction or Itemized
# Table[21][3] =
# Table[21][4] = deductions (from Schedule
# Table[21][5] = A)
# Table[21][6] =
# Table[21][7] =
# Table[21][8] = 12
# Table[21][9] =
# Table[22][0] = If you checked box under
# Table[22][1] = 13
# Table[22][2] = Qualified business income deduction
# Table[22][3] =
# Table[22][4] = from Form 8995 or
# Table[22][5] = Form 8995-A
# Table[22][6] =
# Table[22][7] =
# Table[22][8] = 13
# Table[22][9] =
# Table[23][0] = any Standard
# Table[23][1] = 14
# Table[23][2] = Add lines 12 and 13
# Table[23][3] =
# Table[23][4] =
# Table[23][5] =
# Table[23][6] =
# Table[23][7] =
# Table[23][8] = 14
# Table[23][9] = 12,000
# Table[24][0] = Deduction, see instructions.
# Table[24][1] = 15
# Table[24][2] = Subtract line 14 from line 11. If
# Table[24][3] = zero or
# Table[24][4] = less, enter -0-. This
# Table[24][5] = is your taxable
# Table[24][6] = income
# Table[24][7] =
# Table[24][8] = 15
# Table[24][9] = 92,000
# Table[25][0] =
# Table[25][1] =
# Table[25][2] =
# Table[25][3] =
# Table[25][4] =
# Table[25][5] =
# Table[25][6] =
# Table[25][7] =
# Table[25][8] =
# Table[25][9] =

# %%
import pandas as pd

# Create an empty list to store tables
tables_list = []

# Iterate through the tables and append each table to the list
for table in page.tables:
    tables_list.append(table)

# Extract and convert Table 5 to a Pandas DataFrame (index 4 since Python uses 0-based indexing)
table_5 = tables_list[4]

# Create an empty DataFrame to store the table data
data = []

# Iterate over the rows and cells of Table 5 and populate the data list
for r, row in enumerate(table_5.rows):
    row_data = [cell.text.strip() for cell in row.cells]
    data.append(row_data)
data
# Create a Pandas DataFrame from the data list
df5 = pd.DataFrame(data)

# Print the DataFrame
df5
# Out:
#                      0          1    2          3         4                 5
# 0  (see instructions):             (2)     Social  security  (3) Relationship  \
# 1       (1) First name  Last name          number                      to you
# 2                  JAY      SMITH       135792468                         SON
# 3             VICTORIA      SMITH  246         81      3579          DAUGHTER
# 4
# 5
#
#                                 6                            7
# 0  (4) Check the box if qualifies      for (see instructions):
# 1                Child tax credit  Credit for other dependents
# 2                       SELECTED,                NOT_SELECTED,
# 3                       SELECTED,                NOT_SELECTED,
# 4                   NOT_SELECTED,                NOT_SELECTED,
# 5                   NOT_SELECTED,                NOT_SELECTED,

# %%
data = str(data)

# %%
ents, types = entity_detection(data, "en")
print("Entities:", ents)
print("Entity Types:", types)
# Out:
# Entities: ['JAY', '135792468', 'VICTORIA', 'SMITH', '3579']
# Entity Types: ['PERSON', 'OTHER', 'PERSON', 'PERSON', 'OTHER']

# %%
df5[1]
# Out:
# 0
# 1    Last name
# 2        SMITH
# 3        SMITH
# 4
# 5
# Name: 1, dtype: object

# %%
# Concatenate columns 2, 3, and 4 into a single column
df5[3] = df5[2] + ' ' + df5[3] + ' ' + df5[4]
df5.drop([2, 4], axis=1, inplace=True)

df5
# Out:
#                      0          1                    3                 5
# 0  (see instructions):             (2) Social security  (3) Relationship  \
# 1       (1) First name  Last name              number             to you
# 2                  JAY      SMITH           135792468                SON
# 3             VICTORIA      SMITH          246 81 3579          DAUGHTER
# 4
# 5
#
#                                 6                            7
# 0  (4) Check the box if qualifies      for (see instructions):
# 1                Child tax credit  Credit for other dependents
# 2                       SELECTED,                NOT_SELECTED,
# 3                       SELECTED,                NOT_SELECTED,
# 4                   NOT_SELECTED,                NOT_SELECTED,
# 5                   NOT_SELECTED,                NOT_SELECTED,

# %%
# Number of rows to drop
n = 2
# Using DataFrame.tail() function to drop first n rows
df5 = df5.tail(-2)
df = df.tail(-2)

# %%
df5
# Out:
#           0      1            3         5              6              7
# 2       JAY  SMITH   135792468        SON      SELECTED,  NOT_SELECTED,
# 3  VICTORIA  SMITH  246 81 3579  DAUGHTER      SELECTED,  NOT_SELECTED,
# 4                                          NOT_SELECTED,  NOT_SELECTED,
# 5                                          NOT_SELECTED,  NOT_SELECTED,

# %%
df5[0]
# Out:
# 2         JAY
# 3    VICTORIA
# 4
# 5
# Name: 0, dtype: object

# %%
df
# Out:
#            0          1          3          5          6          7
# 2  87.597656  88.134766  80.680339  89.941406  87.988281  85.791016
# 3  88.476562  89.013672  81.494141  90.869141  88.867188  86.669922
# 4  86.132812  86.669922  79.313151  88.427734  86.474609  84.375000
# 5  91.113281  91.699219  83.902995  93.554688  91.503906  89.208984

# %%
NUM_TO_REVIEW = len(df5) # number of line items to review
dffn = df5[0].to_list()
dfln = df5[1].to_list()
dfssn = df5[3].to_list()
dfrl = df5[5].to_list()
dfct = df5[6].to_list()
dfcd = df5[7].to_list()
dfn = df["0"].to_list()
dln = df["1"].to_list()
dssn = df["3"].to_list()
drl = df["5"].to_list()
dct = df["6"].to_list()
dcd = df["7"].to_list()


item_list5 = [{'row': "{}".format(x), 'First Name': dffn[x],'FirstNameConfidence': dfn[x], 'Last Name': dfln[x], 'LastNameConfidence': dfn[x],  'SSN': dfssn[x], 'SSNConfidence': dssn[x], 'Relation to you': dfrl[x], 'RTYConfidence': drl[x], 'Child tax credit': dfct[x],'CTCConfidence': dct[x], 'Credit for other dependents': dfcd[x], 'CODConfidence': dcd[x]} for x in range(NUM_TO_REVIEW)]
item_list5
# Out:
# [{'row': '0',
#   'First Name': 'JAY',
#   'FirstNameConfidence': 87.59765625,
#   'Last Name': 'SMITH',
#   'LastNameConfidence': 87.59765625,
#   'SSN': ' 135792468 ',
#   'SSNConfidence': 80.68033854166667,
#   'Relation to you': 'SON',
#   'RTYConfidence': 89.94140625,
#   'Child tax credit': 'SELECTED,',
#   'CTCConfidence': 87.98828125,
#   'Credit for other dependents': 'NOT_SELECTED,',
#   'CODConfidence': 85.791015625},
#  {'row': '1',
#   'First Name': 'VICTORIA',
#   'FirstNameConfidence': 88.4765625,
#   'Last Name': 'SMITH',
#   'LastNameConfidence': 88.4765625,
#   'SSN': '246 81 3579',
#   'SSNConfidence': 81.494140625,
#   'Relation to you': 'DAUGHTER',
#   'RTYConfidence': 90.869140625,
#   'Child tax credit': 'SELECTED,',
#   'CTCConfidence': 88.8671875,
#   'Credit for other dependents': 'NOT_SELECTED,',
#   'CODConfidence': 86.669921875},
#  {'row': '2',
#   'First Name': '',
#   'FirstNameConfidence': 86.1328125,
#   'Last Name': '',
#   'LastNameConfidence': 86.1328125,
#   'SSN': '  ',
#   'SSNConfidence': 79.31315104166667,
#   'Relation to you': '',
#   'RTYConfidence': 88.427734375,
#   'Child tax credit': 'NOT_SELECTED,',
#   'CTCConfidence': 86.474609375,
#   'Credit for other dependents': 'NOT_SELECTED,',
#   'CODConfidence': 84.375},
#  {'row': '3',
#   'First Name': '',
#   'FirstNameConfidence': 91.11328125,
#   'Last Name': '',
#   'LastNameConfidence': 91.11328125,
#   'SSN': '  ',
#   'SSNConfidence': 83.90299479166667,
#   'Relation to you': '',
#   'RTYConfidence': 93.5546875,
#   'Child tax credit': 'NOT_SELECTED,',
#   'CTCConfidence': 91.50390625,
#   'Credit for other dependents': 'NOT_SELECTED,',
#   'CODConfidence': 89.208984375}]

# %%
# Fields to extract confidence scores for
fields_to_extract = [
    "Married filing jointly",
    "Were born before January 2, 1958",
    "Head of household (HOH)",
    "Married filing separately (MFS)",
    "You as a dependent",
    "Single"
]

# Extract confidence scores for the specified fields
confidence_scores = {}

for block in response['Blocks']:
    if 'Text' in block:
        text = block['Text']
        confidence = block['Confidence']
        
        for field in fields_to_extract:
            if field in text:
                confidence_scores[field] = confidence

# Print extracted confidence scores
for field, confidence in confidence_scores.items():
    print(f"Field: {field}, Confidence: {confidence}")
# Out:
# Field: Single, Confidence: 99.9559097290039
# Field: Married filing jointly, Confidence: 99.80797576904297
# Field: Married filing separately (MFS), Confidence: 99.8315200805664
# Field: Head of household (HOH), Confidence: 99.94461822509766
# Field: You as a dependent, Confidence: 99.84811401367188
# Field: Were born before January 2, 1958, Confidence: 98.56246948242188

# %% [markdown]
# You can use Textract response parser library to easily parser JSON returned by Amazon Textract. Library parses JSON and provides programming language specific constructs to work with different parts of the document. For more details please refer to the [Amazon Textract Parser Library](https://github.com/aws-samples/amazon-textract-response-parser/tree/master/src-python)

# %%
from trp import Document
import json
# Create a dictionary to store fields and values
fields_dict = {}

# Parse JSON response from Textract
doc = Document(response)

# Iterate over elements in the document
for page in doc.pages:
    # Print lines and words
    for line in page.lines:
        print("Line: {}".format(line.text))
        for word in line.words:
            print("Word: {}".format(word.text))

    # Print tables
    for table in page.tables:
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}".format(r, c, cell.text))




import json

# Initialize a dictionary to store field data
fields_dict = {}

# List of specific key values to extract
fields_to_extract = [
    "Married filing jointly",
    "Were born before January 2, 1958",
    "Head of household (HOH)",
    "Married filing separately (MFS)",
    "You as a dependent",
    "Single"
]

# Iterate through the fields
for field in page.form.fields:
    if field.key is not None and field.key.text in fields_to_extract:
        fields_dict[field.key.text] = {
            "value": field.value.text if field.value is not None else "NULL",
            "confidence": field.value.block["Confidence"] if field.value is not None else None
        }

# Convert the dictionary to a JSON string
json_data = json.dumps(fields_dict, indent=4)

# Print the JSON data
print(json_data)
# Out:
# Line: 1040
# Word: 1040
# Line: Department of the Treasury - Internal Revenue Service
# Word: Department
# Word: of
# Word: the
# Word: Treasury
# Word: -
# Word: Internal
# Word: Revenue
# Word: Service
# Line: U.S. Individual Income Tax Return
# Word: U.S.
# Word: Individual
# Word: Income
# Word: Tax
# Word: Return
# Line: 2022
# Word: 2022
# Line: OMB No. 1545-0074
# Word: OMB
# Word: No.
# Word: 1545-0074
# Line: IRS Use Only-Do not write or staple in this space.
# Word: IRS
# Word: Use
# Word: Only-Do
# Word: not
# Word: write
# Word: or
# Word: staple
# Word: in
# Word: this
# Word: space.
# Line: Filing Status
# Word: Filing
# Word: Status
# Line: Single
# Word: Single
# Line: Married filing jointly
# Word: Married
# Word: filing
# Word: jointly
# Line: Married filing separately (MFS)
# Word: Married
# Word: filing
# Word: separately
# Word: (MFS)
# Line: Head of household (HOH)
# Word: Head
# Word: of
# Word: household
# Word: (HOH)
# Line: Qualifying surviving
# Word: Qualifying
# Word: surviving
# Line: Check only
# Word: Check
# Word: only
# Line: spouse (QSS)
# Word: spouse
# Word: (QSS)
# Line: one box.
# Word: one
# Word: box.
# Line: If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child's name if the qualifying
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: MFS
# Word: box,
# Word: enter
# Word: the
# Word: name
# Word: of
# Word: your
# Word: spouse.
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: HOH
# Word: or
# Word: QSS
# Word: box,
# Word: enter
# Word: the
# Word: child's
# Word: name
# Word: if
# Word: the
# Word: qualifying
# Line: person is a child but not your dependent:
# Word: person
# Word: is
# Word: a
# Word: child
# Word: but
# Word: not
# Word: your
# Word: dependent:
# Line: Your first name and middle initial
# Word: Your
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Your social security number
# Word: Your
# Word: social
# Word: security
# Word: number
# Line: JOHN J
# Word: JOHN
# Word: J
# Line: SMITH
# Word: SMITH
# Line: 123 45 6789
# Word: 123 45 6789
# Line: If joint return, spouse's first name and middle initial
# Word: If
# Word: joint
# Word: return,
# Word: spouse's
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Spouse's social security number
# Word: Spouse's
# Word: social
# Word: security
# Word: number
# Line: JANE K
# Word: JANE
# Word: K
# Line: SMITH
# Word: SMITH
# Line: 9871654321
# Word: 9871654321
# Line: Home address (number and street). If you have a P.O. box, see instructions.
# Word: Home
# Word: address
# Word: (number
# Word: and
# Word: street).
# Word: If
# Word: you
# Word: have
# Word: a
# Word: P.O.
# Word: box,
# Word: see
# Word: instructions.
# Line: Apt. no.
# Word: Apt.
# Word: no.
# Line: Presidential Election Campaign
# Word: Presidential
# Word: Election
# Word: Campaign
# Line: 1040 N PHOENIX RD
# Word: 1040
# Word: N
# Word: PHOENIX
# Word: RD
# Line: Check here if you, or your
# Word: Check
# Word: here
# Word: if
# Word: you,
# Word: or
# Word: your
# Line: City, town, or post office. If you have a foreign address, also complete spaces below.
# Word: City,
# Word: town,
# Word: or
# Word: post
# Word: office.
# Word: If
# Word: you
# Word: have
# Word: a
# Word: foreign
# Word: address,
# Word: also
# Word: complete
# Word: spaces
# Word: below.
# Line: State
# Word: State
# Line: ZIP code
# Word: ZIP
# Word: code
# Line: spouse if filing jointly, want $3
# Word: spouse
# Word: if
# Word: filing
# Word: jointly,
# Word: want
# Word: $3
# Line: GLENDALE
# Word: GLENDALE
# Line: A2
# Word: A2
# Line: 85308
# Word: 85308
# Line: to go to this fund. Checking a
# Word: to
# Word: go
# Word: to
# Word: this
# Word: fund.
# Word: Checking
# Word: a
# Line: box below will not change
# Word: box
# Word: below
# Word: will
# Word: not
# Word: change
# Line: Foreign country name
# Word: Foreign
# Word: country
# Word: name
# Line: Foreign province/state/county
# Word: Foreign
# Word: province/state/county
# Line: Foreign postal code
# Word: Foreign
# Word: postal
# Word: code
# Line: your tax or refund.
# Word: your
# Word: tax
# Word: or
# Word: refund.
# Line: You
# Word: You
# Line: Spouse
# Word: Spouse
# Line: Digital
# Word: Digital
# Line: At any time during 2022, did you: (a) receive (as a reward, award, or payment for property or services); or (b) sell,
# Word: At
# Word: any
# Word: time
# Word: during
# Word: 2022,
# Word: did
# Word: you:
# Word: (a)
# Word: receive
# Word: (as
# Word: a
# Word: reward,
# Word: award,
# Word: or
# Word: payment
# Word: for
# Word: property
# Word: or
# Word: services);
# Word: or
# Word: (b)
# Word: sell,
# Line: Assets
# Word: Assets
# Line: exchange, gift, or otherwise dispose of a digital asset (or a financial interest in a digital asset)? (See instructions.)
# Word: exchange,
# Word: gift,
# Word: or
# Word: otherwise
# Word: dispose
# Word: of
# Word: a
# Word: digital
# Word: asset
# Word: (or
# Word: a
# Word: financial
# Word: interest
# Word: in
# Word: a
# Word: digital
# Word: asset)?
# Word: (See
# Word: instructions.)
# Line: Yes
# Word: Yes
# Line: No
# Word: No
# Line: Standard
# Word: Standard
# Line: Someone can claim:
# Word: Someone
# Word: can
# Word: claim:
# Line: You as a dependent
# Word: You
# Word: as
# Word: a
# Word: dependent
# Line: Your spouse as a dependent
# Word: Your
# Word: spouse
# Word: as
# Word: a
# Word: dependent
# Line: Deduction
# Word: Deduction
# Line: Spouse itemizes on a separate return or you were a dual-status alien
# Word: Spouse
# Word: itemizes
# Word: on
# Word: a
# Word: separate
# Word: return
# Word: or
# Word: you
# Word: were
# Word: a
# Word: dual-status
# Word: alien
# Line: Age/Blindness You:
# Word: Age/Blindness
# Word: You:
# Line: Were born before January 2, 1958
# Word: Were
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Are blind
# Word: Are
# Word: blind
# Line: Spouse:
# Word: Spouse:
# Line: Was born before January 2, 1958
# Word: Was
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Is blind
# Word: Is
# Word: blind
# Line: Dependents (see instructions):
# Word: Dependents
# Word: (see
# Word: instructions):
# Line: (2) Social security
# Word: (2)
# Word: Social
# Word: security
# Line: (3) Relationship
# Word: (3)
# Word: Relationship
# Line: (4) Check the box if qualifies for (see instructions):
# Word: (4)
# Word: Check
# Word: the
# Word: box
# Word: if
# Word: qualifies
# Word: for
# Word: (see
# Word: instructions):
# Line: If more
# Word: If
# Word: more
# Line: (1) First name
# Word: (1)
# Word: First
# Word: name
# Line: Last name
# Word: Last
# Word: name
# Line: number
# Word: number
# Line: to you
# Word: to
# Word: you
# Line: Child tax credit
# Word: Child
# Word: tax
# Word: credit
# Line: Credit for other dependents
# Word: Credit
# Word: for
# Word: other
# Word: dependents
# Line: than four
# Word: than
# Word: four
# Line: JAY
# Word: JAY
# Line: SMITH
# Word: SMITH
# Line: 135792468
# Word: 135792468
# Line: SON
# Word: SON
# Line: dependents,
# Word: dependents,
# Line: see instructions
# Word: see
# Word: instructions
# Line: VICTORIA
# Word: VICTORIA
# Line: SMITH
# Word: SMITH
# Line: 246
# Word: 246
# Line: 81
# Word: 81
# Line: 3579
# Word: 3579
# Line: DAUGHTER
# Word: DAUGHTER
# Line: and check
# Word: and
# Word: check
# Line: here
# Word: here
# Line: Income
# Word: Income
# Line: 1a Total amount from Form(s) W-2, box 1 (see instructions)
# Word: 1a
# Word: Total
# Word: amount
# Word: from
# Word: Form(s)
# Word: W-2,
# Word: box
# Word: 1
# Word: (see
# Word: instructions)
# Line: 1a
# Word: 1a
# Line: 100,000
# Word: 100,000
# Line: b Household employee wages not reported on Form(s) W-2
# Word: b
# Word: Household
# Word: employee
# Word: wages
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Line: 1b
# Word: 1b
# Line: Attach Form(s)
# Word: Attach
# Word: Form(s)
# Line: c Tip income not reported on line 1a (see instructions)
# Word: c
# Word: Tip
# Word: income
# Word: not
# Word: reported
# Word: on
# Word: line
# Word: 1a
# Word: (see
# Word: instructions)
# Line: 1c
# Word: 1c
# Line: W-2 here. Also
# Word: W-2
# Word: here.
# Word: Also
# Line: attach Forms
# Word: attach
# Word: Forms
# Line: d Medicaid waiver payments not reported on Form(s) W-2 (see instructions)
# Word: d
# Word: Medicaid
# Word: waiver
# Word: payments
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Word: (see
# Word: instructions)
# Line: 1d
# Word: 1d
# Line: W-2G and
# Word: W-2G
# Word: and
# Line: e Taxable dependent care benefits from Form 2441, line 26
# Word: e
# Word: Taxable
# Word: dependent
# Word: care
# Word: benefits
# Word: from
# Word: Form
# Word: 2441,
# Word: line
# Word: 26
# Line: 1e
# Word: 1e
# Line: 1099-R if tax
# Word: 1099-R
# Word: if
# Word: tax
# Line: 5,000
# Word: 5,000
# Line: was withheld.
# Word: was
# Word: withheld.
# Line: f Employer-provided adoption benefits from Form 8839, line 29
# Word: f
# Word: Employer-provided
# Word: adoption
# Word: benefits
# Word: from
# Word: Form
# Word: 8839,
# Word: line
# Word: 29
# Line: 1f
# Word: 1f
# Line: If you did not
# Word: If
# Word: you
# Word: did
# Word: not
# Line: g Wages from Form 8919, line 6
# Word: g
# Word: Wages
# Word: from
# Word: Form
# Word: 8919,
# Word: line
# Word: 6
# Line: 1g
# Word: 1g
# Line: apia
# Word: apia
# Line: get a Form
# Word: get
# Word: a
# Word: Form
# Line: h Other earned income (see instructions)
# Word: h
# Word: Other
# Word: earned
# Word: income
# Word: (see
# Word: instructions)
# Line: 1h
# Word: 1h
# Line: W-2, see
# Word: W-2,
# Word: see
# Line: i
# Word: i
# Line: instructions.
# Word: instructions.
# Line: Nontaxable combat pay election (see instructions)
# Word: Nontaxable
# Word: combat
# Word: pay
# Word: election
# Word: (see
# Word: instructions)
# Line: 1i
# Word: 1i
# Line: z Add lines 1a through 1h
# Word: z
# Word: Add
# Word: lines
# Word: 1a
# Word: through
# Word: 1h
# Line: 1z
# Word: 1z
# Line: 105,000
# Word: 105,000
# Line: Attach Sch. B
# Word: Attach
# Word: Sch.
# Word: B
# Line: 2a
# Word: 2a
# Line: Tax-exempt interest
# Word: Tax-exempt
# Word: interest
# Line: 2a
# Word: 2a
# Line: b Taxable interest
# Word: b
# Word: Taxable
# Word: interest
# Line: 2b
# Word: 2b
# Line: 6,000
# Word: 6,000
# Line: if required.
# Word: if
# Word: required.
# Line: 3a
# Word: 3a
# Line: Qualified dividends
# Word: Qualified
# Word: dividends
# Line: 3a
# Word: 3a
# Line: b Ordinary dividends
# Word: b
# Word: Ordinary
# Word: dividends
# Line: 3b
# Word: 3b
# Line: 4a IRA distributions
# Word: 4a
# Word: IRA
# Word: distributions
# Line: 4a
# Word: 4a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 4b
# Word: 4b
# Line: Standard
# Word: Standard
# Line: 5a Pensions and annuities
# Word: 5a
# Word: Pensions
# Word: and
# Word: annuities
# Line: 5a
# Word: 5a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 5b
# Word: 5b
# Line: Deduction for-
# Word: Deduction
# Word: for-
# Line: 6a
# Word: 6a
# Line: Social security benefits
# Word: Social
# Word: security
# Word: benefits
# Line: 6a
# Word: 6a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 6b
# Word: 6b
# Line: Single or
# Word: Single
# Word: or
# Line: Married filing
# Word: Married
# Word: filing
# Line: c
# Word: c
# Line: If you elect to use the lump-sum election method, check here (see instructions)
# Word: If
# Word: you
# Word: elect
# Word: to
# Word: use
# Word: the
# Word: lump-sum
# Word: election
# Word: method,
# Word: check
# Word: here
# Word: (see
# Word: instructions)
# Line: separately,
# Word: separately,
# Line: $12,950
# Word: $12,950
# Line: 7
# Word: 7
# Line: Capital gaín or (loss). Attach Schedule D if required. If not required, check here
# Word: Capital
# Word: gaín
# Word: or
# Word: (loss).
# Word: Attach
# Word: Schedule
# Word: D
# Word: if
# Word: required.
# Word: If
# Word: not
# Word: required,
# Word: check
# Word: here
# Line: 7
# Word: 7
# Line: Married filing
# Word: Married
# Word: filing
# Line: 8
# Word: 8
# Line: Other income from Schedule 1, line 10
# Word: Other
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 10
# Line: 8
# Word: 8
# Line: 111,000
# Word: 111,000
# Line: jointly or
# Word: jointly
# Word: or
# Line: Qualifying
# Word: Qualifying
# Line: 9
# Word: 9
# Line: Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income
# Word: Add
# Word: lines
# Word: 1z,
# Word: 2b,
# Word: 3b,
# Word: 4b,
# Word: 5b,
# Word: 6b,
# Word: 7,
# Word: and
# Word: 8.
# Word: This
# Word: is
# Word: your
# Word: total
# Word: income
# Line: 9
# Word: 9
# Line: 7,000
# Word: 7,000
# Line: surviving spouse,
# Word: surviving
# Word: spouse,
# Line: 10
# Word: 10
# Line: $25,900
# Word: $25,900
# Line: Adjustments to income from Schedule 1, line 26
# Word: Adjustments
# Word: to
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 26
# Line: 10
# Word: 10
# Line: 104,000
# Word: 104,000
# Line: Head of
# Word: Head
# Word: of
# Line: 11
# Word: 11
# Line: Subtract line 10 from line 9. This is your adjusted gross income
# Word: Subtract
# Word: line
# Word: 10
# Word: from
# Word: line
# Word: 9.
# Word: This
# Word: is
# Word: your
# Word: adjusted
# Word: gross
# Word: income
# Line: 11
# Word: 11
# Line: household,
# Word: household,
# Line: $19,400
# Word: $19,400
# Line: 12
# Word: 12
# Line: Standard deduction or Itemized deductions (from Schedule A)
# Word: Standard
# Word: deduction
# Word: or
# Word: Itemized
# Word: deductions
# Word: (from
# Word: Schedule
# Word: A)
# Line: 12
# Word: 12
# Line: If you checked
# Word: If
# Word: you
# Word: checked
# Line: 13
# Word: 13
# Line: Qualified business income deduction from Form 8995 or Form 8995-A
# Word: Qualified
# Word: business
# Word: income
# Word: deduction
# Word: from
# Word: Form
# Word: 8995
# Word: or
# Word: Form
# Word: 8995-A
# Line: 13
# Word: 13
# Line: any box under
# Word: any
# Word: box
# Word: under
# Line: Standard
# Word: Standard
# Line: 14
# Word: 14
# Line: Add lines 12 and 13
# Word: Add
# Word: lines
# Word: 12
# Word: and
# Word: 13
# Line: 14
# Word: 14
# Line: 12,000
# Word: 12,000
# Line: Deduction,
# Word: Deduction,
# Line: 15
# Word: 15
# Line: see instructions.
# Word: see
# Word: instructions.
# Line: Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income
# Word: Subtract
# Word: line
# Word: 14
# Word: from
# Word: line
# Word: 11.
# Word: If
# Word: zero
# Word: or
# Word: less,
# Word: enter
# Word: -0-.
# Word: This
# Word: is
# Word: your
# Word: taxable
# Word: income
# Line: 15
# Word: 15
# Line: 92,000
# Word: 92,000
# Line: For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.
# Word: For
# Word: Disclosure,
# Word: Privacy
# Word: Act,
# Word: and
# Word: Paperwork
# Word: Reduction
# Word: Act
# Word: Notice,
# Word: see
# Word: separate
# Word: instructions.
# Line: Cat. No. 11320B
# Word: Cat.
# Word: No.
# Word: 11320B
# Line: Form
# Word: Form
# Line: 1040
# Word: 1040
# Line: (2022)
# Word: (2022)
# Table[0][0] = Your first name and middle initial
# Table[0][1] = Last name
# Table[1][0] = JOHN J
# Table[1][1] = SMITH
# Table[2][0] = If joint return, spouse's first name and middle initial
# Table[2][1] = Last name
# Table[3][0] = JANE K
# Table[3][1] = SMITH
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions.
# Table[0][1] = Apt. no.
# Table[1][0] = 1040 N PHOENIX RD
# Table[1][1] =
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below.
# Table[0][1] = State
# Table[0][2] = ZIP code
# Table[1][0] = GLENDALE
# Table[1][1] = A2
# Table[1][2] = 85308
# Table[0][0] = Foreign country name
# Table[0][1] = Foreign province/state/county
# Table[0][2] = Foreign postal code
# Table[1][0] =
# Table[1][1] =
# Table[1][2] =
# Table[0][0] = (see instructions):
# Table[0][1] =
# Table[0][2] = (2)
# Table[0][3] = Social
# Table[0][4] = security
# Table[0][5] = (3) Relationship
# Table[0][6] = (4) Check the box if qualifies
# Table[0][7] = for (see instructions):
# Table[1][0] = (1) First name
# Table[1][1] = Last name
# Table[1][2] =
# Table[1][3] = number
# Table[1][4] =
# Table[1][5] = to you
# Table[1][6] = Child tax credit
# Table[1][7] = Credit for other dependents
# Table[2][0] = JAY
# Table[2][1] = SMITH
# Table[2][2] =
# Table[2][3] = 135792468
# Table[2][4] =
# Table[2][5] = SON
# Table[2][6] = SELECTED,
# Table[2][7] = NOT_SELECTED,
# Table[3][0] = VICTORIA
# Table[3][1] = SMITH
# Table[3][2] = 246
# Table[3][3] = 81
# Table[3][4] = 3579
# Table[3][5] = DAUGHTER
# Table[3][6] = SELECTED,
# Table[3][7] = NOT_SELECTED,
# Table[4][0] =
# Table[4][1] =
# Table[4][2] =
# Table[4][3] =
# Table[4][4] =
# Table[4][5] =
# Table[4][6] = NOT_SELECTED,
# Table[4][7] = NOT_SELECTED,
# Table[5][0] =
# Table[5][1] =
# Table[5][2] =
# Table[5][3] =
# Table[5][4] =
# Table[5][5] =
# Table[5][6] = NOT_SELECTED,
# Table[5][7] = NOT_SELECTED,
# Table[0][0] = Income
# Table[0][1] = 1a
# Table[0][2] = Total amount from Form(s) W-2,
# Table[0][3] = box 1
# Table[0][4] = (see instructions)
# Table[0][5] =
# Table[0][6] =
# Table[0][7] =
# Table[0][8] = 1a
# Table[0][9] = 100,000
# Table[1][0] =
# Table[1][1] = b
# Table[1][2] = Household employee wages not
# Table[1][3] = reported
# Table[1][4] = on Form(s) W-2
# Table[1][5] =
# Table[1][6] =
# Table[1][7] =
# Table[1][8] = 1b
# Table[1][9] =
# Table[2][0] = Attach Form(s)
# Table[2][1] = c
# Table[2][2] = Tip income not reported on line
# Table[2][3] = 1a (see
# Table[2][4] = instructions)
# Table[2][5] =
# Table[2][6] =
# Table[2][7] =
# Table[2][8] = 1c
# Table[2][9] =
# Table[3][0] = W-2 here. Also attach Forms
# Table[3][1] = d
# Table[3][2] = Medicaid waiver payments not
# Table[3][3] = reported
# Table[3][4] = on Form(s) W-2 (see
# Table[3][5] = instructions)
# Table[3][6] =
# Table[3][7] =
# Table[3][8] = 1d
# Table[3][9] =
# Table[4][0] = W-2G and
# Table[4][1] = e
# Table[4][2] = Taxable dependent care benefits
# Table[4][3] = from
# Table[4][4] = Form 2441, line 26
# Table[4][5] =
# Table[4][6] =
# Table[4][7] =
# Table[4][8] = 1e
# Table[4][9] = 5,000
# Table[5][0] = 1099-R if tax was withheld.
# Table[5][1] = f
# Table[5][2] = Employer-provided adoption
# Table[5][3] = benefits
# Table[5][4] = from Form 8839, line
# Table[5][5] = 29
# Table[5][6] =
# Table[5][7] =
# Table[5][8] = 1f
# Table[5][9] =
# Table[6][0] = If you did not
# Table[6][1] = g
# Table[6][2] = Wages from Form 8919, line 6
# Table[6][3] =
# Table[6][4] =
# Table[6][5] =
# Table[6][6] =
# Table[6][7] =
# Table[6][8] = 1g
# Table[6][9] = apia
# Table[7][0] = get a Form
# Table[7][1] = h
# Table[7][2] = Other earned income (see
# Table[7][3] = instructions)
# Table[7][4] =
# Table[7][5] =
# Table[7][6] =
# Table[7][7] =
# Table[7][8] = 1h
# Table[7][9] =
# Table[8][0] = W-2, see instructions.
# Table[8][1] = i
# Table[8][2] = Nontaxable combat pay election
# Table[8][3] = (see
# Table[8][4] = instructions)
# Table[8][5] =
# Table[8][6] = 1i
# Table[8][7] =
# Table[8][8] =
# Table[8][9] =
# Table[9][0] =
# Table[9][1] = z
# Table[9][2] = Add lines 1a through 1h
# Table[9][3] =
# Table[9][4] =
# Table[9][5] =
# Table[9][6] =
# Table[9][7] =
# Table[9][8] = 1z
# Table[9][9] = 105,000
# Table[10][0] = Attach Sch. B
# Table[10][1] = 2a
# Table[10][2] = Tax-exempt interest
# Table[10][3] = 2a
# Table[10][4] =
# Table[10][5] = b Taxable
# Table[10][6] = interest
# Table[10][7] =
# Table[10][8] = 2b
# Table[10][9] = 6,000
# Table[11][0] = if required.
# Table[11][1] = 3a
# Table[11][2] = Qualified dividends
# Table[11][3] = 3a
# Table[11][4] =
# Table[11][5] = b Ordinary
# Table[11][6] = dividends
# Table[11][7] =
# Table[11][8] = 3b
# Table[11][9] =
# Table[12][0] =
# Table[12][1] = 4a
# Table[12][2] = IRA distributions
# Table[12][3] = 4a
# Table[12][4] =
# Table[12][5] = b Taxable
# Table[12][6] = amount
# Table[12][7] =
# Table[12][8] = 4b
# Table[12][9] =
# Table[13][0] = Standard
# Table[13][1] = 5a
# Table[13][2] = Pensions and annuities
# Table[13][3] = 5a
# Table[13][4] =
# Table[13][5] = b Taxable
# Table[13][6] = amount
# Table[13][7] =
# Table[13][8] = 5b
# Table[13][9] =
# Table[14][0] = Deduction for- Single or
# Table[14][1] = 6a
# Table[14][2] = Social security benefits
# Table[14][3] = 6a
# Table[14][4] =
# Table[14][5] = b Taxable
# Table[14][6] = amount
# Table[14][7] =
# Table[14][8] = 6b
# Table[14][9] =
# Table[15][0] = Married filing
# Table[15][1] = c
# Table[15][2] = If you elect to use the lump-sum
# Table[15][3] = election
# Table[15][4] = method, check
# Table[15][5] = here (see instructions)
# Table[15][6] =
# Table[15][7] = NOT_SELECTED,
# Table[15][8] =
# Table[15][9] =
# Table[16][0] = separately, $12,950
# Table[16][1] = 7
# Table[16][2] = Capital gaín or (loss). Attach
# Table[16][3] = Schedule
# Table[16][4] = D if required. If not
# Table[16][5] = required, check
# Table[16][6] = here
# Table[16][7] = NOT_SELECTED,
# Table[16][8] = 7
# Table[16][9] =
# Table[17][0] = Married filing
# Table[17][1] = 8
# Table[17][2] = Other income from Schedule 1,
# Table[17][3] = line 10
# Table[17][4] =
# Table[17][5] =
# Table[17][6] =
# Table[17][7] =
# Table[17][8] = 8
# Table[17][9] = 111,000
# Table[18][0] = jointly or Qualifying
# Table[18][1] = 9
# Table[18][2] = Add lines 1z, 2b, 3b, 4b, 5b, 6b,
# Table[18][3] = 7, and
# Table[18][4] = 8. This is your total
# Table[18][5] = income
# Table[18][6] =
# Table[18][7] =
# Table[18][8] = 9
# Table[18][9] = 7,000
# Table[19][0] = surviving spouse, $25,900
# Table[19][1] = 10
# Table[19][2] = Adjustments to income from
# Table[19][3] = Schedule
# Table[19][4] = 1, line 26
# Table[19][5] =
# Table[19][6] =
# Table[19][7] =
# Table[19][8] = 10
# Table[19][9] = 104,000
# Table[20][0] = Head of
# Table[20][1] = 11
# Table[20][2] = Subtract line 10 from line 9. This
# Table[20][3] = is your
# Table[20][4] = adjusted gross
# Table[20][5] = income
# Table[20][6] =
# Table[20][7] =
# Table[20][8] = 11
# Table[20][9] =
# Table[21][0] = household, $19,400
# Table[21][1] = 12
# Table[21][2] = Standard deduction or Itemized
# Table[21][3] =
# Table[21][4] = deductions (from Schedule
# Table[21][5] = A)
# Table[21][6] =
# Table[21][7] =
# Table[21][8] = 12
# Table[21][9] =
# Table[22][0] = If you checked box under
# Table[22][1] = 13
# Table[22][2] = Qualified business income deduction
# Table[22][3] =
# Table[22][4] = from Form 8995 or
# Table[22][5] = Form 8995-A
# Table[22][6] =
# Table[22][7] =
# Table[22][8] = 13
# Table[22][9] =
# Table[23][0] = any Standard
# Table[23][1] = 14
# Table[23][2] = Add lines 12 and 13
# Table[23][3] =
# Table[23][4] =
# Table[23][5] =
# Table[23][6] =
# Table[23][7] =
# Table[23][8] = 14
# Table[23][9] = 12,000
# Table[24][0] = Deduction, see instructions.
# Table[24][1] = 15
# Table[24][2] = Subtract line 14 from line 11. If
# Table[24][3] = zero or
# Table[24][4] = less, enter -0-. This
# Table[24][5] = is your taxable
# Table[24][6] = income
# Table[24][7] =
# Table[24][8] = 15
# Table[24][9] = 92,000
# Table[25][0] =
# Table[25][1] =
# Table[25][2] =
# Table[25][3] =
# Table[25][4] =
# Table[25][5] =
# Table[25][6] =
# Table[25][7] =
# Table[25][8] =
# Table[25][9] =
# {
#     "Married filing jointly": {
#         "value": "SELECTED",
#         "confidence": 93.80208587646484
#     },
#     "Were born before January 2, 1958": {
#         "value": "NOT_SELECTED",
#         "confidence": 93.31975555419922
#     },
#     "Married filing separately (MFS)": {
#         "value": "NOT_SELECTED",
#         "confidence": 92.85863494873047
#     },
#     "Head of household (HOH)": {
#         "value": "NOT_SELECTED",
#         "confidence": 92.73064422607422
#     },
#     "Single": {
#         "value": "NOT_SELECTED",
#         "confidence": 90.8843002319336
#     },
#     "You as a dependent": {
#         "value": "NOT_SELECTED",
#         "confidence": 88.05580139160156
#     }
# }

# %%
print(json_data)
# Out:
# {
#     "Married filing jointly": {
#         "value": "SELECTED",
#         "confidence": 93.80208587646484
#     },
#     "Were born before January 2, 1958": {
#         "value": "NOT_SELECTED",
#         "confidence": 93.31975555419922
#     },
#     "Married filing separately (MFS)": {
#         "value": "NOT_SELECTED",
#         "confidence": 92.85863494873047
#     },
#     "Head of household (HOH)": {
#         "value": "NOT_SELECTED",
#         "confidence": 92.73064422607422
#     },
#     "Single": {
#         "value": "NOT_SELECTED",
#         "confidence": 90.8843002319336
#     },
#     "You as a dependent": {
#         "value": "NOT_SELECTED",
#         "confidence": 88.05580139160156
#     }
# }

# %%
# Parse JSON data to a dictionary
fields_dict = json.loads(json_data)

# Convert dictionary to DataFrame
data = []
for key, values in fields_dict.items():
    data.append([key, values["value"], values["confidence"]])

dff = pd.DataFrame(data, columns=["Key", "Value", "Confidence"])

dff
# Out:
#                                 Key         Value  Confidence
# 0            Married filing jointly      SELECTED   93.802086
# 1  Were born before January 2, 1958  NOT_SELECTED   93.319756
# 2   Married filing separately (MFS)  NOT_SELECTED   92.858635
# 3           Head of household (HOH)  NOT_SELECTED   92.730644
# 4                            Single  NOT_SELECTED   90.884300
# 5                You as a dependent  NOT_SELECTED   88.055801

# %%
from trp import Document
import json
# Create a dictionary to store fields and values
fields_dict = {}

# Parse JSON response from Textract
doc = Document(response)

# Iterate over elements in the document
for page in doc.pages:
    # Print lines and words
    for line in page.lines:
        print("Line: {}".format(line.text))
        for word in line.words:
            print("Word: {}".format(word.text))

    # Print tables
    for table in page.tables:
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}".format(r, c, cell.text))
# Out:
# Line: 1040
# Word: 1040
# Line: Department of the Treasury - Internal Revenue Service
# Word: Department
# Word: of
# Word: the
# Word: Treasury
# Word: -
# Word: Internal
# Word: Revenue
# Word: Service
# Line: U.S. Individual Income Tax Return
# Word: U.S.
# Word: Individual
# Word: Income
# Word: Tax
# Word: Return
# Line: 2022
# Word: 2022
# Line: OMB No. 1545-0074
# Word: OMB
# Word: No.
# Word: 1545-0074
# Line: IRS Use Only-Do not write or staple in this space.
# Word: IRS
# Word: Use
# Word: Only-Do
# Word: not
# Word: write
# Word: or
# Word: staple
# Word: in
# Word: this
# Word: space.
# Line: Filing Status
# Word: Filing
# Word: Status
# Line: Single
# Word: Single
# Line: Married filing jointly
# Word: Married
# Word: filing
# Word: jointly
# Line: Married filing separately (MFS)
# Word: Married
# Word: filing
# Word: separately
# Word: (MFS)
# Line: Head of household (HOH)
# Word: Head
# Word: of
# Word: household
# Word: (HOH)
# Line: Qualifying surviving
# Word: Qualifying
# Word: surviving
# Line: Check only
# Word: Check
# Word: only
# Line: spouse (QSS)
# Word: spouse
# Word: (QSS)
# Line: one box.
# Word: one
# Word: box.
# Line: If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child's name if the qualifying
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: MFS
# Word: box,
# Word: enter
# Word: the
# Word: name
# Word: of
# Word: your
# Word: spouse.
# Word: If
# Word: you
# Word: checked
# Word: the
# Word: HOH
# Word: or
# Word: QSS
# Word: box,
# Word: enter
# Word: the
# Word: child's
# Word: name
# Word: if
# Word: the
# Word: qualifying
# Line: person is a child but not your dependent:
# Word: person
# Word: is
# Word: a
# Word: child
# Word: but
# Word: not
# Word: your
# Word: dependent:
# Line: Your first name and middle initial
# Word: Your
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Your social security number
# Word: Your
# Word: social
# Word: security
# Word: number
# Line: JOHN J
# Word: JOHN
# Word: J
# Line: SMITH
# Word: SMITH
# Line: 123 45 6789
# Word: 123 45 6789
# Line: If joint return, spouse's first name and middle initial
# Word: If
# Word: joint
# Word: return,
# Word: spouse's
# Word: first
# Word: name
# Word: and
# Word: middle
# Word: initial
# Line: Last name
# Word: Last
# Word: name
# Line: Spouse's social security number
# Word: Spouse's
# Word: social
# Word: security
# Word: number
# Line: JANE K
# Word: JANE
# Word: K
# Line: SMITH
# Word: SMITH
# Line: 9871654321
# Word: 9871654321
# Line: Home address (number and street). If you have a P.O. box, see instructions.
# Word: Home
# Word: address
# Word: (number
# Word: and
# Word: street).
# Word: If
# Word: you
# Word: have
# Word: a
# Word: P.O.
# Word: box,
# Word: see
# Word: instructions.
# Line: Apt. no.
# Word: Apt.
# Word: no.
# Line: Presidential Election Campaign
# Word: Presidential
# Word: Election
# Word: Campaign
# Line: 1040 N PHOENIX RD
# Word: 1040
# Word: N
# Word: PHOENIX
# Word: RD
# Line: Check here if you, or your
# Word: Check
# Word: here
# Word: if
# Word: you,
# Word: or
# Word: your
# Line: City, town, or post office. If you have a foreign address, also complete spaces below.
# Word: City,
# Word: town,
# Word: or
# Word: post
# Word: office.
# Word: If
# Word: you
# Word: have
# Word: a
# Word: foreign
# Word: address,
# Word: also
# Word: complete
# Word: spaces
# Word: below.
# Line: State
# Word: State
# Line: ZIP code
# Word: ZIP
# Word: code
# Line: spouse if filing jointly, want $3
# Word: spouse
# Word: if
# Word: filing
# Word: jointly,
# Word: want
# Word: $3
# Line: GLENDALE
# Word: GLENDALE
# Line: A2
# Word: A2
# Line: 85308
# Word: 85308
# Line: to go to this fund. Checking a
# Word: to
# Word: go
# Word: to
# Word: this
# Word: fund.
# Word: Checking
# Word: a
# Line: box below will not change
# Word: box
# Word: below
# Word: will
# Word: not
# Word: change
# Line: Foreign country name
# Word: Foreign
# Word: country
# Word: name
# Line: Foreign province/state/county
# Word: Foreign
# Word: province/state/county
# Line: Foreign postal code
# Word: Foreign
# Word: postal
# Word: code
# Line: your tax or refund.
# Word: your
# Word: tax
# Word: or
# Word: refund.
# Line: You
# Word: You
# Line: Spouse
# Word: Spouse
# Line: Digital
# Word: Digital
# Line: At any time during 2022, did you: (a) receive (as a reward, award, or payment for property or services); or (b) sell,
# Word: At
# Word: any
# Word: time
# Word: during
# Word: 2022,
# Word: did
# Word: you:
# Word: (a)
# Word: receive
# Word: (as
# Word: a
# Word: reward,
# Word: award,
# Word: or
# Word: payment
# Word: for
# Word: property
# Word: or
# Word: services);
# Word: or
# Word: (b)
# Word: sell,
# Line: Assets
# Word: Assets
# Line: exchange, gift, or otherwise dispose of a digital asset (or a financial interest in a digital asset)? (See instructions.)
# Word: exchange,
# Word: gift,
# Word: or
# Word: otherwise
# Word: dispose
# Word: of
# Word: a
# Word: digital
# Word: asset
# Word: (or
# Word: a
# Word: financial
# Word: interest
# Word: in
# Word: a
# Word: digital
# Word: asset)?
# Word: (See
# Word: instructions.)
# Line: Yes
# Word: Yes
# Line: No
# Word: No
# Line: Standard
# Word: Standard
# Line: Someone can claim:
# Word: Someone
# Word: can
# Word: claim:
# Line: You as a dependent
# Word: You
# Word: as
# Word: a
# Word: dependent
# Line: Your spouse as a dependent
# Word: Your
# Word: spouse
# Word: as
# Word: a
# Word: dependent
# Line: Deduction
# Word: Deduction
# Line: Spouse itemizes on a separate return or you were a dual-status alien
# Word: Spouse
# Word: itemizes
# Word: on
# Word: a
# Word: separate
# Word: return
# Word: or
# Word: you
# Word: were
# Word: a
# Word: dual-status
# Word: alien
# Line: Age/Blindness You:
# Word: Age/Blindness
# Word: You:
# Line: Were born before January 2, 1958
# Word: Were
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Are blind
# Word: Are
# Word: blind
# Line: Spouse:
# Word: Spouse:
# Line: Was born before January 2, 1958
# Word: Was
# Word: born
# Word: before
# Word: January
# Word: 2,
# Word: 1958
# Line: Is blind
# Word: Is
# Word: blind
# Line: Dependents (see instructions):
# Word: Dependents
# Word: (see
# Word: instructions):
# Line: (2) Social security
# Word: (2)
# Word: Social
# Word: security
# Line: (3) Relationship
# Word: (3)
# Word: Relationship
# Line: (4) Check the box if qualifies for (see instructions):
# Word: (4)
# Word: Check
# Word: the
# Word: box
# Word: if
# Word: qualifies
# Word: for
# Word: (see
# Word: instructions):
# Line: If more
# Word: If
# Word: more
# Line: (1) First name
# Word: (1)
# Word: First
# Word: name
# Line: Last name
# Word: Last
# Word: name
# Line: number
# Word: number
# Line: to you
# Word: to
# Word: you
# Line: Child tax credit
# Word: Child
# Word: tax
# Word: credit
# Line: Credit for other dependents
# Word: Credit
# Word: for
# Word: other
# Word: dependents
# Line: than four
# Word: than
# Word: four
# Line: JAY
# Word: JAY
# Line: SMITH
# Word: SMITH
# Line: 135792468
# Word: 135792468
# Line: SON
# Word: SON
# Line: dependents,
# Word: dependents,
# Line: see instructions
# Word: see
# Word: instructions
# Line: VICTORIA
# Word: VICTORIA
# Line: SMITH
# Word: SMITH
# Line: 246
# Word: 246
# Line: 81
# Word: 81
# Line: 3579
# Word: 3579
# Line: DAUGHTER
# Word: DAUGHTER
# Line: and check
# Word: and
# Word: check
# Line: here
# Word: here
# Line: Income
# Word: Income
# Line: 1a Total amount from Form(s) W-2, box 1 (see instructions)
# Word: 1a
# Word: Total
# Word: amount
# Word: from
# Word: Form(s)
# Word: W-2,
# Word: box
# Word: 1
# Word: (see
# Word: instructions)
# Line: 1a
# Word: 1a
# Line: 100,000
# Word: 100,000
# Line: b Household employee wages not reported on Form(s) W-2
# Word: b
# Word: Household
# Word: employee
# Word: wages
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Line: 1b
# Word: 1b
# Line: Attach Form(s)
# Word: Attach
# Word: Form(s)
# Line: c Tip income not reported on line 1a (see instructions)
# Word: c
# Word: Tip
# Word: income
# Word: not
# Word: reported
# Word: on
# Word: line
# Word: 1a
# Word: (see
# Word: instructions)
# Line: 1c
# Word: 1c
# Line: W-2 here. Also
# Word: W-2
# Word: here.
# Word: Also
# Line: attach Forms
# Word: attach
# Word: Forms
# Line: d Medicaid waiver payments not reported on Form(s) W-2 (see instructions)
# Word: d
# Word: Medicaid
# Word: waiver
# Word: payments
# Word: not
# Word: reported
# Word: on
# Word: Form(s)
# Word: W-2
# Word: (see
# Word: instructions)
# Line: 1d
# Word: 1d
# Line: W-2G and
# Word: W-2G
# Word: and
# Line: e Taxable dependent care benefits from Form 2441, line 26
# Word: e
# Word: Taxable
# Word: dependent
# Word: care
# Word: benefits
# Word: from
# Word: Form
# Word: 2441,
# Word: line
# Word: 26
# Line: 1e
# Word: 1e
# Line: 1099-R if tax
# Word: 1099-R
# Word: if
# Word: tax
# Line: 5,000
# Word: 5,000
# Line: was withheld.
# Word: was
# Word: withheld.
# Line: f Employer-provided adoption benefits from Form 8839, line 29
# Word: f
# Word: Employer-provided
# Word: adoption
# Word: benefits
# Word: from
# Word: Form
# Word: 8839,
# Word: line
# Word: 29
# Line: 1f
# Word: 1f
# Line: If you did not
# Word: If
# Word: you
# Word: did
# Word: not
# Line: g Wages from Form 8919, line 6
# Word: g
# Word: Wages
# Word: from
# Word: Form
# Word: 8919,
# Word: line
# Word: 6
# Line: 1g
# Word: 1g
# Line: apia
# Word: apia
# Line: get a Form
# Word: get
# Word: a
# Word: Form
# Line: h Other earned income (see instructions)
# Word: h
# Word: Other
# Word: earned
# Word: income
# Word: (see
# Word: instructions)
# Line: 1h
# Word: 1h
# Line: W-2, see
# Word: W-2,
# Word: see
# Line: i
# Word: i
# Line: instructions.
# Word: instructions.
# Line: Nontaxable combat pay election (see instructions)
# Word: Nontaxable
# Word: combat
# Word: pay
# Word: election
# Word: (see
# Word: instructions)
# Line: 1i
# Word: 1i
# Line: z Add lines 1a through 1h
# Word: z
# Word: Add
# Word: lines
# Word: 1a
# Word: through
# Word: 1h
# Line: 1z
# Word: 1z
# Line: 105,000
# Word: 105,000
# Line: Attach Sch. B
# Word: Attach
# Word: Sch.
# Word: B
# Line: 2a
# Word: 2a
# Line: Tax-exempt interest
# Word: Tax-exempt
# Word: interest
# Line: 2a
# Word: 2a
# Line: b Taxable interest
# Word: b
# Word: Taxable
# Word: interest
# Line: 2b
# Word: 2b
# Line: 6,000
# Word: 6,000
# Line: if required.
# Word: if
# Word: required.
# Line: 3a
# Word: 3a
# Line: Qualified dividends
# Word: Qualified
# Word: dividends
# Line: 3a
# Word: 3a
# Line: b Ordinary dividends
# Word: b
# Word: Ordinary
# Word: dividends
# Line: 3b
# Word: 3b
# Line: 4a IRA distributions
# Word: 4a
# Word: IRA
# Word: distributions
# Line: 4a
# Word: 4a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 4b
# Word: 4b
# Line: Standard
# Word: Standard
# Line: 5a Pensions and annuities
# Word: 5a
# Word: Pensions
# Word: and
# Word: annuities
# Line: 5a
# Word: 5a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 5b
# Word: 5b
# Line: Deduction for-
# Word: Deduction
# Word: for-
# Line: 6a
# Word: 6a
# Line: Social security benefits
# Word: Social
# Word: security
# Word: benefits
# Line: 6a
# Word: 6a
# Line: b Taxable amount
# Word: b
# Word: Taxable
# Word: amount
# Line: 6b
# Word: 6b
# Line: Single or
# Word: Single
# Word: or
# Line: Married filing
# Word: Married
# Word: filing
# Line: c
# Word: c
# Line: If you elect to use the lump-sum election method, check here (see instructions)
# Word: If
# Word: you
# Word: elect
# Word: to
# Word: use
# Word: the
# Word: lump-sum
# Word: election
# Word: method,
# Word: check
# Word: here
# Word: (see
# Word: instructions)
# Line: separately,
# Word: separately,
# Line: $12,950
# Word: $12,950
# Line: 7
# Word: 7
# Line: Capital gaín or (loss). Attach Schedule D if required. If not required, check here
# Word: Capital
# Word: gaín
# Word: or
# Word: (loss).
# Word: Attach
# Word: Schedule
# Word: D
# Word: if
# Word: required.
# Word: If
# Word: not
# Word: required,
# Word: check
# Word: here
# Line: 7
# Word: 7
# Line: Married filing
# Word: Married
# Word: filing
# Line: 8
# Word: 8
# Line: Other income from Schedule 1, line 10
# Word: Other
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 10
# Line: 8
# Word: 8
# Line: 111,000
# Word: 111,000
# Line: jointly or
# Word: jointly
# Word: or
# Line: Qualifying
# Word: Qualifying
# Line: 9
# Word: 9
# Line: Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income
# Word: Add
# Word: lines
# Word: 1z,
# Word: 2b,
# Word: 3b,
# Word: 4b,
# Word: 5b,
# Word: 6b,
# Word: 7,
# Word: and
# Word: 8.
# Word: This
# Word: is
# Word: your
# Word: total
# Word: income
# Line: 9
# Word: 9
# Line: 7,000
# Word: 7,000
# Line: surviving spouse,
# Word: surviving
# Word: spouse,
# Line: 10
# Word: 10
# Line: $25,900
# Word: $25,900
# Line: Adjustments to income from Schedule 1, line 26
# Word: Adjustments
# Word: to
# Word: income
# Word: from
# Word: Schedule
# Word: 1,
# Word: line
# Word: 26
# Line: 10
# Word: 10
# Line: 104,000
# Word: 104,000
# Line: Head of
# Word: Head
# Word: of
# Line: 11
# Word: 11
# Line: Subtract line 10 from line 9. This is your adjusted gross income
# Word: Subtract
# Word: line
# Word: 10
# Word: from
# Word: line
# Word: 9.
# Word: This
# Word: is
# Word: your
# Word: adjusted
# Word: gross
# Word: income
# Line: 11
# Word: 11
# Line: household,
# Word: household,
# Line: $19,400
# Word: $19,400
# Line: 12
# Word: 12
# Line: Standard deduction or Itemized deductions (from Schedule A)
# Word: Standard
# Word: deduction
# Word: or
# Word: Itemized
# Word: deductions
# Word: (from
# Word: Schedule
# Word: A)
# Line: 12
# Word: 12
# Line: If you checked
# Word: If
# Word: you
# Word: checked
# Line: 13
# Word: 13
# Line: Qualified business income deduction from Form 8995 or Form 8995-A
# Word: Qualified
# Word: business
# Word: income
# Word: deduction
# Word: from
# Word: Form
# Word: 8995
# Word: or
# Word: Form
# Word: 8995-A
# Line: 13
# Word: 13
# Line: any box under
# Word: any
# Word: box
# Word: under
# Line: Standard
# Word: Standard
# Line: 14
# Word: 14
# Line: Add lines 12 and 13
# Word: Add
# Word: lines
# Word: 12
# Word: and
# Word: 13
# Line: 14
# Word: 14
# Line: 12,000
# Word: 12,000
# Line: Deduction,
# Word: Deduction,
# Line: 15
# Word: 15
# Line: see instructions.
# Word: see
# Word: instructions.
# Line: Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income
# Word: Subtract
# Word: line
# Word: 14
# Word: from
# Word: line
# Word: 11.
# Word: If
# Word: zero
# Word: or
# Word: less,
# Word: enter
# Word: -0-.
# Word: This
# Word: is
# Word: your
# Word: taxable
# Word: income
# Line: 15
# Word: 15
# Line: 92,000
# Word: 92,000
# Line: For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.
# Word: For
# Word: Disclosure,
# Word: Privacy
# Word: Act,
# Word: and
# Word: Paperwork
# Word: Reduction
# Word: Act
# Word: Notice,
# Word: see
# Word: separate
# Word: instructions.
# Line: Cat. No. 11320B
# Word: Cat.
# Word: No.
# Word: 11320B
# Line: Form
# Word: Form
# Line: 1040
# Word: 1040
# Line: (2022)
# Word: (2022)
# Table[0][0] = Your first name and middle initial
# Table[0][1] = Last name
# Table[1][0] = JOHN J
# Table[1][1] = SMITH
# Table[2][0] = If joint return, spouse's first name and middle initial
# Table[2][1] = Last name
# Table[3][0] = JANE K
# Table[3][1] = SMITH
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions.
# Table[0][1] = Apt. no.
# Table[1][0] = 1040 N PHOENIX RD
# Table[1][1] =
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below.
# Table[0][1] = State
# Table[0][2] = ZIP code
# Table[1][0] = GLENDALE
# Table[1][1] = A2
# Table[1][2] = 85308
# Table[0][0] = Foreign country name
# Table[0][1] = Foreign province/state/county
# Table[0][2] = Foreign postal code
# Table[1][0] =
# Table[1][1] =
# Table[1][2] =
# Table[0][0] = (see instructions):
# Table[0][1] =
# Table[0][2] = (2)
# Table[0][3] = Social
# Table[0][4] = security
# Table[0][5] = (3) Relationship
# Table[0][6] = (4) Check the box if qualifies
# Table[0][7] = for (see instructions):
# Table[1][0] = (1) First name
# Table[1][1] = Last name
# Table[1][2] =
# Table[1][3] = number
# Table[1][4] =
# Table[1][5] = to you
# Table[1][6] = Child tax credit
# Table[1][7] = Credit for other dependents
# Table[2][0] = JAY
# Table[2][1] = SMITH
# Table[2][2] =
# Table[2][3] = 135792468
# Table[2][4] =
# Table[2][5] = SON
# Table[2][6] = SELECTED,
# Table[2][7] = NOT_SELECTED,
# Table[3][0] = VICTORIA
# Table[3][1] = SMITH
# Table[3][2] = 246
# Table[3][3] = 81
# Table[3][4] = 3579
# Table[3][5] = DAUGHTER
# Table[3][6] = SELECTED,
# Table[3][7] = NOT_SELECTED,
# Table[4][0] =
# Table[4][1] =
# Table[4][2] =
# Table[4][3] =
# Table[4][4] =
# Table[4][5] =
# Table[4][6] = NOT_SELECTED,
# Table[4][7] = NOT_SELECTED,
# Table[5][0] =
# Table[5][1] =
# Table[5][2] =
# Table[5][3] =
# Table[5][4] =
# Table[5][5] =
# Table[5][6] = NOT_SELECTED,
# Table[5][7] = NOT_SELECTED,
# Table[0][0] = Income
# Table[0][1] = 1a
# Table[0][2] = Total amount from Form(s) W-2,
# Table[0][3] = box 1
# Table[0][4] = (see instructions)
# Table[0][5] =
# Table[0][6] =
# Table[0][7] =
# Table[0][8] = 1a
# Table[0][9] = 100,000
# Table[1][0] =
# Table[1][1] = b
# Table[1][2] = Household employee wages not
# Table[1][3] = reported
# Table[1][4] = on Form(s) W-2
# Table[1][5] =
# Table[1][6] =
# Table[1][7] =
# Table[1][8] = 1b
# Table[1][9] =
# Table[2][0] = Attach Form(s)
# Table[2][1] = c
# Table[2][2] = Tip income not reported on line
# Table[2][3] = 1a (see
# Table[2][4] = instructions)
# Table[2][5] =
# Table[2][6] =
# Table[2][7] =
# Table[2][8] = 1c
# Table[2][9] =
# Table[3][0] = W-2 here. Also attach Forms
# Table[3][1] = d
# Table[3][2] = Medicaid waiver payments not
# Table[3][3] = reported
# Table[3][4] = on Form(s) W-2 (see
# Table[3][5] = instructions)
# Table[3][6] =
# Table[3][7] =
# Table[3][8] = 1d
# Table[3][9] =
# Table[4][0] = W-2G and
# Table[4][1] = e
# Table[4][2] = Taxable dependent care benefits
# Table[4][3] = from
# Table[4][4] = Form 2441, line 26
# Table[4][5] =
# Table[4][6] =
# Table[4][7] =
# Table[4][8] = 1e
# Table[4][9] = 5,000
# Table[5][0] = 1099-R if tax was withheld.
# Table[5][1] = f
# Table[5][2] = Employer-provided adoption
# Table[5][3] = benefits
# Table[5][4] = from Form 8839, line
# Table[5][5] = 29
# Table[5][6] =
# Table[5][7] =
# Table[5][8] = 1f
# Table[5][9] =
# Table[6][0] = If you did not
# Table[6][1] = g
# Table[6][2] = Wages from Form 8919, line 6
# Table[6][3] =
# Table[6][4] =
# Table[6][5] =
# Table[6][6] =
# Table[6][7] =
# Table[6][8] = 1g
# Table[6][9] = apia
# Table[7][0] = get a Form
# Table[7][1] = h
# Table[7][2] = Other earned income (see
# Table[7][3] = instructions)
# Table[7][4] =
# Table[7][5] =
# Table[7][6] =
# Table[7][7] =
# Table[7][8] = 1h
# Table[7][9] =
# Table[8][0] = W-2, see instructions.
# Table[8][1] = i
# Table[8][2] = Nontaxable combat pay election
# Table[8][3] = (see
# Table[8][4] = instructions)
# Table[8][5] =
# Table[8][6] = 1i
# Table[8][7] =
# Table[8][8] =
# Table[8][9] =
# Table[9][0] =
# Table[9][1] = z
# Table[9][2] = Add lines 1a through 1h
# Table[9][3] =
# Table[9][4] =
# Table[9][5] =
# Table[9][6] =
# Table[9][7] =
# Table[9][8] = 1z
# Table[9][9] = 105,000
# Table[10][0] = Attach Sch. B
# Table[10][1] = 2a
# Table[10][2] = Tax-exempt interest
# Table[10][3] = 2a
# Table[10][4] =
# Table[10][5] = b Taxable
# Table[10][6] = interest
# Table[10][7] =
# Table[10][8] = 2b
# Table[10][9] = 6,000
# Table[11][0] = if required.
# Table[11][1] = 3a
# Table[11][2] = Qualified dividends
# Table[11][3] = 3a
# Table[11][4] =
# Table[11][5] = b Ordinary
# Table[11][6] = dividends
# Table[11][7] =
# Table[11][8] = 3b
# Table[11][9] =
# Table[12][0] =
# Table[12][1] = 4a
# Table[12][2] = IRA distributions
# Table[12][3] = 4a
# Table[12][4] =
# Table[12][5] = b Taxable
# Table[12][6] = amount
# Table[12][7] =
# Table[12][8] = 4b
# Table[12][9] =
# Table[13][0] = Standard
# Table[13][1] = 5a
# Table[13][2] = Pensions and annuities
# Table[13][3] = 5a
# Table[13][4] =
# Table[13][5] = b Taxable
# Table[13][6] = amount
# Table[13][7] =
# Table[13][8] = 5b
# Table[13][9] =
# Table[14][0] = Deduction for- Single or
# Table[14][1] = 6a
# Table[14][2] = Social security benefits
# Table[14][3] = 6a
# Table[14][4] =
# Table[14][5] = b Taxable
# Table[14][6] = amount
# Table[14][7] =
# Table[14][8] = 6b
# Table[14][9] =
# Table[15][0] = Married filing
# Table[15][1] = c
# Table[15][2] = If you elect to use the lump-sum
# Table[15][3] = election
# Table[15][4] = method, check
# Table[15][5] = here (see instructions)
# Table[15][6] =
# Table[15][7] = NOT_SELECTED,
# Table[15][8] =
# Table[15][9] =
# Table[16][0] = separately, $12,950
# Table[16][1] = 7
# Table[16][2] = Capital gaín or (loss). Attach
# Table[16][3] = Schedule
# Table[16][4] = D if required. If not
# Table[16][5] = required, check
# Table[16][6] = here
# Table[16][7] = NOT_SELECTED,
# Table[16][8] = 7
# Table[16][9] =
# Table[17][0] = Married filing
# Table[17][1] = 8
# Table[17][2] = Other income from Schedule 1,
# Table[17][3] = line 10
# Table[17][4] =
# Table[17][5] =
# Table[17][6] =
# Table[17][7] =
# Table[17][8] = 8
# Table[17][9] = 111,000
# Table[18][0] = jointly or Qualifying
# Table[18][1] = 9
# Table[18][2] = Add lines 1z, 2b, 3b, 4b, 5b, 6b,
# Table[18][3] = 7, and
# Table[18][4] = 8. This is your total
# Table[18][5] = income
# Table[18][6] =
# Table[18][7] =
# Table[18][8] = 9
# Table[18][9] = 7,000
# Table[19][0] = surviving spouse, $25,900
# Table[19][1] = 10
# Table[19][2] = Adjustments to income from
# Table[19][3] = Schedule
# Table[19][4] = 1, line 26
# Table[19][5] =
# Table[19][6] =
# Table[19][7] =
# Table[19][8] = 10
# Table[19][9] = 104,000
# Table[20][0] = Head of
# Table[20][1] = 11
# Table[20][2] = Subtract line 10 from line 9. This
# Table[20][3] = is your
# Table[20][4] = adjusted gross
# Table[20][5] = income
# Table[20][6] =
# Table[20][7] =
# Table[20][8] = 11
# Table[20][9] =
# Table[21][0] = household, $19,400
# Table[21][1] = 12
# Table[21][2] = Standard deduction or Itemized
# Table[21][3] =
# Table[21][4] = deductions (from Schedule
# Table[21][5] = A)
# Table[21][6] =
# Table[21][7] =
# Table[21][8] = 12
# Table[21][9] =
# Table[22][0] = If you checked box under
# Table[22][1] = 13
# Table[22][2] = Qualified business income deduction
# Table[22][3] =
# Table[22][4] = from Form 8995 or
# Table[22][5] = Form 8995-A
# Table[22][6] =
# Table[22][7] =
# Table[22][8] = 13
# Table[22][9] =
# Table[23][0] = any Standard
# Table[23][1] = 14
# Table[23][2] = Add lines 12 and 13
# Table[23][3] =
# Table[23][4] =
# Table[23][5] =
# Table[23][6] =
# Table[23][7] =
# Table[23][8] = 14
# Table[23][9] = 12,000
# Table[24][0] = Deduction, see instructions.
# Table[24][1] = 15
# Table[24][2] = Subtract line 14 from line 11. If
# Table[24][3] = zero or
# Table[24][4] = less, enter -0-. This
# Table[24][5] = is your taxable
# Table[24][6] = income
# Table[24][7] =
# Table[24][8] = 15
# Table[24][9] = 92,000
# Table[25][0] =
# Table[25][1] =
# Table[25][2] =
# Table[25][3] =
# Table[25][4] =
# Table[25][5] =
# Table[25][6] =
# Table[25][7] =
# Table[25][8] =
# Table[25][9] =

# %%
    # Print tables
    for table in page.tables:
        print("Table Confidence Score: {}".format(table.confidence))  # Print the confidence score of the table
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}".format(r, c, cell.text))
# Out:
# Table Confidence Score: 100.0
# Table[0][0] = Your first name and middle initial
# Table[0][1] = Last name
# Table[1][0] = JOHN J
# Table[1][1] = SMITH
# Table[2][0] = If joint return, spouse's first name and middle initial
# Table[2][1] = Last name
# Table[3][0] = JANE K
# Table[3][1] = SMITH
# Table Confidence Score: 99.951171875
# Table[0][0] = Home address (number and street). If you have a P.O. box, see instructions.
# Table[0][1] = Apt. no.
# Table[1][0] = 1040 N PHOENIX RD
# Table[1][1] =
# Table Confidence Score: 100.0
# Table[0][0] = City, town, or post office. If you have a foreign address, also complete spaces below.
# Table[0][1] = State
# Table[0][2] = ZIP code
# Table[1][0] = GLENDALE
# Table[1][1] = A2
# Table[1][2] = 85308
# Table Confidence Score: 99.8046875
# Table[0][0] = Foreign country name
# Table[0][1] = Foreign province/state/county
# Table[0][2] = Foreign postal code
# Table[1][0] =
# Table[1][1] =
# Table[1][2] =
# Table Confidence Score: 100.0
# Table[0][0] = (see instructions):
# Table[0][1] =
# Table[0][2] = (2)
# Table[0][3] = Social
# Table[0][4] = security
# Table[0][5] = (3) Relationship
# Table[0][6] = (4) Check the box if qualifies
# Table[0][7] = for (see instructions):
# Table[1][0] = (1) First name
# Table[1][1] = Last name
# Table[1][2] =
# Table[1][3] = number
# Table[1][4] =
# Table[1][5] = to you
# Table[1][6] = Child tax credit
# Table[1][7] = Credit for other dependents
# Table[2][0] = JAY
# Table[2][1] = SMITH
# Table[2][2] =
# Table[2][3] = 135792468
# Table[2][4] =
# Table[2][5] = SON
# Table[2][6] = SELECTED,
# Table[2][7] = NOT_SELECTED,
# Table[3][0] = VICTORIA
# Table[3][1] = SMITH
# Table[3][2] = 246
# Table[3][3] = 81
# Table[3][4] = 3579
# Table[3][5] = DAUGHTER
# Table[3][6] = SELECTED,
# Table[3][7] = NOT_SELECTED,
# Table[4][0] =
# Table[4][1] =
# Table[4][2] =
# Table[4][3] =
# Table[4][4] =
# Table[4][5] =
# Table[4][6] = NOT_SELECTED,
# Table[4][7] = NOT_SELECTED,
# Table[5][0] =
# Table[5][1] =
# Table[5][2] =
# Table[5][3] =
# Table[5][4] =
# Table[5][5] =
# Table[5][6] = NOT_SELECTED,
# Table[5][7] = NOT_SELECTED,
# Table Confidence Score: 100.0
# Table[0][0] = Income
# Table[0][1] = 1a
# Table[0][2] = Total amount from Form(s) W-2,
# Table[0][3] = box 1
# Table[0][4] = (see instructions)
# Table[0][5] =
# Table[0][6] =
# Table[0][7] =
# Table[0][8] = 1a
# Table[0][9] = 100,000
# Table[1][0] =
# Table[1][1] = b
# Table[1][2] = Household employee wages not
# Table[1][3] = reported
# Table[1][4] = on Form(s) W-2
# Table[1][5] =
# Table[1][6] =
# Table[1][7] =
# Table[1][8] = 1b
# Table[1][9] =
# Table[2][0] = Attach Form(s)
# Table[2][1] = c
# Table[2][2] = Tip income not reported on line
# Table[2][3] = 1a (see
# Table[2][4] = instructions)
# Table[2][5] =
# Table[2][6] =
# Table[2][7] =
# Table[2][8] = 1c
# Table[2][9] =
# Table[3][0] = W-2 here. Also attach Forms
# Table[3][1] = d
# Table[3][2] = Medicaid waiver payments not
# Table[3][3] = reported
# Table[3][4] = on Form(s) W-2 (see
# Table[3][5] = instructions)
# Table[3][6] =
# Table[3][7] =
# Table[3][8] = 1d
# Table[3][9] =
# Table[4][0] = W-2G and
# Table[4][1] = e
# Table[4][2] = Taxable dependent care benefits
# Table[4][3] = from
# Table[4][4] = Form 2441, line 26
# Table[4][5] =
# Table[4][6] =
# Table[4][7] =
# Table[4][8] = 1e
# Table[4][9] = 5,000
# Table[5][0] = 1099-R if tax was withheld.
# Table[5][1] = f
# Table[5][2] = Employer-provided adoption
# Table[5][3] = benefits
# Table[5][4] = from Form 8839, line
# Table[5][5] = 29
# Table[5][6] =
# Table[5][7] =
# Table[5][8] = 1f
# Table[5][9] =
# Table[6][0] = If you did not
# Table[6][1] = g
# Table[6][2] = Wages from Form 8919, line 6
# Table[6][3] =
# Table[6][4] =
# Table[6][5] =
# Table[6][6] =
# Table[6][7] =
# Table[6][8] = 1g
# Table[6][9] = apia
# Table[7][0] = get a Form
# Table[7][1] = h
# Table[7][2] = Other earned income (see
# Table[7][3] = instructions)
# Table[7][4] =
# Table[7][5] =
# Table[7][6] =
# Table[7][7] =
# Table[7][8] = 1h
# Table[7][9] =
# Table[8][0] = W-2, see instructions.
# Table[8][1] = i
# Table[8][2] = Nontaxable combat pay election
# Table[8][3] = (see
# Table[8][4] = instructions)
# Table[8][5] =
# Table[8][6] = 1i
# Table[8][7] =
# Table[8][8] =
# Table[8][9] =
# Table[9][0] =
# Table[9][1] = z
# Table[9][2] = Add lines 1a through 1h
# Table[9][3] =
# Table[9][4] =
# Table[9][5] =
# Table[9][6] =
# Table[9][7] =
# Table[9][8] = 1z
# Table[9][9] = 105,000
# Table[10][0] = Attach Sch. B
# Table[10][1] = 2a
# Table[10][2] = Tax-exempt interest
# Table[10][3] = 2a
# Table[10][4] =
# Table[10][5] = b Taxable
# Table[10][6] = interest
# Table[10][7] =
# Table[10][8] = 2b
# Table[10][9] = 6,000
# Table[11][0] = if required.
# Table[11][1] = 3a
# Table[11][2] = Qualified dividends
# Table[11][3] = 3a
# Table[11][4] =
# Table[11][5] = b Ordinary
# Table[11][6] = dividends
# Table[11][7] =
# Table[11][8] = 3b
# Table[11][9] =
# Table[12][0] =
# Table[12][1] = 4a
# Table[12][2] = IRA distributions
# Table[12][3] = 4a
# Table[12][4] =
# Table[12][5] = b Taxable
# Table[12][6] = amount
# Table[12][7] =
# Table[12][8] = 4b
# Table[12][9] =
# Table[13][0] = Standard
# Table[13][1] = 5a
# Table[13][2] = Pensions and annuities
# Table[13][3] = 5a
# Table[13][4] =
# Table[13][5] = b Taxable
# Table[13][6] = amount
# Table[13][7] =
# Table[13][8] = 5b
# Table[13][9] =
# Table[14][0] = Deduction for- Single or
# Table[14][1] = 6a
# Table[14][2] = Social security benefits
# Table[14][3] = 6a
# Table[14][4] =
# Table[14][5] = b Taxable
# Table[14][6] = amount
# Table[14][7] =
# Table[14][8] = 6b
# Table[14][9] =
# Table[15][0] = Married filing
# Table[15][1] = c
# Table[15][2] = If you elect to use the lump-sum
# Table[15][3] = election
# Table[15][4] = method, check
# Table[15][5] = here (see instructions)
# Table[15][6] =
# Table[15][7] = NOT_SELECTED,
# Table[15][8] =
# Table[15][9] =
# Table[16][0] = separately, $12,950
# Table[16][1] = 7
# Table[16][2] = Capital gaín or (loss). Attach
# Table[16][3] = Schedule
# Table[16][4] = D if required. If not
# Table[16][5] = required, check
# Table[16][6] = here
# Table[16][7] = NOT_SELECTED,
# Table[16][8] = 7
# Table[16][9] =
# Table[17][0] = Married filing
# Table[17][1] = 8
# Table[17][2] = Other income from Schedule 1,
# Table[17][3] = line 10
# Table[17][4] =
# Table[17][5] =
# Table[17][6] =
# Table[17][7] =
# Table[17][8] = 8
# Table[17][9] = 111,000
# Table[18][0] = jointly or Qualifying
# Table[18][1] = 9
# Table[18][2] = Add lines 1z, 2b, 3b, 4b, 5b, 6b,
# Table[18][3] = 7, and
# Table[18][4] = 8. This is your total
# Table[18][5] = income
# Table[18][6] =
# Table[18][7] =
# Table[18][8] = 9
# Table[18][9] = 7,000
# Table[19][0] = surviving spouse, $25,900
# Table[19][1] = 10
# Table[19][2] = Adjustments to income from
# Table[19][3] = Schedule
# Table[19][4] = 1, line 26
# Table[19][5] =
# Table[19][6] =
# Table[19][7] =
# Table[19][8] = 10
# Table[19][9] = 104,000
# Table[20][0] = Head of
# Table[20][1] = 11
# Table[20][2] = Subtract line 10 from line 9. This
# Table[20][3] = is your
# Table[20][4] = adjusted gross
# Table[20][5] = income
# Table[20][6] =
# Table[20][7] =
# Table[20][8] = 11
# Table[20][9] =
# Table[21][0] = household, $19,400
# Table[21][1] = 12
# Table[21][2] = Standard deduction or Itemized
# Table[21][3] =
# Table[21][4] = deductions (from Schedule
# Table[21][5] = A)
# Table[21][6] =
# Table[21][7] =
# Table[21][8] = 12
# Table[21][9] =
# Table[22][0] = If you checked box under
# Table[22][1] = 13
# Table[22][2] = Qualified business income deduction
# Table[22][3] =
# Table[22][4] = from Form 8995 or
# Table[22][5] = Form 8995-A
# Table[22][6] =
# Table[22][7] =
# Table[22][8] = 13
# Table[22][9] =
# Table[23][0] = any Standard
# Table[23][1] = 14
# Table[23][2] = Add lines 12 and 13
# Table[23][3] =
# Table[23][4] =
# Table[23][5] =
# Table[23][6] =
# Table[23][7] =
# Table[23][8] = 14
# Table[23][9] = 12,000
# Table[24][0] = Deduction, see instructions.
# Table[24][1] = 15
# Table[24][2] = Subtract line 14 from line 11. If
# Table[24][3] = zero or
# Table[24][4] = less, enter -0-. This
# Table[24][5] = is your taxable
# Table[24][6] = income
# Table[24][7] =
# Table[24][8] = 15
# Table[24][9] = 92,000
# Table[25][0] =
# Table[25][1] =
# Table[25][2] =
# Table[25][3] =
# Table[25][4] =
# Table[25][5] =
# Table[25][6] =
# Table[25][7] =
# Table[25][8] =
# Table[25][9] =

# %%
import json

# Initialize a dictionary to store field data
fields_dict = {}

# List of specific key values to extract
fields_to_extract = [
    "Your first name and middle initial",
    "Last name",
    "Your social security number",
    "If joint return, spouse’s first name and middle initial",
    "Last name",
    "Home address (number and street). If you have a P.O. box, see instructions.",
    "Apt. no.",
    "City, town, or post office. If you have a foreign address, also complete spaces below. ",
    "State",
    "ZIP code",
    "Foreign country name",
    "Foreign province/state/county",
    "Foreign postal code",
    "Spouse's social security number",
    "You",
    "Spouse",
    "SSN"
]

# Iterate through the fields
for field in page.form.fields:
    if field.key is not None and field.key.text in fields_to_extract:
        fields_dict[field.key.text] = {
            "value": field.value.text if field.value is not None else "NULL",
            "confidence": field.value.block["Confidence"] if field.value is not None else None
        }

# Convert the dictionary to a JSON string
json_data = json.dumps(fields_dict, indent=4)
print(json_data)
# Out:
# {
#     "Home address (number and street). If you have a P.O. box, see instructions.": {
#         "value": "1040 N PHOENIX RD",
#         "confidence": 91.69149780273438
#     },
#     "You": {
#         "value": "NOT_SELECTED",
#         "confidence": 91.49413299560547
#     },
#     "Spouse": {
#         "value": "NOT_SELECTED",
#         "confidence": 91.27055358886719
#     },
#     "Last name": {
#         "value": "SMITH",
#         "confidence": 90.18329620361328
#     },
#     "Your social security number": {
#         "value": "123 45 6789",
#         "confidence": 90.6737060546875
#     },
#     "Your first name and middle initial": {
#         "value": "JOHN J",
#         "confidence": 90.09069061279297
#     },
#     "Foreign province/state/county": {
#         "value": "NULL",
#         "confidence": null
#     },
#     "ZIP code": {
#         "value": "85308",
#         "confidence": 89.56851959228516
#     },
#     "State": {
#         "value": "A2",
#         "confidence": 89.18620300292969
#     },
#     "Spouse's social security number": {
#         "value": "9871654321",
#         "confidence": 88.43028259277344
#     },
#     "Foreign country name": {
#         "value": "NULL",
#         "confidence": null
#     },
#     "Apt. no.": {
#         "value": "NULL",
#         "confidence": null
#     },
#     "Foreign postal code": {
#         "value": "NULL",
#         "confidence": null
#     }
# }

# %%
# Parse JSON data to a dictionary
fields_dict = json.loads(json_data)

# Convert dictionary to DataFrame
data = []
for key, values in fields_dict.items():
    data.append([key, values["value"], values["confidence"]])

dff2 = pd.DataFrame(data, columns=["Key", "Value", "Confidence"])
dff2['Value']
data = list(dff2['Value'])
data
my_string = ', '.join(data)
dff2
my_string
# Out:
# '1040 N PHOENIX RD, NOT_SELECTED, NOT_SELECTED, SMITH, 123 45 6789, JOHN J, NULL, 85308, A2, 9871654321, NULL, NULL, NULL'

# %% [markdown]
# ## AWS COMPREHEND

# %%
import boto3
import pandas as pd


# Replace "NULL" with a placeholder
placeholder = '<NULL>'
processed_string = my_string.replace('NULL', placeholder)

# Initialize the AWS Comprehend client
comprehend = boto3.client(service_name='comprehend', region_name='us-east-1')

print('Calling DetectEntities')

# Split the processed string into words
words = processed_string.split(', ')

# Create a list to store the results
result_data = []

for word in words:
    response = comprehend.detect_entities(Text=word, LanguageCode='en')
    if response['Entities']:
        entity_type = response['Entities'][0]['Type']
    else:
        entity_type = 'NULL'  # If there are no entities, consider it as "NULL"
    result_data.append({'Word': word, 'Entity_Type': entity_type})

# Create a DataFrame from the list
result_df = pd.DataFrame(result_data)

dff2['Entity'] = result_df['Entity_Type']
dff2
# Out:
# Calling DetectEntities
#                                                   Key              Value
# 0   Home address (number and street). If you have ...  1040 N PHOENIX RD  \
# 1                                                 You       NOT_SELECTED
# 2                                              Spouse       NOT_SELECTED
# 3                                           Last name              SMITH
# 4                         Your social security number        123 45 6789
# 5                  Your first name and middle initial             JOHN J
# 6                       Foreign province/state/county               NULL
# 7                                            ZIP code              85308
# 8                                               State                 A2
# 9                     Spouse's social security number         9871654321
# 10                               Foreign country name               NULL
# 11                                           Apt. no.               NULL
# 12                                Foreign postal code               NULL
#
#     Confidence    Entity
# 0    91.691498  LOCATION
# 1    91.494133      NULL
# 2    91.270554      NULL
# 3    90.183296    PERSON
# 4    90.673706     OTHER
# 5    90.090691    PERSON
# 6          NaN      NULL
# 7    89.568520     OTHER
# 8    89.186203     OTHER
# 9    88.430283     OTHER
# 10         NaN      NULL
# 11         NaN      NULL
# 12         NaN      NULL

# %%
ssn = dff2.loc[dff2["Key"] == "Your social security number", "Value"].values[0]
ssn2 = dff2.loc[dff2["Key"] == "Spouse's social security number", "Value"].values[0]

# %% [markdown]
# ### Custom Entity Recognition Model

# %%
model = !aws comprehend detect-entities --endpoint-arn arn:aws:comprehend:us-east-1:485636232393:entity-recognizer-endpoint/comprehendendpoint --language-code en --text '1040 N PHOENIX RD, NOT_SELECTED, NOT_SELECTED, SMITH, 123 45 6789, JOHN J, NULL, 85308, A2, 9871654321, NULL, NULL, NULL'

# %%
import json

# Your 'model' data as a string
model_str = ' '.join(model)  # Combine the list of strings into one string
model_dict = json.loads(model_str)  # Convert the string to a dictionary

data = {
    "Text": [entity["Text"] for entity in model_dict["Entities"]],
    "Type": [entity["Type"] for entity in model_dict["Entities"]]
}
df = pd.DataFrame(data)

# Check if either of the two values is present in the 'Value' column
if (dff2['Value'] == ssn).any() or (dff2['Value'] == ssn2).any():
    # Find the indices where the conditions are true
    indices_to_update = dff2[(dff2['Value'] == ssn) | (dff2['Value'] == ssn2)].index
    
    # Update the 'Entity' column in the found rows with the 'Type' value from df
    for index in indices_to_update:
        dff2.at[index, 'Entity'] = df['Type'].values[0]

# %%
dff2
# Out:
#                                                   Key              Value
# 0   Home address (number and street). If you have ...  1040 N PHOENIX RD  \
# 1                                                 You       NOT_SELECTED
# 2                                              Spouse       NOT_SELECTED
# 3                                           Last name              SMITH
# 4                         Your social security number        123 45 6789
# 5                  Your first name and middle initial             JOHN J
# 6                       Foreign province/state/county               NULL
# 7                                            ZIP code              85308
# 8                                               State                 A2
# 9                     Spouse's social security number         9871654321
# 10                               Foreign country name               NULL
# 11                                           Apt. no.               NULL
# 12                                Foreign postal code               NULL
#
#     Confidence    Entity
# 0    91.691498  LOCATION
# 1    91.494133      NULL
# 2    91.270554      NULL
# 3    90.183296    PERSON
# 4    90.673706       SSN
# 5    90.090691    PERSON
# 6          NaN      NULL
# 7    89.568520     OTHER
# 8    89.186203     OTHER
# 9    88.430283       SSN
# 10         NaN      NULL
# 11         NaN      NULL
# 12         NaN      NULL

# %%
# Initialize a dictionary to store field data
fields_dict = {}

# List of specific key values to extract
fields_to_extract = [
    "Yes",
    "No"
]

# Iterate through the fields
for field in page.form.fields:
    if field.key is not None and field.key.text in fields_to_extract:
        fields_dict[field.key.text] = {
            "value": field.value.text if field.value is not None else "NULL",
            "confidence": field.value.block["Confidence"] if field.value is not None else None
        }

# Convert the dictionary to a JSON string
json_data_da = json.dumps(fields_dict, indent=4)

# Print the JSON data
print(json_data_da)
# Out:
# {
#     "Yes": {
#         "value": "NOT_SELECTED",
#         "confidence": 90.43658447265625
#     },
#     "No": {
#         "value": "SELECTED",
#         "confidence": 88.84349822998047
#     }
# }

# %%
# Convert dictionary to DataFrame
data = []
for key, values in fields_dict.items():
    data.append([key, values["value"], values["confidence"]])

dff3 = pd.DataFrame(data, columns=["Key", "Value", "Confidence"])

dff3
# Out:
#    Key         Value  Confidence
# 0  Yes  NOT_SELECTED   90.436584
# 1   No      SELECTED   88.843498

# %%
# Initialize a dictionary to store field data
fields_dict = {}

# List of specific key values to extract
fields_to_extract = [
    "You as a dependent",
    "Your spouse as a dependent",
    "Spouse itemizes on a separate return or you were a dual-status alien",
    "Were born before January 2, 1958",
    "Are blind",
    "Was born before January 2, 1958",
    "Is blind"
]

# Iterate through the fields
for field in page.form.fields:
    if field.key is not None and field.key.text in fields_to_extract:
        fields_dict[field.key.text] = {
            "value": field.value.text if field.value is not None else "NULL",
            "confidence": field.value.block["Confidence"] if field.value is not None else None
        }

# Convert the dictionary to a JSON string
json_data_ab = json.dumps(fields_dict, indent=4)

# Print the JSON data
print(json_data_ab)
# Out:
# {
#     "Were born before January 2, 1958": {
#         "value": "NOT_SELECTED",
#         "confidence": 93.31975555419922
#     },
#     "Was born before January 2, 1958": {
#         "value": "NOT_SELECTED",
#         "confidence": 90.74566650390625
#     },
#     "Is blind": {
#         "value": "NOT_SELECTED",
#         "confidence": 90.03730010986328
#     },
#     "Your spouse as a dependent": {
#         "value": "NOT_SELECTED",
#         "confidence": 89.89031219482422
#     },
#     "Spouse itemizes on a separate return or you were a dual-status alien": {
#         "value": "NOT_SELECTED",
#         "confidence": 89.16678619384766
#     },
#     "Are blind": {
#         "value": "NOT_SELECTED",
#         "confidence": 88.45318603515625
#     },
#     "You as a dependent": {
#         "value": "NOT_SELECTED",
#         "confidence": 88.05580139160156
#     }
# }

# %%
# Convert dictionary to DataFrame
data = []
for key, values in fields_dict.items():
    data.append([key, values["value"], values["confidence"]])

dff4 = pd.DataFrame(data, columns=["Key", "Value", "Confidence"])

dff4
# Out:
#                                                  Key         Value  Confidence
# 0                   Were born before January 2, 1958  NOT_SELECTED   93.319756
# 1                    Was born before January 2, 1958  NOT_SELECTED   90.745667
# 2                                           Is blind  NOT_SELECTED   90.037300
# 3                         Your spouse as a dependent  NOT_SELECTED   89.890312
# 4  Spouse itemizes on a separate return or you we...  NOT_SELECTED   89.166786
# 5                                          Are blind  NOT_SELECTED   88.453186
# 6                                 You as a dependent  NOT_SELECTED   88.055801

# %% [markdown]
# # Step 3 - Setting up Amazon A2I human loop to review Textract's low confidence responses
#
# In this step, we will send the form line items in a tabular form to an Amazon A2I human loop for review, and modifications/augmentation to the data as required. Once this is done, we will persist this updated data in a DynamoDB table so downstream applications can use for processing.

# %%
timestamp = time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())
# Amazon SageMaker client
sagemaker_client = boto3.client('sagemaker')

# Amazon Augment AI (A2I) client
a2i = boto3.client('sagemaker-a2i-runtime')

# Amazon S3 client 
s3 = boto3.client('s3')

# Flow definition name - this value is unique per account and region. You can also provide your own value here.
flowDefinitionName = 'fd-hw-docs-' + timestamp

# Task UI name - this value is unique per account and region. You can also provide your own value here.
taskUIName = 'ui-hw-docs-' + timestamp

# Flow definition outputs
OUTPUT_PATH = f's3://' + sess.default_bucket() + '/' + prefix + '/a2i-results'

# %% [markdown]
# ### Step 3b - Create the human task UI
#
# Create a human task UI resource, giving a UI template in liquid html.You can download this tempalte and customize it https://github.com/aws-samples/amazon-textract-a2i-dynamodb-handwritten-tabular/blob/main/tables-keyvalue-sample.liquid.html
# This template will be rendered to the human workers whenever human loop is required. For over 70 pre built UIs, check: https://github.com/aws-samples/amazon-a2i-sample-task-uis. But first, lets declare some variables that we need during the next set of steps.

# %%
template = r"""<script src="https://assets.crowd.aws/crowd-html-elements.js"></script>

<style>
  table, tr, th, td {
    border: 1px solid black;
    border-collapse: collapse;
    padding: 5px;
  }
  .green {
    background-color: green;
  }
  .yellow {
    background-color: yellow;
  }
  .red {
    background-color: red;
  }
</style>
<crowd-form>
  <div>
    <h3>Original PDF</h3>
      <classification-target>
        <img style="width: 100%; max-height: 40%; margin-bottom: 10px" src="{{ task.input.image1 | grant_read_access }}"/>        
      </classification-target> 
  <div>
    <h1>Instructions</h1>
    <p>Please review the form and make corrections where needed.</p>
</div>
<br>

<h3>Filling Status Check Only One Boxes</h3>
<table>
    <tr>
        <th>Key</th>
        <th>Selection</th>
        <th>Confidence</th>
        <th>Corrected Value</th>
        <th>Change Required</th>
        <th>Comments</th>
    </tr>
    {% for entry in task.input.Pairs %}
        <tr>
            <td>{{ entry.Key }}</td>
            <td>{{ entry.Value }}</td>
            <td class="{% if entry.Confidence > 90 %} green {% elsif entry.Confidence >= 85 %} yellow {% else %} red {% endif %}">{{ entry.Confidence }}</td>
            <td>
                <input type="radio" name="change_required_{{ entry.row }}" value="agree" required> Correct
                <input type="radio" name="change_required_{{ entry.row }}" value="disagree" required> Incorrect
            </td>
            <td><input type="text" name="Corrected Column1 value{{ entry.row }}"></td>
            <td><input type="text" name="comments_{{ entry.row }}"></td>
        </tr>
    {% endfor %}
</table>
<br>
<br>
<h2>Section Two</h2>
<table>
    <tr>
        <th>Key</th>
        <th>Value</th>
        <th>Confidence</th>
        <th>Entity<th>
        <th>Corrected Value</th>
        <th>Change Required</th>
        <th>Comments</th>
    </tr>
    {% for entry in task.input.text %}
        <tr>
            <td>{{ entry.Key }}</td>
            <td>{{ entry.Value }}</td>
            <td class="{% if entry.Confidence > 90 %} green {% elsif entry.Confidence >85 %} yellow {% else %} red {% endif %}">{{ entry.Confidence }}</td>
            <td>{{ entry.Entity }}</td>
            <td>
                <input type="radio" name="change_required_{{ entry.row }}" value="agree" required> Correct
                <input type="radio" name="change_required_{{ entry.row }}" value="disagree" required> Incorrect
            </td>
            <td><input type="text" name="Corrected Column2 Values{{ entry.row }}"></td>
            <td><input type="text" name="comments_{{ entry.row }}"></td>
        </tr>
    {% endfor %}
</table>
<h2>DIGITAL ASSET</h2>
<table>
    <tr>
        <th>Key</th>
        <th>Value</th>
        <th>Confidence</th>
        <th>Corrected Value</th>
        <th>Change Required</th>
        <th>Comments</th>
    </tr>
    {% for entry in task.input.text1 %}
        <tr>
            <td>{{ entry.Key }}</td>
            <td>{{ entry.Value }}</td>
            <td class="{% if entry.Confidence > 90 %} green {% elsif entry.Confidence >= 85 %} yellow {% else %} red {% endif %}">{{ entry.Confidence }}</td>
            <td>
                <input type="radio" name="change_required_{{ entry.row }}" value="agree" required> Correct
                <input type="radio" name="change_required_{{ entry.row }}" value="disagree" required> Incorrect
            </td>
            <td><input type="text" name="Corrected Column3 Values{{ entry.row }}"></td>
            <td><input type="text" name="comments_{{ entry.row }}"></td>
        </tr>
    {% endfor %}
</table>
<h2>STANDARD DEDUCTION</h2>
<h3>Age/Blindness</h3>
<table>
    <tr>
        <th>Key</th>
        <th>Value</th>
        <th>Confidence</th>
        <th>Corrected Value</th>
        <th>Change Required</th>
        <th>Comments</th>
    </tr>
    {% for entry in task.input.text2 %}
        <tr>
            <td>{{ entry.Key }}</td>
            <td>{{ entry.Value }}</td>
            <td class="{% if entry.Confidence > 90 %} green {% elsif entry.Confidence >= 85 %} yellow {% else %} red {% endif %}">{{ entry.Confidence }}</td>
            <td>
                <input type="radio" name="change_required_{{ entry.row }}" value="agree" required> Correct
                <input type="radio" name="change_required_{{ entry.row }}" value="disagree" required> Incorrect
            </td>
            <td><input type="text" name="Corrected Column4 Values{{ entry.row }}"></td>
            <td><input type="text" name="comments_{{ entry.row }}"></td>
        </tr>
    {% endfor %}
</table>
<h2>Dependents</h2>
<table>
    <tr>
        <th>LINE ITEM</th>
        <th>FIRST NAME Value</th>
        <th>FIRST NAME Confidence</th>
        <th>LAST NAME Value</th>
        <th>LAST NAME Confidence</th>
        <th>SOCIAL SECURITY NUMBER Value</th>
        <th>SOCIAL SECURITY NUMBER Confidence</th>
        <th>RELATION TO YOU Value</th>
        <th>RELATION TO YOU Confidence</th>
        <th>CHILD TAX CREDIT Value</th>
        <th>CHILD TAX CREDIT Confidence</th>
        <th>CREDIT FOR OTHER DEPENDENCIES Value</th>
        <th>CREDIT FOR OTHER DEPENDENCIES Confidence</th>
        <th>TRUE FIRST NAME</th>
        <th>TRUE LAST NAME</th>
        <th>TRUE SOCIAL SECURITY NUMBER</th>
        <th>TRUE RELATION TO YOU</th>
        <th>TRUE CHILD TAX CREDIT</th>
        <th>TRUE CREDIT FOR OTHER DEPENDENTS</th>
        <th>COMMENTS</th>
    </tr>
    {% for item in task.input.text3 %}
        <tr>
            <td>{{ item.row }}</td>
            <td>{{ item['First Name'] }}</td>
            <td class="{% if item['FirstNameConfidence'] > 90 %} green {% elsif item['FirstNameConfidence'] >= 90 %} yellow {% else %} red {% endif %}">{{ item['FirstNameConfidence'] }}</td>
            <td>{{ item['Last Name'] }}</td>
            <td class="{% if item['LastNameConfidence'] > 90 %} green {% elsif item['LastNameConfidence'] >= 85 %} yellow {% else %} red {% endif %}">{{ item['LastNameConfidence'] }}</td>
            <td>{{ item['SSN'] }}</td>
            <td class="{% if item['SSNConfidence'] > 90 %} green {% elsif item['SSNConfidence'] >= 85 %} yellow {% else %} red {% endif %}">{{ item['SSNConfidence'] }}</td>
            <td>{{ item['Relation to you'] }}</td>
            <td class="{% if item['RTYConfidence'] > 90 %} green {% elsif item['RTYConfidence'] >= 85 %} yellow {% else %} red {% endif %}">{{ item['RTYConfidence'] }}</td>
            <td>{{ item['Child tax credit'] }}</td>
            <td class="{% if item['CTCConfidence'] >= 90 %} green {% elsif item['CTCConfidence'] >= 85 %} yellow {% else %} red {% endif %}">{{ item['CTCConfidence'] }}</td>
            <td>{{ item['Credit for other dependents'] }}</td>
            <td class="{% if item['CTCConfidence'] >= 90 %} green {% elsif item['CTCConfidence'] >= 85 %} yellow {% else %} red {% endif %}">{{ item['CTCConfidence'] }}</td>
            <td>
                <p>
                    <input type="radio" id="agreeline{{ forloop.index }}" name="ratingline{{ forloop.index }}" value="agree" required>
                    <label for="agreeline{{ forloop.index }}">Correct</label>
                </p>
                <p>
                    <input type="radio" id="disagreeline{{ forloop.index }}" name="ratingline{{ forloop.index }}" value="disagree" required>
                    <label for="disagreeline{{ forloop.index }}">Incorrect</label>
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueFirstName{{ forloop.index }}" placeholder="Corrected First Name" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueLastName{{ forloop.index }}" placeholder="Corrected Last Name" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueSSN{{ forloop.index }}" placeholder="Corrected SSN" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueRelation{{ forloop.index }}" placeholder="Corrected Relation" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueChildTaxCredit{{ forloop.index }}" placeholder="Corrected Child Tax Credit" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="TrueCreditForOtherDep{{ forloop.index }}" placeholder="Corrected Credit for Other Dependents" />
                </p>
            </td>
            <td>
                <p>
                    <input type="text" name="ChangeReason{{ forloop.index }}" placeholder="Explain why you changed the value" />
                </p>
            </td>
        </tr>
    {% endfor %}
</table>
</crowd-form>

"""

# %% [markdown]
# After creating this custom template using HTML, you must use this template to generate an Amazon A2I human task UI Amazon Resource Name (ARN) .This ARN has the following format: arn:aws:sagemaker:<aws-region>:<aws-account-number>:human-task-ui/<template-name>. This ARN is associated with a worker task template resource that you can use in one or more human review workflows (flow definitions).Generate a human task UI ARN using a worker task template by using the CreateHumanTaskUi API operation by running the notebook cell below:

# %%
def create_task_ui():
    '''
    Creates a Human Task UI resource.

    Returns:
    struct: HumanTaskUiArn
    '''
    response = sagemaker_client.create_human_task_ui(
        HumanTaskUiName=taskUIName,
        UiTemplate={'Content': template})
    return response

# %%
# Create task UI
humanTaskUiResponse = create_task_ui()
humanTaskUiArn = humanTaskUiResponse['HumanTaskUiArn']
print(humanTaskUiArn)
# Out:
# arn:aws:sagemaker:us-east-1:485636232393:human-task-ui/ui-hw-docs-2023-09-18-20-26-27

# %% [markdown]
# ### Step 3b - Create the Flow Definition
# In this section, we're going to create a flow definition definition. Flow Definitions allow us to specify:
#
# * The workforce that your tasks will be sent to.
# * The instructions that your workforce will receive. This is called a worker task template.
# * Where your output data will be stored.
# * This demo is going to use the API, but you can optionally create this workflow definition in the console as well.
#
# For more details and instructions, see: https://docs.aws.amazon.com/sagemaker/latest/dg/a2i-create-flow-definition.html.

# %%
create_workflow_definition_response = sagemaker_client.create_flow_definition(
        FlowDefinitionName= flowDefinitionName,
        RoleArn= role,
        HumanLoopConfig= {
            "WorkteamArn": WORKTEAM_ARN,
            "HumanTaskUiArn": humanTaskUiArn,
            "TaskCount": 1,
            "TaskDescription": "Review the contents and correct values as indicated",
            "TaskTitle": "Form 1040 Review"
        },
        OutputConfig={
            "S3OutputPath" : OUTPUT_PATH
        }
    )
flowDefinitionArn = create_workflow_definition_response['FlowDefinitionArn'] # let's save this ARN for future use

# %%
for x in range(60):
    describeFlowDefinitionResponse = sagemaker_client.describe_flow_definition(FlowDefinitionName=flowDefinitionName)
    print(describeFlowDefinitionResponse['FlowDefinitionStatus'])
    if (describeFlowDefinitionResponse['FlowDefinitionStatus'] == 'Active'):
        print("Flow Definition is active")
        break
    time.sleep(2)
# Out:
# Initializing
# Active
# Flow Definition is active

# %%
dff
# Out:
#                                 Key         Value  Confidence
# 0            Married filing jointly      SELECTED   93.802086
# 1  Were born before January 2, 1958  NOT_SELECTED   93.319756
# 2   Married filing separately (MFS)  NOT_SELECTED   92.858635
# 3           Head of household (HOH)  NOT_SELECTED   92.730644
# 4                            Single  NOT_SELECTED   90.884300
# 5                You as a dependent  NOT_SELECTED   88.055801

# %% [markdown]
# # Sending predictions to Amazon A2I human loops

# %%
NUM_TO_REVIEW = len(dff) # number of line items to review
dfstart = dff['Key'].to_list()
dfend = dff['Value'].to_list()
dfkeyCon = dff['Confidence'].to_list()


item_list = [{'row': "{}".format(x), 'Key': dfstart[x], 'Value': dfend[x], 'Confidence': dfkeyCon[x]} for x in range(NUM_TO_REVIEW)]
item_list
# Out:
# [{'row': '0',
#   'Key': 'Married filing jointly',
#   'Value': 'SELECTED',
#   'Confidence': 93.80208587646484},
#  {'row': '1',
#   'Key': 'Were born before January 2, 1958',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 93.31975555419922},
#  {'row': '2',
#   'Key': 'Married filing separately (MFS)',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 92.85863494873047},
#  {'row': '3',
#   'Key': 'Head of household (HOH)',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 92.73064422607422},
#  {'row': '4',
#   'Key': 'Single',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 90.8843002319336},
#  {'row': '5',
#   'Key': 'You as a dependent',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 88.05580139160156}]

# %%
NUM_TO_REVIEW = len(dff2) # number of line items to review
dfstart = dff2['Key'].to_list()
dfend = dff2['Value'].to_list()
dfkeyCon = dff2['Confidence'].to_list()
dfentity= dff2['Entity'].to_list()



item_list2 = [{'row': "{}".format(x), 'Key': dfstart[x], 'Value': dfend[x], 'Confidence': dfkeyCon[x], 'Entity': dfentity[x]} for x in range(NUM_TO_REVIEW)]
item_list2
# Out:
# [{'row': '0',
#   'Key': 'Home address (number and street). If you have a P.O. box, see instructions.',
#   'Value': '1040 N PHOENIX RD',
#   'Confidence': 91.69149780273438,
#   'Entity': 'LOCATION'},
#  {'row': '1',
#   'Key': 'You',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 91.49413299560547,
#   'Entity': 'NULL'},
#  {'row': '2',
#   'Key': 'Spouse',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 91.27055358886719,
#   'Entity': 'NULL'},
#  {'row': '3',
#   'Key': 'Last name',
#   'Value': 'SMITH',
#   'Confidence': 90.18329620361328,
#   'Entity': 'PERSON'},
#  {'row': '4',
#   'Key': 'Your social security number',
#   'Value': '123 45 6789',
#   'Confidence': 90.6737060546875,
#   'Entity': 'SSN'},
#  {'row': '5',
#   'Key': 'Your first name and middle initial',
#   'Value': 'JOHN J',
#   'Confidence': 90.09069061279297,
#   'Entity': 'PERSON'},
#  {'row': '6',
#   'Key': 'Foreign province/state/county',
#   'Value': 'NULL',
#   'Confidence': nan,
#   'Entity': 'NULL'},
#  {'row': '7',
#   'Key': 'ZIP code',
#   'Value': '85308',
#   'Confidence': 89.56851959228516,
#   'Entity': 'OTHER'},
#  {'row': '8',
#   'Key': 'State',
#   'Value': 'A2',
#   'Confidence': 89.18620300292969,
#   'Entity': 'OTHER'},
#  {'row': '9',
#   'Key': "Spouse's social security number",
#   'Value': '9871654321',
#   'Confidence': 88.43028259277344,
#   'Entity': 'SSN'},
#  {'row': '10',
#   'Key': 'Foreign country name',
#   'Value': 'NULL',
#   'Confidence': nan,
#   'Entity': 'NULL'},
#  {'row': '11',
#   'Key': 'Apt. no.',
#   'Value': 'NULL',
#   'Confidence': nan,
#   'Entity': 'NULL'},
#  {'row': '12',
#   'Key': 'Foreign postal code',
#   'Value': 'NULL',
#   'Confidence': nan,
#   'Entity': 'NULL'}]

# %%
NUM_TO_REVIEW = len(dff3) # number of line items to review
dfstart = dff3['Key'].to_list()
dfend = dff3['Value'].to_list()
dfkeyCon = dff3['Confidence'].to_list()


item_list3 = [{'row': "{}".format(x), 'Key': dfstart[x], 'Value': dfend[x], 'Confidence': dfkeyCon[x]} for x in range(NUM_TO_REVIEW)]
item_list3
# Out:
# [{'row': '0',
#   'Key': 'Yes',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 90.43658447265625},
#  {'row': '1',
#   'Key': 'No',
#   'Value': 'SELECTED',
#   'Confidence': 88.84349822998047}]

# %%
NUM_TO_REVIEW = len(dff3) # number of line items to review
dfstart = dff4['Key'].to_list()
dfend = dff4['Value'].to_list()
dfkeyCon = dff4['Confidence'].to_list()


item_list4 = [{'row': "{}".format(x), 'Key': dfstart[x], 'Value': dfend[x], 'Confidence': dfkeyCon[x]} for x in range(NUM_TO_REVIEW)]
item_list4
# Out:
# [{'row': '0',
#   'Key': 'Were born before January 2, 1958',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 93.31975555419922},
#  {'row': '1',
#   'Key': 'Was born before January 2, 1958',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 90.74566650390625}]

# %%
import json
import math

# Replace NaN values with None (which will be converted to null in JSON)
for item in item_list2:
    for key, value in item.items():
        if isinstance(value, float) and math.isnan(value):
            item[key] = None

# Update ip_content dictionary
ip_content = {
    "Pairs": item_list,  # Use the transformed item_list here
    "text": item_list2,
    "text1": item_list3,
    "text2": item_list4,
    "text3": item_list5,
    "image1": s3_img_url 
}

# %%
ip_content
# Out:
# {'Pairs': [{'row': '0',
#    'Key': 'Married filing jointly',
#    'Value': 'SELECTED',
#    'Confidence': 93.80208587646484},
#   {'row': '1',
#    'Key': 'Were born before January 2, 1958',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 93.31975555419922},
#   {'row': '2',
#    'Key': 'Married filing separately (MFS)',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 92.85863494873047},
#   {'row': '3',
#    'Key': 'Head of household (HOH)',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 92.73064422607422},
#   {'row': '4',
#    'Key': 'Single',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 90.8843002319336},
#   {'row': '5',
#    'Key': 'You as a dependent',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 88.05580139160156}],
#  'text': [{'row': '0',
#    'Key': 'Home address (number and street). If you have a P.O. box, see instructions.',
#    'Value': '1040 N PHOENIX RD',
#    'Confidence': 91.69149780273438,
#    'Entity': 'LOCATION'},
#   {'row': '1',
#    'Key': 'You',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 91.49413299560547,
#    'Entity': 'NULL'},
#   {'row': '2',
#    'Key': 'Spouse',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 91.27055358886719,
#    'Entity': 'NULL'},
#   {'row': '3',
#    'Key': 'Last name',
#    'Value': 'SMITH',
#    'Confidence': 90.18329620361328,
#    'Entity': 'PERSON'},
#   {'row': '4',
#    'Key': 'Your social security number',
#    'Value': '123 45 6789',
#    'Confidence': 90.6737060546875,
#    'Entity': 'SSN'},
#   {'row': '5',
#    'Key': 'Your first name and middle initial',
#    'Value': 'JOHN J',
#    'Confidence': 90.09069061279297,
#    'Entity': 'PERSON'},
#   {'row': '6',
#    'Key': 'Foreign province/state/county',
#    'Value': 'NULL',
#    'Confidence': None,
#    'Entity': 'NULL'},
#   {'row': '7',
#    'Key': 'ZIP code',
#    'Value': '85308',
#    'Confidence': 89.56851959228516,
#    'Entity': 'OTHER'},
#   {'row': '8',
#    'Key': 'State',
#    'Value': 'A2',
#    'Confidence': 89.18620300292969,
#    'Entity': 'OTHER'},
#   {'row': '9',
#    'Key': "Spouse's social security number",
#    'Value': '9871654321',
#    'Confidence': 88.43028259277344,
#    'Entity': 'SSN'},
#   {'row': '10',
#    'Key': 'Foreign country name',
#    'Value': 'NULL',
#    'Confidence': None,
#    'Entity': 'NULL'},
#   {'row': '11',
#    'Key': 'Apt. no.',
#    'Value': 'NULL',
#    'Confidence': None,
#    'Entity': 'NULL'},
#   {'row': '12',
#    'Key': 'Foreign postal code',
#    'Value': 'NULL',
#    'Confidence': None,
#    'Entity': 'NULL'}],
#  'text1': [{'row': '0',
#    'Key': 'Yes',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 90.43658447265625},
#   {'row': '1',
#    'Key': 'No',
#    'Value': 'SELECTED',
#    'Confidence': 88.84349822998047}],
#  'text2': [{'row': '0',
#    'Key': 'Were born before January 2, 1958',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 93.31975555419922},
#   {'row': '1',
#    'Key': 'Was born before January 2, 1958',
#    'Value': 'NOT_SELECTED',
#    'Confidence': 90.74566650390625}],
#  'text3': [{'row': '0',
#    'First Name': 'JAY',
#    'FirstNameConfidence': 87.59765625,
#    'Last Name': 'SMITH',
#    'LastNameConfidence': 87.59765625,
#    'SSN': ' 135792468 ',
#    'SSNConfidence': 80.68033854166667,
#    'Relation to you': 'SON',
#    'RTYConfidence': 89.94140625,
#    'Child tax credit': 'SELECTED,',
#    'CTCConfidence': 87.98828125,
#    'Credit for other dependents': 'NOT_SELECTED,',
#    'CODConfidence': 85.791015625},
#   {'row': '1',
#    'First Name': 'VICTORIA',
#    'FirstNameConfidence': 88.4765625,
#    'Last Name': 'SMITH',
#    'LastNameConfidence': 88.4765625,
#    'SSN': '246 81 3579',
#    'SSNConfidence': 81.494140625,
#    'Relation to you': 'DAUGHTER',
#    'RTYConfidence': 90.869140625,
#    'Child tax credit': 'SELECTED,',
#    'CTCConfidence': 88.8671875,
#    'Credit for other dependents': 'NOT_SELECTED,',
#    'CODConfidence': 86.669921875},
#   {'row': '2',
#    'First Name': '',
#    'FirstNameConfidence': 86.1328125,
#    'Last Name': '',
#    'LastNameConfidence': 86.1328125,
#    'SSN': '  ',
#    'SSNConfidence': 79.31315104166667,
#    'Relation to you': '',
#    'RTYConfidence': 88.427734375,
#    'Child tax credit': 'NOT_SELECTED,',
#    'CTCConfidence': 86.474609375,
#    'Credit for other dependents': 'NOT_SELECTED,',
#    'CODConfidence': 84.375},
#   {'row': '3',
#    'First Name': '',
#    'FirstNameConfidence': 91.11328125,
#    'Last Name': '',
#    'LastNameConfidence': 91.11328125,
#    'SSN': '  ',
#    'SSNConfidence': 83.90299479166667,
#    'Relation to you': '',
#    'RTYConfidence': 93.5546875,
#    'Child tax credit': 'NOT_SELECTED,',
#    'CTCConfidence': 91.50390625,
#    'Credit for other dependents': 'NOT_SELECTED,',
#    'CODConfidence': 89.208984375}],
#  'image1': 's3://sagemaker-us-east-1-485636232393/textract-a2i-handwritten/f1040 Page 1 Sample - Handwritten - Soumya.pdf.png'}

# %%
item_list2
# Out:
# [{'row': '0',
#   'Key': 'Home address (number and street). If you have a P.O. box, see instructions.',
#   'Value': '1040 N PHOENIX RD',
#   'Confidence': 91.69149780273438,
#   'Entity': 'LOCATION'},
#  {'row': '1',
#   'Key': 'You',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 91.49413299560547,
#   'Entity': 'NULL'},
#  {'row': '2',
#   'Key': 'Spouse',
#   'Value': 'NOT_SELECTED',
#   'Confidence': 91.27055358886719,
#   'Entity': 'NULL'},
#  {'row': '3',
#   'Key': 'Last name',
#   'Value': 'SMITH',
#   'Confidence': 90.18329620361328,
#   'Entity': 'PERSON'},
#  {'row': '4',
#   'Key': 'Your social security number',
#   'Value': '123 45 6789',
#   'Confidence': 90.6737060546875,
#   'Entity': 'SSN'},
#  {'row': '5',
#   'Key': 'Your first name and middle initial',
#   'Value': 'JOHN J',
#   'Confidence': 90.09069061279297,
#   'Entity': 'PERSON'},
#  {'row': '6',
#   'Key': 'Foreign province/state/county',
#   'Value': 'NULL',
#   'Confidence': None,
#   'Entity': 'NULL'},
#  {'row': '7',
#   'Key': 'ZIP code',
#   'Value': '85308',
#   'Confidence': 89.56851959228516,
#   'Entity': 'OTHER'},
#  {'row': '8',
#   'Key': 'State',
#   'Value': 'A2',
#   'Confidence': 89.18620300292969,
#   'Entity': 'OTHER'},
#  {'row': '9',
#   'Key': "Spouse's social security number",
#   'Value': '9871654321',
#   'Confidence': 88.43028259277344,
#   'Entity': 'SSN'},
#  {'row': '10',
#   'Key': 'Foreign country name',
#   'Value': 'NULL',
#   'Confidence': None,
#   'Entity': 'NULL'},
#  {'row': '11',
#   'Key': 'Apt. no.',
#   'Value': 'NULL',
#   'Confidence': None,
#   'Entity': 'NULL'},
#  {'row': '12',
#   'Key': 'Foreign postal code',
#   'Value': 'NULL',
#   'Confidence': None,
#   'Entity': 'NULL'}]

# %%
# Serialize the ip_content dictionary to a JSON string
input_content_json = json.dumps(ip_content, default=str)  # Use default=str to handle non-serializable values

# Print the serialized JSON for verification
print("Serialized JSON Input Content:")
print(input_content_json)

# Continue with starting the human loop
humanLoopName = str(uuid.uuid4())

start_loop_response = a2i.start_human_loop(
    HumanLoopName=humanLoopName,
    FlowDefinitionArn=flowDefinitionArn,
    HumanLoopInput={
        "InputContent": input_content_json
    }
)
# Out:
# Serialized JSON Input Content:
# {"Pairs": [{"row": "0", "Key": "Married filing jointly", "Value": "SELECTED", "Confidence": 93.80208587646484}, {"row": "1", "Key": "Were born before January 2, 1958", "Value": "NOT_SELECTED", "Confidence": 93.31975555419922}, {"row": "2", "Key": "Married filing separately (MFS)", "Value": "NOT_SELECTED", "Confidence": 92.85863494873047}, {"row": "3", "Key": "Head of household (HOH)", "Value": "NOT_SELECTED", "Confidence": 92.73064422607422}, {"row": "4", "Key": "Single", "Value": "NOT_SELECTED", "Confidence": 90.8843002319336}, {"row": "5", "Key": "You as a dependent", "Value": "NOT_SELECTED", "Confidence": 88.05580139160156}], "text": [{"row": "0", "Key": "Home address (number and street). If you have a P.O. box, see instructions.", "Value": "1040 N PHOENIX RD", "Confidence": 91.69149780273438, "Entity": "LOCATION"}, {"row": "1", "Key": "You", "Value": "NOT_SELECTED", "Confidence": 91.49413299560547, "Entity": "NULL"}, {"row": "2", "Key": "Spouse", "Value": "NOT_SELECTED", "Confidence": 91.27055358886719, "Entity": "NULL"}, {"row": "3", "Key": "Last name", "Value": "SMITH", "Confidence": 90.18329620361328, "Entity": "PERSON"}, {"row": "4", "Key": "Your social security number", "Value": "123 45 6789", "Confidence": 90.6737060546875, "Entity": "SSN"}, {"row": "5", "Key": "Your first name and middle initial", "Value": "JOHN J", "Confidence": 90.09069061279297, "Entity": "PERSON"}, {"row": "6", "Key": "Foreign province/state/county", "Value": "NULL", "Confidence": null, "Entity": "NULL"}, {"row": "7", "Key": "ZIP code", "Value": "85308", "Confidence": 89.56851959228516, "Entity": "OTHER"}, {"row": "8", "Key": "State", "Value": "A2", "Confidence": 89.18620300292969, "Entity": "OTHER"}, {"row": "9", "Key": "Spouse's social security number", "Value": "9871654321", "Confidence": 88.43028259277344, "Entity": "SSN"}, {"row": "10", "Key": "Foreign country name", "Value": "NULL", "Confidence": null, "Entity": "NULL"}, {"row": "11", "Key": "Apt. no.", "Value": "NULL", "Confidence": null, "Entity": "NULL"}, {"row": "12", "Key": "Foreign postal code", "Value": "NULL", "Confidence": null, "Entity": "NULL"}], "text1": [{"row": "0", "Key": "Yes", "Value": "NOT_SELECTED", "Confidence": 90.43658447265625}, {"row": "1", "Key": "No", "Value": "SELECTED", "Confidence": 88.84349822998047}], "text2": [{"row": "0", "Key": "Were born before January 2, 1958", "Value": "NOT_SELECTED", "Confidence": 93.31975555419922}, {"row": "1", "Key": "Was born before January 2, 1958", "Value": "NOT_SELECTED", "Confidence": 90.74566650390625}], "text3": [{"row": "0", "First Name": "JAY", "FirstNameConfidence": 87.59765625, "Last Name": "SMITH", "LastNameConfidence": 87.59765625, "SSN": " 135792468 ", "SSNConfidence": 80.68033854166667, "Relation to you": "SON", "RTYConfidence": 89.94140625, "Child tax credit": "SELECTED,", "CTCConfidence": 87.98828125, "Credit for other dependents": "NOT_SELECTED,", "CODConfidence": 85.791015625}, {"row": "1", "First Name": "VICTORIA", "FirstNameConfidence": 88.4765625, "Last Name": "SMITH", "LastNameConfidence": 88.4765625, "SSN": "246 81 3579", "SSNConfidence": 81.494140625, "Relation to you": "DAUGHTER", "RTYConfidence": 90.869140625, "Child tax credit": "SELECTED,", "CTCConfidence": 88.8671875, "Credit for other dependents": "NOT_SELECTED,", "CODConfidence": 86.669921875}, {"row": "2", "First Name": "", "FirstNameConfidence": 86.1328125, "Last Name": "", "LastNameConfidence": 86.1328125, "SSN": "  ", "SSNConfidence": 79.31315104166667, "Relation to you": "", "RTYConfidence": 88.427734375, "Child tax credit": "NOT_SELECTED,", "CTCConfidence": 86.474609375, "Credit for other dependents": "NOT_SELECTED,", "CODConfidence": 84.375}, {"row": "3", "First Name": "", "FirstNameConfidence": 91.11328125, "Last Name": "", "LastNameConfidence": 91.11328125, "SSN": "  ", "SSNConfidence": 83.90299479166667, "Relation to you": "", "RTYConfidence": 93.5546875, "Child tax credit": "NOT_SELECTED,", "CTCConfidence": 91.50390625, "Credit for other de ...

# %%
flowDefinitionArn
# Out:
# 'arn:aws:sagemaker:us-east-1:485636232393:flow-definition/fd-hw-docs-2023-09-18-20-26-27'

# %%
humanLoopName
# Out:
# '3d7e7dbb-d6de-4895-afb4-7980cced653e'

# %% [markdown]
# Check status of human loop

# %%
completed_human_loops = []
resp = a2i.describe_human_loop(HumanLoopName=humanLoopName)
print(f'HumanLoop Name: {humanLoopName}')
print(f'HumanLoop Status: {resp["HumanLoopStatus"]}')
print(f'HumanLoop Output Destination: {resp["HumanLoopOutput"]}')
print('\n')
   
      
if resp["HumanLoopStatus"] == "Completed":
    completed_human_loops.append(resp)
# Out:
# HumanLoop Name: 3d7e7dbb-d6de-4895-afb4-7980cced653e
# HumanLoop Status: InProgress
# HumanLoop Output Destination: {'OutputS3Uri': 's3://sagemaker-us-east-1-485636232393/textract-a2i-handwritten/a2i-results/fd-hw-docs-2023-09-18-20-26-27/2023/09/18/20/26/39/3d7e7dbb-d6de-4895-afb4-7980cced653e/output.json'}

# %%
resp = a2i.describe_human_loop(HumanLoopName=humanLoopName)
resp
# Out:
# {'ResponseMetadata': {'RequestId': '8c168732-30e1-4673-a0e1-af85377004f2',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Mon, 18 Sep 2023 20:26:57 GMT',
#    'content-type': 'application/json; charset=UTF-8',
#    'content-length': '5114',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '8c168732-30e1-4673-a0e1-af85377004f2',
#    'access-control-allow-origin': '*',
#    'x-amz-apigw-id': 'LeDWvH4toAMErYg=',
#    'x-amzn-trace-id': 'Root=1-6508b291-13a741b249c2e2204c52259f'},
#   'RetryAttempts': 0},
#  'CreationTime': datetime.datetime(2023, 9, 18, 20, 26, 39, 670000, tzinfo=tzlocal()),
#  'HumanLoopStatus': 'InProgress',
#  'HumanLoopName': '3d7e7dbb-d6de-4895-afb4-7980cced653e',
#  'HumanLoopArn': 'arn:aws:sagemaker:us-east-1:485636232393:human-loop/3d7e7dbb-d6de-4895-afb4-7980cced653e',
#  'FlowDefinitionArn': 'arn:aws:sagemaker:us-east-1:485636232393:flow-definition/fd-hw-docs-2023-09-18-20-26-27',
#  'HumanLoopOutput': {'OutputS3Uri': 's3://sagemaker-us-east-1-485636232393/textract-a2i-handwritten/a2i-results/fd-hw-docs-2023-09-18-20-26-27/2023/09/18/20/26/39/3d7e7dbb-d6de-4895-afb4-7980cced653e/output.json'}}

# %%
workteamName = WORKTEAM_ARN[WORKTEAM_ARN.rfind('/') + 1:]
print("Navigate to the private worker portal and do the tasks. Make sure you've invited yourself to your workteam!")
print('https://' + sagemaker_client.describe_workteam(WorkteamName=workteamName)['Workteam']['SubDomain'])
# Out:
# Navigate to the private worker portal and do the tasks. Make sure you've invited yourself to your workteam!
# https://pwko5jvpzh.labeling.us-east-1.sagemaker.aws

# %%
completed_human_loops = []
resp = a2i.describe_human_loop(HumanLoopName=humanLoopName)
print(f'HumanLoop Name: {humanLoopName}')
print(f'HumanLoop Status: {resp["HumanLoopStatus"]}')
print(f'HumanLoop Output Destination: {resp["HumanLoopOutput"]}')
print('\n')
    
if resp["HumanLoopStatus"] == "Completed":
    completed_human_loops.append(resp)
# Out:
# HumanLoop Name: 09ad1b3b-ce3c-422d-9e93-8e5d81f0127c
# HumanLoop Status: InProgress
# HumanLoop Output Destination: {'OutputS3Uri': 's3://sagemaker-us-east-1-485636232393/textract-a2i-handwritten/a2i-results/fd-hw-docs-2023-09-18-20-09-33/2023/09/18/20/09/42/09ad1b3b-ce3c-422d-9e93-8e5d81f0127c/output.json'}

# %%
import re
import pprint

pp = pprint.PrettyPrinter(indent=4)

for resp in completed_human_loops:
    splitted_string = re.split('s3://' + sess.default_bucket()  + '/', resp['HumanLoopOutput']['OutputS3Uri'])
    output_bucket_key = splitted_string[1]
    response = s3.get_object(Bucket=bucket, Key=output_bucket_key)
    content = response["Body"].read()
    json_output = json.loads(content)
    pp.pprint(json_output)
    print('\n')

# %%
json_output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[910], line 1
# ----> 1 json_output
#
# NameError: name 'json_output' is not defined

# %%
dff
# Out:
#                                 Key         Value  Confidence
# 0            Married filing jointly      SELECTED   93.802086
# 1  Were born before January 2, 1958  NOT_SELECTED   93.319756
# 2   Married filing separately (MFS)  NOT_SELECTED   92.858635
# 3           Head of household (HOH)  NOT_SELECTED   92.730644
# 4                            Single  NOT_SELECTED   90.884300
# 5                You as a dependent  NOT_SELECTED   88.055801

# %%
#updated array values to be strings for dataframe assignment
for i in json_output['humanAnswers']:
    x = i['answerContent']
        
for j in range(0, len(dff)):    
    dff.at[j, 'TrueHeader'] = str(x.get('Corrected Column1 value'+str(j)))
    dff.at[j, 'Comments'] = str(x.get('comments_'+str(j)))
    
    
dff = dff.where(dff.notnull(), None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[871], line 2
#       1 #updated array values to be strings for dataframe assignment
# ----> 2 for i in json_output['humanAnswers']:
#       3     x = i['answerContent']
#       5 for j in range(0, len(dff)):
#
# NameError: name 'json_output' is not defined

# %%
dff
